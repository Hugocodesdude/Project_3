# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import requests
import re
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rcParams
import folium
from folium import Choropleth, Circle, Marker, Icon, Map
from folium.plugins import HeatMap, MarkerCluster
import pandas as pd
import os
import requests
import json
from dotenv import load_dotenv
from geopy import distance
import IPython

# %% [markdown]
# ## London Dataframes
#
# - 31 Great Pulteney St (51.5121948,-0.1360746)

# %%
#CSV Import: highval
airport_ldn_df_clean= pd.read_csv("../data/airport_ldn_df.csv")

# %%
airport_ldn_df_clean
# Out:
#                             name        lat       lon  \
# 0  London Heathrow Airport (LHR)  51.470012 -0.454478
# 1      London City Airport (LCY)  51.503297  0.050112
# 2              Elstree Aerodrome  51.654044 -0.323953
# 3               Kenley Aerodrome  51.302516 -0.099422
# 4      Biggin Hill Airport (BQH)  51.331889  0.028996
# 5              Sala VIP Heathrow  51.426550 -0.131691
# 6          Damyns Hall Aerodrome  51.531190  0.246276
# 7                Cargo Worldwide  51.523898  0.095290
# 8       Stapleford Flight Centre  51.656588  0.155572
# 9               Denham Aerodrome  51.591065 -0.512883
#
#                                                 type    city  category
# 0  {'typepoint': {'type': 'Point', 'coordinates':...  London  airports
# 1  {'typepoint': {'type': 'Point', 'coordinates':...  London  airports
# 2  {'typepoint': {'type': 'Point', 'coordinates':...  London  airports
# 3  {'typepoint': {'type': 'Point', 'coordinates':...  London  airports
# ...

# %%
#CSV Import: highval
basketball_ldn_df_clean= pd.read_csv("../data/basketball_ldn_df.csv")

# %%
basketball_ldn_df_clean
# Out:
#                                         name        lat       lon  \
# 0  Geraldine Mary Harmsworth Sports Facility  51.496187 -0.106748
# 1                               Aske Gardens  51.528096 -0.083989
# 2           Q Motion Health & Fitness Centre  51.523206 -0.043008
# 3                          Chinbrook Meadows  51.428723  0.028298
# 4                            Kennington Park  51.482819 -0.107596
# 5                        Leyton Jubilee Park  51.564646 -0.025511
# 6                              Victoria Park  51.605484 -0.184854
# 7      Crystal Palace National Sports Centre  51.418907 -0.067866
# 8                          Enfield Town Park  51.651648 -0.086295
# 9                    The Prince of Greenwich  51.476263 -0.009841
#
#                                                 type    city    category
# 0  {'typepoint': {'type': 'Point', 'coordinates':...  London  basketball
# 1  {'typepoint': {'type': 'Point', 'coordinates':...  London  basketball
# ...

# %%
#CSV Import: highval
childcare_ldn_df_clean= pd.read_csv("../data/childcare_ldn_df.csv")

# %%
childcare_ldn_df_clean
# Out:
#                                                 name        lat       lon  \
# 0                        Brookhill Children's Centre  51.484853  0.066747
# 1                         Alderwood Childrens Centre  51.449384  0.085953
# 2                       Newham London Tuition Centre  51.537237  0.027185
# 3                          Premier Lodge Day Nursery  51.427289  0.100880
# 4               Waterways Community Childrens Centre  51.501587  0.113661
# 5        Bright Horizons East India Dock Day Nursery  51.509069 -0.001825
# 6  Bright Horizons New Eltham Day Nursery and Pre...  51.436470  0.062079
# 7                                       Baby Sensory  51.553082  0.231919
# 8  Bright Horizons Blackheath Day Nursery and Pre...  51.458278  0.010933
# 9                                     Zoom Nurseries  51.459091  0.009783
#
#                                                 type    city    category
# 0  {'typepoint': {'type': 'Point', 'coordinates':...  London  child care
# ...

# %%
#CSV Import: highval
music_ldn_df_clean= pd.read_csv("../data/music_ldn_df.csv")

# %%
music_ldn_df_clean
# Out:
#                 name        lat       lon  \
# 0              Tramp  51.508255 -0.137820
# 1     Cirque le Soir  51.512910 -0.138930
# 2        Maddox Club  51.512702 -0.142262
# 3  Ministry of Sound  51.497637 -0.099503
# 4             Phonox  51.464317 -0.114536
# 5       Electrowerkz  51.532262 -0.105177
# 6             Fabric  51.519620 -0.102520
# 7         The Social  51.517359 -0.140988
# 8               Fold  51.519379  0.003826
# 9        Tape London  51.514326 -0.144572
#
#                                                 type    city      category
# 0  {'typepoint': {'type': 'Point', 'coordinates':...  London  music venues
# 1  {'typepoint': {'type': 'Point', 'coordinates':...  London  music venues
# 2  {'typepoint': {'type': 'Point', 'coordinates':...  London  music venues
# 3  {'typepoint': {'type': 'Point', 'coordinates':...  London  music venues
# 4  {'typepoint': {'type': 'Point', 'coordinates':...  London  music venues
# ...

# %%
#CSV Import: highval
petgrooming_ldn_df_clean= pd.read_csv("../data/petgrooming_ldn_df.csv")

# %%
petgrooming_ldn_df_clean
# Out:
#                             name        lat       lon  \
# 0  Wet paws dog grooming parlour  51.490143  0.126140
# 1     Celia Hammond Animal Trust  51.517926  0.012533
# 2               H & I's Grooming  51.458059  0.133845
# 3   Animal Ark Veterinary Centre  51.565823  0.110170
# 4        The Pet Grooming School  51.468002  0.069073
# 5     Barrier Animal Care Clinic  51.492611  0.039651
# 6         Animal Protection Shop  51.482343  0.145960
# 7            About Grooming Time  51.483140  0.151170
# 8       Bexleyheath Dog Grooming  51.478798  0.127427
# 9            Animal Welfare 2000  51.487564  0.092368
#
#                                                 type    city      category
# 0  {'typepoint': {'type': 'Point', 'coordinates':...  London  pet grooming
# 1  {'typepoint': {'type': 'Point', 'coordinates':...  London  pet grooming
# 2  {'typepoint': {'type': 'Point', 'coordinates':...  London  pet grooming
# ...

# %%
#CSV Import: highval
starbucks_ldn_df_clean= pd.read_csv("../data/starbucks_ldn_df_3.csv")

# %%
starbucks_ldn_df_clean
# Out:
#         name        lat       lon  \
# 0  Starbucks  51.507386 -0.142561
# 1  Starbucks  51.514658 -0.150231
# 2  Starbucks  51.499068 -0.135253
# 3  Starbucks  51.512252 -0.121563
# 4  Starbucks  51.498155 -0.132786
# 5  Starbucks  51.516025 -0.144089
# 6  Starbucks  51.512688 -0.133203
# 7  Starbucks  51.515250 -0.135126
# 8  Starbucks  51.507373 -0.122973
# 9  Starbucks  51.494357 -0.146995
#
#                                                 type    city category
# 0  {'typepoint': {'type': 'Point', 'coordinates':...  London   coffee
# 1  {'typepoint': {'type': 'Point', 'coordinates':...  London   coffee
# 2  {'typepoint': {'type': 'Point', 'coordinates':...  London   coffee
# 3  {'typepoint': {'type': 'Point', 'coordinates':...  London   coffee
# 4  {'typepoint': {'type': 'Point', 'coordinates':...  London   coffee
# 5  {'typepoint': {'type': 'Point', 'coordinates':...  London   coffee
# 6  {'typepoint': {'type': 'Point', 'coordinates':...  London   coffee
# ...

# %%
#CSV Import: highval
vegan_ldn_df_clean= pd.read_csv("../data/vegan_ldn_df.csv")

# %%
vegan_ldn_df_clean
# Out:
#                    name        lat       lon  \
# 0              Mildreds  51.513024 -0.136479
# 1             Black Cat  51.551292 -0.055470
# 2        What the Pitta  51.523478 -0.076177
# 3      222 Veggie Vegan  51.486001 -0.203059
# 4              Mildreds  51.531369 -0.117538
# 5               Purezza  51.538144 -0.144202
# 6               Farmacy  51.515491 -0.192777
# 7  The Gate Hammersmith  51.490254 -0.225387
# 8              Mildreds  51.545444 -0.074703
# 9       Mildreds Camden  51.540535 -0.145131
#
#                                                 type    city  \
# 0  {'typepoint': {'type': 'Point', 'coordinates':...  London
# 1  {'typepoint': {'type': 'Point', 'coordinates':...  London
# 2  {'typepoint': {'type': 'Point', 'coordinates':...  London
# 3  {'typepoint': {'type': 'Point', 'coordinates':...  London
# 4  {'typepoint': {'type': 'Point', 'coordinates':...  London
# 5  {'typepoint': {'type': 'Point', 'coordinates':...  London
# ...

# %%
ldn_api_df = pd.concat([airport_ldn_df_clean,basketball_ldn_df_clean,childcare_ldn_df_clean,music_ldn_df_clean,petgrooming_ldn_df_clean,starbucks_ldn_df_clean,vegan_ldn_df_clean], axis=0)
ldn_api_df
# Out:
#                              name        lat       lon  \
# 0   London Heathrow Airport (LHR)  51.470012 -0.454478
# 1       London City Airport (LCY)  51.503297  0.050112
# 2               Elstree Aerodrome  51.654044 -0.323953
# 3                Kenley Aerodrome  51.302516 -0.099422
# 4       Biggin Hill Airport (BQH)  51.331889  0.028996
# ..                            ...        ...       ...
# 5                         Purezza  51.538144 -0.144202
# 6                         Farmacy  51.515491 -0.192777
# 7            The Gate Hammersmith  51.490254 -0.225387
# 8                        Mildreds  51.545444 -0.074703
# 9                 Mildreds Camden  51.540535 -0.145131
#
#                                                  type    city  \
# 0   {'typepoint': {'type': 'Point', 'coordinates':...  London
# 1   {'typepoint': {'type': 'Point', 'coordinates':...  London
# 2   {'typepoint': {'type': 'Point', 'coordinates':...  London
# ...

# %%
ldn_api_df.shape
# Out:
# (70, 6)

# %%
def calc_distance_LDN_mean(x, site):
    #site_coords = (51.5121948,-0.1360746)
    place2_coords = (x.lat, x.lon)
    return (distance.geodesic(site, place2_coords).km)*1000

ldn_api_df["Distance"] = ldn_api_df.apply(lambda x: calc_distance_LDN_mean(x, (51.5121948,-0.1360746)), axis = 1).round(2)
ldn_api_df["Distance"].mean()
# Out:
# 9987.957857142857

# %%
#ldn_api_df["Distance_office_1"] = ldn_api_df.apply(calc_distance_LDN((51.5121948,-0.1360746)), axis = 1).round(2)
#ldn_api_df["Distance"].mean()

# %%
#ldn_api_df["Distance_office_2"] = ldn_api_df.apply(calc_distance_LDN(), axis = 1).round(2)
#ldn_api_df["Distance_office_2"].mean()

# %%
ldn_api_df
# Out:
#                              name        lat       lon  \
# 0   London Heathrow Airport (LHR)  51.470012 -0.454478
# 1       London City Airport (LCY)  51.503297  0.050112
# 2               Elstree Aerodrome  51.654044 -0.323953
# 3                Kenley Aerodrome  51.302516 -0.099422
# 4       Biggin Hill Airport (BQH)  51.331889  0.028996
# ..                            ...        ...       ...
# 5                         Purezza  51.538144 -0.144202
# 6                         Farmacy  51.515491 -0.192777
# 7            The Gate Hammersmith  51.490254 -0.225387
# 8                        Mildreds  51.545444 -0.074703
# 9                 Mildreds Camden  51.540535 -0.145131
#
#                                                  type    city  \
# 0   {'typepoint': {'type': 'Point', 'coordinates':...  London
# 1   {'typepoint': {'type': 'Point', 'coordinates':...  London
# 2   {'typepoint': {'type': 'Point', 'coordinates':...  London
# ...

# %%
ldn_api_df.groupby("category").describe()
# Out:
#                     lat                                                        \
#                   count       mean       std        min        25%        50%
# category
# airports           10.0  51.499105  0.120943  51.302516  51.437416  51.513598
# basketball         10.0  51.517598  0.073834  51.418907  51.477902  51.509697
# child care         10.0  51.481634  0.042745  51.427289  51.451608  51.471972
# coffee             10.0  51.507721  0.007917  51.494357  51.501144  51.509819
# music venues       10.0  51.509877  0.018280  51.464317  51.509367  51.513618
# pet grooming       10.0  51.492441  0.030217  51.458059  51.479684  51.485352
# vegan restaurants  10.0  51.523503  0.022375  51.486001  51.513641  51.527423
#
#                                           lon            ...            \
#                          75%        max count      mean  ...       75%
# category                                                 ...
# ...

# %%
group by

# %%
ls

# %%
from IPython.display import display
display(filename='src/ldn_map_1.html')

# %% [markdown]
# ## Barcelona Dataframes
#
# - Carrer de Zamora, 67 (41.3943113,2.190921)

# %%
#CSV Import: highval
airport_bcn_df_clean= pd.read_csv("../data/airport_bcn_df.csv")

# %%
airport_bcn_df_clean
# Out:
#                                                 name        lat       lon  \
# 0  Barcelona–El Prat Josep Tarradellas Airport (B...  41.289084  2.073963
# 1            Sabadell Airport (Aeroport de Sabadell)  41.521142  2.103024
# 2                      Estacion del Capitolio, Panem  41.296123  2.075351
# 3                                   Newco Base Rampa  41.291094  2.078811
# 4                  Pk 217 T1 Aeropuerto de Barcelona  41.291755  2.075308
# 5                                         KLM lounge  41.290260  2.075008
# 6                  Oficina transitos Vueling, zona a  41.290654  2.074304
# 7                             Sala Tripulaciones VLG  41.291167  2.072467
# 8                               Sala de control sate  41.288312  2.076681
# 9                                 Planta -1 de la T1  41.288614  2.074044
#
#                                                 type       city  category
# 0  {'typepoint': {'type': 'Point', 'coordinates':...  Barcelona  airports
# ...

# %%
#CSV Import: highval
basketball_bcn_df_clean= pd.read_csv("../data/basketball_bcn_df.csv")

# %%
basketball_bcn_df_clean
# Out:
#                                                 name        lat       lon  \
# 0                                   Palau Sant Jordi  41.363271  2.152611
# 1                        Pavelló Olímpic de Badalona  41.442346  2.232148
# 2                       Pavelló Municipal de Cabrils  41.521748  2.369039
# 3                            Club Basquet Granollers  41.616691  2.293679
# 4                               Parque de la Infanta  41.360562  2.063817
# 5                                    Esportiu Claret  41.406447  2.166812
# 6                              Poliesportiu Ripollet  41.500396  2.149372
# 7                              Poliesportiu la Llana  41.501004  2.029792
# 8                             Poliesportiu municipal  41.431310  2.215605
# 9  Complex Esportiu Municipal Sant Quirze del Valles  41.537535  2.075410
#
#                                                 type       city    category
# 0  {'typepoint': {'type': 'Point', 'coordinates':...  Barcelona  basketball
# ...

# %%
#CSV Import: highval
childcare_bcn_df_clean= pd.read_csv("../data/childcare_bcn_df.csv")

# %%
childcare_bcn_df_clean
# Out:
#                                  name        lat       lon  \
# 0                       Ludosfera Sll  41.398219  2.155636
# 1                           EBM Xiroi  41.387858  2.132165
# 2               Escola Bressol Petits  41.393697  2.170025
# 3           Sol Solet, Llar D'Infants  41.397884  2.180625
# 4               Llar d'Infants I-Beth  41.380198  2.148764
# 5  Escola Bressol Municipal Barrufets  41.408167  2.170923
# 6                   Guardería Hamelin  41.393059  2.139467
# 7                  Muksut of Poblenou  41.399533  2.196269
# 8                         El Tricicle  41.374278  2.138011
# 9                             Xantala  41.402963  2.198044
#
#                                                 type       city    category
# 0  {'typepoint': {'type': 'Point', 'coordinates':...  Barcelona  child care
# 1  {'typepoint': {'type': 'Point', 'coordinates':...  Barcelona  child care
# 2  {'typepoint': {'type': 'Point', 'coordinates':...  Barcelona  child care
# ...

# %%
#CSV Import: highval
music_bcn_df_clean= pd.read_csv("../data/music_bcn_df.csv")

# %%
music_bcn_df_clean
# Out:
#                      name        lat       lon  \
# 0  Antilla BCN Latin Club  41.384641  2.154478
# 1              Razzmatazz  41.397599  2.191102
# 2                   Input  41.368636  2.148770
# 3                    Cdlc  41.384976  2.196300
# 4            La Terrrazza  41.368845  2.149262
# 5              Garage 442  41.397175  2.160680
# 6                   Opium  41.385104  2.196826
# 7        Undead Dark Club  41.379763  2.133411
# 8                    Moog  41.378149  2.174909
# 9              Carpe Diem  41.389427  2.163662
#
#                                                 type       city      category
# 0  {'typepoint': {'type': 'Point', 'coordinates':...  Barcelona  music venues
# 1  {'typepoint': {'type': 'Point', 'coordinates':...  Barcelona  music venues
# 2  {'typepoint': {'type': 'Point', 'coordinates':...  Barcelona  music venues
# 3  {'typepoint': {'type': 'Point', 'coordinates':...  Barcelona  music venues
# ...

# %%
#CSV Import: highval
petgrooming_bcn_df_clean= pd.read_csv("../data/petgrooming_bcn_df.csv")

# %%
petgrooming_bcn_df_clean
# Out:
#                                          name        lat       lon  \
# 0                        Kiwoko. Mundo Animal  41.386723  2.161102
# 1                   Centro Profesional Animal  41.386733  2.161261
# 2  Fundacion Altarriba Amigos de los Animales  41.389956  2.170577
# 3                           Ceva Salud Animal  41.395276  2.155801
# 4                               Animalear.com  41.398508  2.163766
#
#                                                 type       city      category
# 0  {'typepoint': {'type': 'Point', 'coordinates':...  Barcelona  pet grooming
# 1  {'typepoint': {'type': 'Point', 'coordinates':...  Barcelona  pet grooming
# 2  {'typepoint': {'type': 'Point', 'coordinates':...  Barcelona  pet grooming
# 3  {'typepoint': {'type': 'Point', 'coordinates':...  Barcelona  pet grooming
# 4  {'typepoint': {'type': 'Point', 'coordinates':...  Barcelona  pet grooming

# %%
#CSV Import: highval
starbucks_bcn_df_clean= pd.read_csv("../data/starbucks_bcn_df.csv")

# %%
starbucks_bcn_df_clean
# Out:
#         name        lat       lon  \
# 0  Starbucks  41.390814  2.165062
# 1  Starbucks  41.385779  2.167932
# 2  Starbucks  41.385204  2.163273
# 3  Starbucks  41.387848  2.169634
# 4  Starbucks  41.381816  2.172250
# 5  Starbucks  41.376510  2.150584
# 6  Starbucks  41.385244  2.177226
# 7  Starbucks  41.374891  2.182597
# 8  Starbucks  41.395158  2.158227
# 9  Starbucks  41.392904  2.165519
#
#                                                 type       city category
# 0  {'typepoint': {'type': 'Point', 'coordinates':...  Barcelona   coffee
# 1  {'typepoint': {'type': 'Point', 'coordinates':...  Barcelona   coffee
# 2  {'typepoint': {'type': 'Point', 'coordinates':...  Barcelona   coffee
# 3  {'typepoint': {'type': 'Point', 'coordinates':...  Barcelona   coffee
# 4  {'typepoint': {'type': 'Point', 'coordinates':...  Barcelona   coffee
# 5  {'typepoint': {'type': 'Point', 'coordinates':...  Barcelona   coffee
# ...

# %%
#CSV Import: highval
vegan_bcn_df_clean= pd.read_csv("../data/vegan_bcn_df.csv")

# %%
vegan_bcn_df_clean
# Out:
#                    name        lat       lon  \
# 0             A Tu Bola  41.380092  2.168815
# 1       Maoz Vegetarian  41.380911  2.174652
# 2  Quinoa Bar Vegetarià  41.402766  2.159899
# 3               La Papa  41.389798  2.157615
# 4         Teresa Carles  41.385039  2.167858
# 5              Menssana  41.390787  2.190208
# 6            La Cerería  41.381564  2.176641
# 7               Federal  41.378062  2.177878
# 8           Flax & Kale  41.385204  2.165382
# 9            Green Spot  41.381781  2.183982
#
#                                                 type       city  \
# 0  {'typepoint': {'type': 'Point', 'coordinates':...  Barcelona
# 1  {'typepoint': {'type': 'Point', 'coordinates':...  Barcelona
# 2  {'typepoint': {'type': 'Point', 'coordinates':...  Barcelona
# 3  {'typepoint': {'type': 'Point', 'coordinates':...  Barcelona
# 4  {'typepoint': {'type': 'Point', 'coordinates':...  Barcelona
# 5  {'typepoint': {'type': 'Point', 'coordinates':...  Barcelona
# ...

# %%
bcn_api_df = pd.concat([airport_bcn_df_clean,basketball_bcn_df_clean,childcare_bcn_df_clean,music_bcn_df_clean,petgrooming_bcn_df_clean,starbucks_bcn_df_clean,vegan_bcn_df_clean], axis=0)
bcn_api_df
# Out:
#                                                  name        lat       lon  \
# 0   Barcelona–El Prat Josep Tarradellas Airport (B...  41.289084  2.073963
# 1             Sabadell Airport (Aeroport de Sabadell)  41.521142  2.103024
# 2                       Estacion del Capitolio, Panem  41.296123  2.075351
# 3                                    Newco Base Rampa  41.291094  2.078811
# 4                   Pk 217 T1 Aeropuerto de Barcelona  41.291755  2.075308
# ..                                                ...        ...       ...
# 5                                            Menssana  41.390787  2.190208
# 6                                          La Cerería  41.381564  2.176641
# 7                                             Federal  41.378062  2.177878
# 8                                         Flax & Kale  41.385204  2.165382
# 9                                          Green Spot  41.381781  2.183982
#
#                                                  type       city  \
# ...

# %%
def calc_distance_BCN_mean(x, site):
    #site_coords = (51.5121948,-0.1360746)
    place2_coords = (x.lat, x.lon)
    return (distance.geodesic(site, place2_coords).km)*1000

bcn_api_df["Distance"] = bcn_api_df.apply(lambda x: calc_distance_BCN_mean(x, (41.3943113,2.190921), axis = 1).round(2)
bcn_api_df["Distance"].mean()
# Out:
#   Input In [47]
#     bcn_api_df["Distance"].mean()
#     ^
# SyntaxError: invalid syntax

# %%
def calc_distance_BCN(x):
    site_coords = (41.3943113,2.190921)
    place2_coords = (x.lat, x.lon)
    return (distance.geodesic(site_coords, place2_coords).km)*1000

bcn_api_df["Distance"] = bcn_api_df.apply(calc_distance_BCN, axis = 1).round(2)

# %%
bcn_api_df

# %% [markdown]
# ## Berlin Distances
#
# - 31 Tucholskystraße (52.5261578,13.3910562)

# %%
#CSV Import: highval
airport_bln_df_clean= pd.read_csv("../data/airport_bln_df.csv")

# %%
#CSV Import: highval
basketball_bln_df_clean= pd.read_csv("../data/basketball_bln_df.csv")

# %%
#CSV Import: highval
childcare_bln_df_clean= pd.read_csv("../data/childcare_bln_df.csv")

# %%
childcare_bln_df_clean
# Out:
#                                           name        lat        lon  \
# 0              FRÖBEL-Kindergarten Schatzinsel  52.512385  13.406038
# 1                  Kinderladen Emil Kirschkern  52.529954  13.398013
# 2            FRÖBEL-Kindergarten Casa Fantasia  52.535267  13.399369
# 3             FRÖBEL-Kindergarten kaleidoscope  52.502381  13.435970
# 4                             KiMu Haltestelle  52.512465  13.467076
# 5                  FRÖBEL-Kindergarten Am Ring  52.514992  13.472276
# 6               FRÖBEL-Kindergarten Wirbelwind  52.493528  13.458451
# 7  John F. Kennedy Friendship Center e.V. Kita  52.454612  13.310066
# 8                       Kita Württemberg Allee  52.512555  13.260816
# 9                                      Småland  52.469804  13.367184
#
#                                                 type    city    category
# 0  {'typepoint': {'type': 'Point', 'coordinates':...  Berlin  child care
# ...

# %%
#CSV Import: highval
music_bln_df_clean= pd.read_csv("../data/music_bln_df.csv")

# %%
#CSV Import: highval
petgrooming_bln_df_clean= pd.read_csv("../data/petgrooming_bln_df.csv")

# %%
#CSV Import: highval
starbucks_bln_df_clean= pd.read_csv("../data/starbucks_bln_df.csv")

# %%
#CSV Import: highval
vegan_bln_df_clean= pd.read_csv("../data/vegan_bln_df.csv")

# %%
bln_api_df = pd.concat([airport_bln_df_clean,basketball_bln_df_clean,childcare_bln_df_clean,music_bln_df_clean,petgrooming_bln_df_clean,starbucks_bln_df_clean,vegan_bln_df_clean], axis=0)
bln_api_df
# Out:
#                          name        lat        lon  \
# 0   Flugplatz Werneuchen GmbH  52.629537  13.735207
# 1          Flugplatz Saarmund  52.308314  13.114647
# 2           Sleepless Records  52.516090  13.376894
# 3          Matthew Rosen N102  52.499586  13.362878
# 4               AirSight GmbH  52.542522  13.383938
# ..                        ...        ...        ...
# 5                   Holy Flat  52.490078  13.427266
# 6          Falafel Dream 2010  52.543234  13.365171
# 7           1990 Vegan Living  52.510345  13.458633
# 8                       Li.Ke  52.511606  13.458694
# 9                 Baba Angora  52.504001  13.316851
#
#                                                  type    city  \
# 0   {'typepoint': {'type': 'Point', 'coordinates':...  Berlin
# 1   {'typepoint': {'type': 'Point', 'coordinates':...  Berlin
# 2   {'typepoint': {'type': 'Point', 'coordinates':...  Berlin
# 3   {'typepoint': {'type': 'Point', 'coordinates':...  Berlin
# ...

# %%
def calc_distance_BLN(x):
    site_coords = (52.5261578,13.3910562)
    place2_coords = (x.lat, x.lon)
    return (distance.geodesic(site_coords, place2_coords).km)*1000

bln_api_df["Distance"] = bln_api_df.apply(calc_distance_BLN, axis = 1).round(2)

# %%
bln_api_df
# Out:
#                          name        lat        lon  \
# 0   Flugplatz Werneuchen GmbH  52.629537  13.735207
# 1          Flugplatz Saarmund  52.308314  13.114647
# 2           Sleepless Records  52.516090  13.376894
# 3          Matthew Rosen N102  52.499586  13.362878
# 4               AirSight GmbH  52.542522  13.383938
# ..                        ...        ...        ...
# 5                   Holy Flat  52.490078  13.427266
# 6          Falafel Dream 2010  52.543234  13.365171
# 7           1990 Vegan Living  52.510345  13.458633
# 8                       Li.Ke  52.511606  13.458694
# 9                 Baba Angora  52.504001  13.316851
#
#                                                  type    city  \
# 0   {'typepoint': {'type': 'Point', 'coordinates':...  Berlin
# 1   {'typepoint': {'type': 'Point', 'coordinates':...  Berlin
# 2   {'typepoint': {'type': 'Point', 'coordinates':...  Berlin
# 3   {'typepoint': {'type': 'Point', 'coordinates':...  Berlin
# ...

# %%
def calc_distance_BL_mean(x, site):
    #site_coords = (51.5121948,-0.1360746)
    place2_coords = (x.lat, x.lon)
    return (distance.geodesic(site, place2_coords).km)*1000

bln_api_df["Distance"] = bln_api_df.apply(lambda x: calc_distance_BLN_mean(x, (52.5261578,13.3910562)), axis = 1).round(2)
bln_api_df["Distance"].mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [61], in <cell line: 6>()
#       3     place2_coords = (x.lat, x.lon)
#       4     return (distance.geodesic(site, place2_coords).km)*1000
# ----> 6 bln_api_df["Distance"] = bln_api_df.apply(lambda x: calc_distance_BLN_mean(x, (52.5261578,13.3910562)), axis = 1).round(2)
#       7 bln_api_df["Distance"].mean()
#
# File ~/opt/anaconda3/envs/ironhack/lib/python3.9/site-packages/pandas/core/frame.py:8848, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    8837 from pandas.core.apply import frame_apply
#    8839 op = frame_apply(
#    8840     self,
#    8841     func=func,
#    (...)
#    8846     kwargs=kwargs,
#    8847 )
# -> 8848 return op.apply().__finalize__(self, method="apply")
#
# ...

# %%
bln_api_df.groupby("category").describe()
# Out:
#                     lat                                                        \
#                   count       mean       std        min        25%        50%
# category
# airports           10.0  52.497406  0.079601  52.308314  52.485699  52.501124
# basketball         10.0  52.511486  0.031115  52.455546  52.489340  52.510534
# child care         10.0  52.503794  0.025183  52.454612  52.495741  52.512425
# coffee             10.0  52.517002  0.007548  52.503837  52.512476  52.519666
# music venues       10.0  52.509743  0.011455  52.493365  52.503660  52.510858
# pet grooming        8.0  52.510696  0.016130  52.494157  52.502433  52.508294
# vegan restaurants  10.0  52.513747  0.017392  52.490078  52.505004  52.510976
#
#                                           lon             ...             \
#                          75%        max count       mean  ...        75%
# category                                                  ...
# ...
