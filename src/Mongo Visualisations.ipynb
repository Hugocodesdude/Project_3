# %% [markdown]
# ## Preliminary City Viz

# %%
#Tools
import requests
from bs4 import BeautifulSoup
import pandas as pd
import requests
import re
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rcParams

# %%
import folium
from folium import Choropleth, Circle, Marker, Icon, Map
from folium.plugins import HeatMap, MarkerCluster
import pandas as pd

# %%
import os
import requests
import json
from dotenv import load_dotenv
import pandas as pd

# %%
#CSV Import: highval
bcn_highval_companies_clean= pd.read_csv("../data/bcn_highval_companies_clean.csv")

# %%
#DataFrame
bcn_highval_companies_clean
# Out:
#         name                                            offices  \
# 0      eyeOS  [{'description': 'HQ', 'address1': 'La Rambla ...
# 1  Futurlink  [{'description': '', 'address1': 'Passeig de G...
# 2       vLex  [{'description': 'VLEX HQ (Barcelona)', 'addre...
# 3      Nuroa  [{'description': 'Offices', 'address1': 'Carre...
# 4     3scale  [{'description': '3scale SPAIN', 'address1': '...
# 5     3scale  [{'description': '3scale SPAIN', 'address1': '...
# 6  Openbravo  [{'description': 'Branch', 'address1': 'Pau Cl...
# 7    Teambox  [{'description': 'Barcelona Office', 'address1...
#
#            description              address1 address2 zip_code       city  \
# 0                   HQ      La Rambla 140 4C      NaN    08002  Barcelona
# 1                  NaN  Passeig de Gracia 49      NaN    08018  Barcelona
# 2  VLEX HQ (Barcelona)   Consell de Cent 334      NaN   E08009  Barcelona
# 3              Offices    Carrer de Bailen 7      NaN    08010  Barcelona
# 4         3scale SPAIN       C/Napols 187, 8      NaN    08013  Barcelona
# 5         3scale SPAIN       C/Napols 187, 8      NaN    08013  Barcelona
# 6               Branch        Pau Claris 138      NaN    08009  Barcelona
# 7     Barcelona Office  Ronda Universitat 31    5o 4a    08007  Barcelona
#
#   state_code country_code   latitude  longitude
# 0        NaN          ESP  41.385486   2.170287
# 1        NaN          ESP  41.396553   2.189241
# 2        NaN          ESP  41.392852   2.168021
# 3        NaN          ESP  41.391679   2.177571
# 4        NaN          ESP  41.406335   2.192023
# 5        NaN          ESP  41.406335   2.192023
# 6        NaN          ESP  41.393532   2.166078
# 7         CA          ESP  41.406335   2.192023

# %% [markdown]
# # Barcelona

# %%
#bcn geolocation 
barna_lat = 41.3898224
barna_long = 2.163367

# %%
#map
bcn_map_1 = Map(location=[barna_lat, barna_long], zoom_start=15)
bcn_map_1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6a4ecfee24e60ca938ced86eb2f987d4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6a4ecfee24e60ca938ced86eb2f987d4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_6a4ecfee24e60ca938ced86eb2f987d4 = L.map(
#                 &quot;map_6a4ecfee24e60ca938ced86eb2f987d4&quot;,
#                 {
#                     center: [41.3898224, 2.163367],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_aac73ddce5f10c506e5d41061e44cf7d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6a4ecfee24e60ca938ced86eb2f987d4);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#highval companies loop
for index, row in bcn_highval_companies_clean.iterrows():
    #1. MARKER without icon
    district = {"location": [row["latitude"], row["longitude"]], "tooltip": row["name"]}
    icon = Icon (
            color="blue",
            opacity = 0.6,
            prefix = "fa",
            icon = "building-o",
            icon_color = "black",
            icon_size=(30, 30)
        )
    #3. Marker
    new_marker = Marker(**district, icon = icon, radius = 2)
    #4. Add the Marker
    new_marker.add_to(bcn_map_1)

# %%
#CSV Import: design
bcn_design_companies_clean= pd.read_csv("../data/bcn_design_companies_clean.csv")

# %%
#DataFrame
bcn_design_companies_clean
# Out:
#      name                                            offices   description  \
# 0  MEDDIA  [{'description': 'Headquarters', 'address1': '...  Headquarters
#
#            address1  address2  zip_code       city  state_code country_code  \
# 0  Av. Diagonal 237       NaN      8013  Barcelona         NaN          ESP
#
#     latitude  longitude
# 0  41.401809   2.181565

# %%
#Design companies loop
for index, row in bcn_design_companies_clean.iterrows():
    #1. MARKER without icon
    district = {"location": [row["latitude"], row["longitude"]], "tooltip": row["name"]}
    icon = Icon (
            color="red",
            opacity = 0.6,
            prefix = "fa",
            icon = "building-o",
            icon_color = "white",
            icon_size=(30, 30)
        )
    #3. Marker
    new_marker = Marker(**district, icon = icon, radius = 2)
    #4. Add the Marker
    new_marker.add_to(bcn_map_1)

# %%
#CSV Import: videogame
bcn_videogame_companies_clean= pd.read_csv("../data/bcn_videogame_companies_clean.csv")

# %%
#Video game companies loop
for index, row in bcn_videogame_companies_clean.iterrows():
    #1. MARKER without icon
    district = {"location": [row["latitude"], row["longitude"]], "tooltip": row["name"]}
    icon = Icon (
            color="pink",
            opacity = 1,
            prefix = "fa",
            icon = "headset",
            icon_color = "black",
            icon_size=(30, 30)
        )
    #3. Marker
    new_marker = Marker(**district, icon = icon, radius = 2)
    #4. Add the Marker
    new_marker.add_to(bcn_map_1)

# %%
#BCN Companies Map
bcn_map_1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6a4ecfee24e60ca938ced86eb2f987d4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6a4ecfee24e60ca938ced86eb2f987d4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_6a4ecfee24e60ca938ced86eb2f987d4 = L.map(
#                 &quot;map_6a4ecfee24e60ca938ced86eb2f987d4&quot;,
#                 {
#                     center: [41.3898224, 2.163367],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_aac73ddce5f10c506e5d41061e44cf7d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6a4ecfee24e60ca938ced86eb2f987d4);
#
#
#             var marker_ed9a8a6f0ebe9cf051b5581f7c711d27 = L.marker(
#                 [41.3854855, 2.1702872],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_6a4ecfee24e60ca938ced86eb2f987d4);
#
#
#             var icon_f697eeb93d92f70a101b32aa426f6fa6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_ed9a8a6f0ebe9cf051b5581f7c711d27.setIcon(icon_f697eeb93d92f70a101b32aa426f6fa6);
#
#
#             marker_ed9a8a6f0ebe9cf051b5581f7c711d27.bindTooltip(
#                 `&lt;div&gt;
#                      eyeOS
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_eb0777b57d7984e78a6744d1b213fcc7 = L.marker(
#                 [41.396553, 2.189241],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_6a4ecfee24e60ca938ced86eb2f987d4);
#
#
#             var icon_b2ce4df624ba1237738ec10fb23d9d79 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_eb0777b57d7984e78a6744d1b213fcc7.setIcon(icon_b2ce4df624ba1237738ec10fb23d9d79);
#
#
#             marker_eb0777b57d7984e78a6744d1b213fcc7.bindTooltip(
#                 `&lt;div&gt;
#                      Futurlink
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_dd437fbdbfe3025b1115787439fb054b = L.marker(
#                 [41.392852, 2.168021],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_6a4ecfee24e60ca938ced86eb2f987d4);
#
#
#             var icon_d886dbee23362d19b4a1cbe62c4ec848 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_dd437fbdbfe3025b1115787439fb054b.setIcon(icon_d886dbee23362d19b4a1cbe62c4ec848);
#
#
#             marker_dd437fbdbfe3025b1115787439fb054b.bindTooltip(
#                 `&lt;div&gt;
#                      vLex
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_0242669c9853eec482b45dbbcd266cc2 = L.marker(
#                 [41.3916792, 2.1775706],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_6a4ecfee24e60ca938ced86eb2f987d4);
#
#
#             var icon_364e3fc56a5047b61e9e541b3c8da662 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_0242669c9853eec482b45dbbcd266cc2.setIcon(icon_364e3fc56a5047b61e9e541b3c8da662);
#
#
#             marker_0242669c9853eec482b45dbbcd266cc2.bindTooltip(
#                 `&lt;div&gt;
#                      Nuroa
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_382504a3a10046e97f23525bac772e8a = L.marker(
#                 [41.406335, 2.192023],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_6a4ecfee24e60ca938ced86eb2f987d4);
#
#
#             var icon_08a393c576ffc302244b26f865d047f0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quo

# %%
bcn_map_1.save('bcn_map_1.html')

# %% [markdown]
# # Berlin

# %%
#Berlin Geolocation
bern_lat = 52.5147951
bern_long = 13.3775787

# %%
#Map
bln_map_1 = Map(location=[bern_lat, bern_long], zoom_start=15)
bln_map_1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_74a7d4e7c624aab3a65b5bbb480d6f07 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_74a7d4e7c624aab3a65b5bbb480d6f07&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_74a7d4e7c624aab3a65b5bbb480d6f07 = L.map(
#                 &quot;map_74a7d4e7c624aab3a65b5bbb480d6f07&quot;,
#                 {
#                     center: [52.5147951, 13.3775787],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e6c04544e2e7964d1341e40ff240400f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_74a7d4e7c624aab3a65b5bbb480d6f07);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#CSV Import: highval
bln_highval_companies_clean= pd.read_csv("../data/bln_highval_companies_clean.csv")

# %%
#highval companies loop
for index, row in bln_highval_companies_clean.iterrows():
    #1. MARKER without icon
    district = {"location": [row["latitude"], row["longitude"]], "tooltip": row["name"]}
    icon = Icon (
            color="blue",
            opacity = 0.6,
            prefix = "fa",
            icon = "building-o",
            icon_color = "black",
            icon_size=(30, 30)
        )
    #3. Marker
    new_marker = Marker(**district, icon = icon, radius = 2)
    #4. Add the Marker
    new_marker.add_to(bln_map_1)

# %%
#CSV Import: design
bln_design_companies_clean= pd.read_csv("../data/bln_design_companies_clean.csv")

# %%
#Design companies loop
for index, row in bln_design_companies_clean.iterrows():
    #1. MARKER without icon
    district = {"location": [row["latitude"], row["longitude"]], "tooltip": row["name"]}
    icon = Icon (
            color="red",
            opacity = 0.6,
            prefix = "fa",
            icon = "building-o",
            icon_color = "white",
            icon_size=(30, 30)
        )
    #3. Marker
    new_marker = Marker(**district, icon = icon, radius = 2)
    #4. Add the Marker
    new_marker.add_to(bln_map_1)

# %%
#CSV Import: videogame
bln_videogame_companies_clean= pd.read_csv("../data/bln_videogame_companies_clean.csv")

# %%
#Video game companies loop
for index, row in bln_videogame_companies_clean.iterrows():
    #1. MARKER without icon
    district = {"location": [row["latitude"], row["longitude"]], "tooltip": row["name"]}
    icon = Icon (
            color="pink",
            opacity = 0.6,
            prefix = "fa",
            icon = "building-o",
            icon_color = "white",
            icon_size=(30, 30)
        )
    #3. Marker
    new_marker = Marker(**district, icon = icon, radius = 2)
    #4. Add the Marker
    new_marker.add_to(bln_map_1)

# %%
#BLN Companies Map
bln_map_1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_74a7d4e7c624aab3a65b5bbb480d6f07 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_74a7d4e7c624aab3a65b5bbb480d6f07&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_74a7d4e7c624aab3a65b5bbb480d6f07 = L.map(
#                 &quot;map_74a7d4e7c624aab3a65b5bbb480d6f07&quot;,
#                 {
#                     center: [52.5147951, 13.3775787],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e6c04544e2e7964d1341e40ff240400f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_74a7d4e7c624aab3a65b5bbb480d6f07);
#
#
#             var marker_a6fd312d17d468cd9fdafabfa759ce97 = L.marker(
#                 [52.523402, 13.398694],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_74a7d4e7c624aab3a65b5bbb480d6f07);
#
#
#             var icon_c3395731acff7ba3eaea64fa9923e17e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_a6fd312d17d468cd9fdafabfa759ce97.setIcon(icon_c3395731acff7ba3eaea64fa9923e17e);
#
#
#             marker_a6fd312d17d468cd9fdafabfa759ce97.bindTooltip(
#                 `&lt;div&gt;
#                      Plazes
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_73ca75968bce278d412535eb1e035d99 = L.marker(
#                 [52.4897, 13.38861],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_74a7d4e7c624aab3a65b5bbb480d6f07);
#
#
#             var icon_a8bc68828ec8f7e6c75eb3ea55cd7bd6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_73ca75968bce278d412535eb1e035d99.setIcon(icon_a8bc68828ec8f7e6c75eb3ea55cd7bd6);
#
#
#             marker_73ca75968bce278d412535eb1e035d99.bindTooltip(
#                 `&lt;div&gt;
#                      babbel
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_b0db5ed71ce2b4698a69367eed03e12c = L.marker(
#                 [52.512249, 13.419841],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_74a7d4e7c624aab3a65b5bbb480d6f07);
#
#
#             var icon_018e3de2f7b782947773dfaae3af85af = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_b0db5ed71ce2b4698a69367eed03e12c.setIcon(icon_018e3de2f7b782947773dfaae3af85af);
#
#
#             marker_b0db5ed71ce2b4698a69367eed03e12c.bindTooltip(
#                 `&lt;div&gt;
#                      Metaversum
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_ea8a41332f726db337e99b824f1612da = L.marker(
#                 [52.52348, 13.411494],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_74a7d4e7c624aab3a65b5bbb480d6f07);
#
#
#             var icon_3c4bafd8fb39e3630fe1cec23f36adb3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_ea8a41332f726db337e99b824f1612da.setIcon(icon_3c4bafd8fb39e3630fe1cec23f36adb3);
#
#
#             marker_ea8a41332f726db337e99b824f1612da.bindTooltip(
#                 `&lt;div&gt;
#                      gate5
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_a87e337d4e924baea7b44075d63dc10d = L.marker(
#                 [52.5283614, 13.4124563],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_74a7d4e7c624aab3a65b5bbb480d6f07);
#
#
#             var icon_9126190f892e17e72262e1a4b4dd6b2e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;blac

# %%
bln_map_1.save('bln_map_1.html')

# %% [markdown]
# ## London

# %%
ldn_lat = 51.5037375
ldn_long = -0.1346877

# %%
ldn_map_1 = Map(location=[ldn_lat, ldn_long], zoom_start=15)
ldn_map_1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2ee7350b4ea165a37f3f50cac615d20f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2ee7350b4ea165a37f3f50cac615d20f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_2ee7350b4ea165a37f3f50cac615d20f = L.map(
#                 &quot;map_2ee7350b4ea165a37f3f50cac615d20f&quot;,
#                 {
#                     center: [51.5037375, -0.1346877],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3db47c00295c236212b118ebf07f6659 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2ee7350b4ea165a37f3f50cac615d20f);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#CSV Import: highval
ldn_highval_companies_clean= pd.read_csv("../data/ldn_highval_companies_clean.csv")

# %%
#highval companies loop
for index, row in ldn_highval_companies_clean.iterrows():
    #1. MARKER without icon
    district = {"location": [row["latitude"], row["longitude"]], "tooltip": row["name"]}
    icon = Icon (
            color="blue",
            opacity = 0.6,
            prefix = "fa",
            icon = "building-o",
            icon_color = "black",
            icon_size=(30, 30)
        )
    #3. Marker
    new_marker = Marker(**district, icon = icon, radius = 2)
    #4. Add the Marker
    new_marker.add_to(ldn_map_1)

# %%
#CSV Import: design
ldn_design_companies_clean= pd.read_csv("../data/ldn_design_companies_clean.csv")

# %%
#Design companies loop
for index, row in ldn_design_companies_clean.iterrows():
    #1. MARKER without icon
    district = {"location": [row["latitude"], row["longitude"]], "tooltip": row["name"]}
    icon = Icon (
            color="red",
            opacity = 0.6,
            prefix = "fa",
            icon = "building-o",
            icon_color = "white",
            icon_size=(30, 30)
        )
    #3. Marker
    new_marker = Marker(**district, icon = icon, radius = 2)
    #4. Add the Marker
    new_marker.add_to(ldn_map_1)

# %%
#CSV Import: videogame
ldn_videogame_companies_clean= pd.read_csv("../data/ldn_videogame_companies_clean.csv")

# %%
ldn_videogame_companies_clean
# Out:
#                    name                                            offices  \
# 0              Babelgum  [{'description': '', 'address1': '', 'address2...
# 1              blinkbox  [{'description': None, 'address1': '20-24 Kirb...
# 2               idiomag  [{'description': None, 'address1': '', 'addres...
# 3              Playfish  [{'description': 'Corporate Headquarters', 'ad...
# 4                 Pikum  [{'description': None, 'address1': '7 Chalcot ...
# 5               Vigster  [{'description': 'London Office', 'address1': ...
# 6              Mixcloud  [{'description': 'Office', 'address1': 'Tabern...
# 7      Illumina Digital  [{'description': '8 Canham Mews', 'address1': ...
# 8              BeatPick  [{'description': 'London Office', 'address1': ...
# 9          CareerPlayer  [{'description': '', 'address1': '', 'address2...
# 10         Wazoo Sports  [{'description': '', 'address1': 'P.O. Box 328...
# 11       Kramaley Games  [{'description': 'London', 'address1': '12A Ec...
# 12         Filmed Media  [{'description': 'Head Office', 'address1': '5...
# 13             Spoonfed  [{'description': 'Spoonfed LDN', 'address1': '...
# 14              Swiffen  [{'description': 'London Office', 'address1': ...
# 15               Owngig  [{'description': 'Owngig.com', 'address1': '1&...
# 16           Bandstocks  [{'description': 'Civilian Industries PLC', 'a...
# 17  Keen Software House  [{'description': 'London Office', 'address1': ...
#
#                 description                address1           address2  \
# 0                       NaN                     NaN                NaN
# 1                       NaN      20-24 Kirby Street                NaN
# 2                       NaN                     NaN                NaN
# 3    Corporate Headquarters  125 Kensington High St             W8 5SF
# 4                       NaN          7 Chalcot Road                NaN
# 5             London Office                     NaN                NaN
# 6                    Office       Tabernacle Street                NaN
# 7             8 Canham Mews             Canham Road                NaN
# 8             London Office                     NaN                NaN
# 9                       NaN                     NaN                NaN
# 10                      NaN           P.O. Box 3289                NaN
# 11                   London    12A Eccleston Street        Westminster
# 12              Head Office       58 Salusbury Road        Queens Park
# 13             Spoonfed LDN               Studio 16  14 Southgate Road
# 14            London Office   114, St. Martins Lane                NaN
# 15               Owngig.com       1&2 Barley Shotts    246 Acklam Road
# 16  Civilian Industries PLC       17 Shorts Gardens      Covent Garden
# 17            London Office  145-157 St John Street                NaN
#
#     zip_code    city state_code country_code   latitude  longitude
# 0        NaN  London        NaN          GBR  53.344104  -6.267494
# 1   EC1N 8TS  London        NaN          GBR  51.520779  -0.107590
# 2        NaN  London        NaN          GBR  51.500152  -0.126236
# 3     London  London        NaN          GBR  51.499109  -0.198480
# 4    Nw1 8lh  London        NaN          GBR  51.539778  -0.152998
# 5        NaN  London        NaN          GBR  51.500152  -0.126236
# 6        NaN  London        NaN          GBR  51.539910  -0.285979
# 7     W3 7SR  London        NaN          GBR  51.503612  -0.256280
# 8        NaN  London        NaN          GBR  51.500152  -0.126236
# 9        NaN  London        NaN          GBR  51.500152  -0.126236
# 10     40743  London         KY          USA  37.128600 -84.083400
# 11  SW1W 9LT  London        NaN          GBR  51.494500  -0.147932
# 12   NW6 6NP  London        NaN          GBR  51.535901  -0.205508
# 13    N1 3LY  London        NaN          GBR  51.757745  -1.218672
# 14   WC2N4BE  London        NaN          GBR  51.516338  -0.082817
# 15   W10 5YG  London        NaN          GBR  39.396150  22.763030
# 16  WC2H 9AT  London        NaN          GBR  51.514213  -0.126185
# 17  EC1V 4PY  London        NaN          GBR  51.522076  -0.115300

# %%
#Video game companies loop
for index, row in ldn_videogame_companies_clean.iterrows():
    #1. MARKER without icon
    district = {"location": [row["latitude"], row["longitude"]], "tooltip": row["name"]}
    icon = Icon (
            color="pink",
            opacity = 0.6,
            prefix = "fa",
            icon = "building-o",
            icon_color = "white",
            icon_size=(30, 30)
        )
    #3. Marker
    new_marker = Marker(**district, icon = icon, radius = 2)
    #4. Add the Marker
    new_marker.add_to(ldn_map_1)

# %%
ldn_map_1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2ee7350b4ea165a37f3f50cac615d20f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2ee7350b4ea165a37f3f50cac615d20f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_2ee7350b4ea165a37f3f50cac615d20f = L.map(
#                 &quot;map_2ee7350b4ea165a37f3f50cac615d20f&quot;,
#                 {
#                     center: [51.5037375, -0.1346877],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3db47c00295c236212b118ebf07f6659 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2ee7350b4ea165a37f3f50cac615d20f);
#
#
#             var marker_2de03c82af1b33f39d071c642647dde7 = L.marker(
#                 [53.344104, -6.267494],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_2ee7350b4ea165a37f3f50cac615d20f);
#
#
#             var icon_569a7c4597b249f1cc40137dd84a1d57 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_2de03c82af1b33f39d071c642647dde7.setIcon(icon_569a7c4597b249f1cc40137dd84a1d57);
#
#
#             marker_2de03c82af1b33f39d071c642647dde7.bindTooltip(
#                 `&lt;div&gt;
#                      Babelgum
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_79a7a97266ea95a4ba9039df13425d57 = L.marker(
#                 [37.09024, -95.712891],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_2ee7350b4ea165a37f3f50cac615d20f);
#
#
#             var icon_9f0e3d2ff0e7eb32f19962a156f2c161 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_79a7a97266ea95a4ba9039df13425d57.setIcon(icon_9f0e3d2ff0e7eb32f19962a156f2c161);
#
#
#             marker_79a7a97266ea95a4ba9039df13425d57.bindTooltip(
#                 `&lt;div&gt;
#                      Kelkoo
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_53853d91633aa573db0078d0b155dabc = L.marker(
#                 [41.53155, -72.188584],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_2ee7350b4ea165a37f3f50cac615d20f);
#
#
#             var icon_26b1598a82133650664adaed1a6930b3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_53853d91633aa573db0078d0b155dabc.setIcon(icon_26b1598a82133650664adaed1a6930b3);
#
#
#             marker_53853d91633aa573db0078d0b155dabc.bindTooltip(
#                 `&lt;div&gt;
#                      ReachLocal
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_84232942b7b87eaf56c8d520f246e020 = L.marker(
#                 [51.5108803, -0.1418973],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_2ee7350b4ea165a37f3f50cac615d20f);
#
#
#             var icon_acd1c5c454ad4f6cadd11baaf1b1119c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_84232942b7b87eaf56c8d520f246e020.setIcon(icon_acd1c5c454ad4f6cadd11baaf1b1119c);
#
#
#             marker_84232942b7b87eaf56c8d520f246e020.bindTooltip(
#                 `&lt;div&gt;
#                      Seedcamp
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_22a018f14a94be9d45d9a99837c8de92 = L.marker(
#                 [51.5192042, -0.1626103],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_2ee7350b4ea165a37f3f50cac615d20f);
#
#
#             var icon_a6980fc113fa2919ef9573c26aee4ab2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;:

# %%
ldn_map_1.save('ldn_map_1.html')

# %% [markdown]
# # FourSquare APIs

# %% [markdown]
# ## Vegan BCN

# %%
load_dotenv()
# Out:
# True

# %%
token_fsq = os.getenv("token_foursquare")

# %%
# Copy and paste from example from website

vegan_bcn_url = "https://api.foursquare.com/v3/places/search?ll=41.3898224%2C2.163367&categories=13377"

headers = {
    "accept": "application/json",
    "Authorization": "fsq3ziQGzWOXPwEcMzd/Rtxo+uQG864OuLbWTFrbzs4E/+U="
}



vegan_bcn_response = requests.get(vegan_bcn_url, headers=headers).json()

# %%
#vegan_bcn_list loop
vegan_bcn_list = []
for i in vegan_bcn_response ["results"]:
    
    name = i["name"]
    address =  i["location"]["formatted_address"]
    lat = i["geocodes"]["main"]["latitude"]
    lon = i["geocodes"]["main"]["longitude"]
        
    type_ = {"typepoint": 
                          {"type": "Point", 
                           "coordinates": [lat, lon]}}
    
    vegan_bcn_list.append({"name":name, "lat":lat, "lon":lon, "type":type_})
    
vegan_bcn_list
# Out:
# [{'name': 'A Tu Bola',
#   'lat': 41.380092,
#   'lon': 2.168815,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [41.380092, 2.168815]}}},
#  {'name': 'Maoz Vegetarian',
#   'lat': 41.380911,
#   'lon': 2.174652,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [41.380911, 2.174652]}}},
#  {'name': 'Quinoa Bar Vegetarià',
#   'lat': 41.402766,
#   'lon': 2.159899,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [41.402766, 2.159899]}}},
#  {'name': 'La Papa',
#   'lat': 41.389798,
#   'lon': 2.157615,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [41.389798, 2.157615]}}},
#  {'name': 'Teresa Carles',
#   'lat': 41.385039,
#   'lon': 2.167858,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [41.385039, 2.167858]}}},
#  {'name': 'Menssana',
#   'lat': 41.390787,
#   'lon': 2.190208,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [41.390787, 2.190208]}}},
#  {'name': 'La Cerería',
#   'lat': 41.381564,
#   'lon': 2.176641,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [41.381564, 2.176641]}}},
#  {'name': 'Federal',
#   'lat': 41.378062,
#   'lon': 2.177878,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [41.378062, 2.177878]}}},
#  {'name': 'Flax & Kale',
#   'lat': 41.385204,
#   'lon': 2.165382,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [41.385204, 2.165382]}}},
#  {'name': 'Green Spot',
#   'lat': 41.381781,
#   'lon': 2.183982,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [41.381781, 2.183982]}}}]

# %%
#Into DataFrame
vegan_bcn_df = pd.DataFrame(vegan_bcn_list)

# %%
vegan_bcn_df
# Out:
#                    name        lat       lon  \
# 0             A Tu Bola  41.380092  2.168815
# 1       Maoz Vegetarian  41.380911  2.174652
# 2  Quinoa Bar Vegetarià  41.402766  2.159899
# 3               La Papa  41.389798  2.157615
# 4         Teresa Carles  41.385039  2.167858
# 5              Menssana  41.390787  2.190208
# 6            La Cerería  41.381564  2.176641
# 7               Federal  41.378062  2.177878
# 8           Flax & Kale  41.385204  2.165382
# 9            Green Spot  41.381781  2.183982
#
#                                                 type
# 0  {'typepoint': {'type': 'Point', 'coordinates':...
# 1  {'typepoint': {'type': 'Point', 'coordinates':...
# 2  {'typepoint': {'type': 'Point', 'coordinates':...
# 3  {'typepoint': {'type': 'Point', 'coordinates':...
# 4  {'typepoint': {'type': 'Point', 'coordinates':...
# 5  {'typepoint': {'type': 'Point', 'coordinates':...
# 6  {'typepoint': {'type': 'Point', 'coordinates':...
# 7  {'typepoint': {'type': 'Point', 'coordinates':...
# 8  {'typepoint': {'type': 'Point', 'coordinates':...
# 9  {'typepoint': {'type': 'Point', 'coordinates':...

# %%
#Save DF
vegan_bcn_df.to_csv("../data/vegan_bcn_df.csv", index=False)

# %%
#Vegan BCN Marker Loop
for index, row in vegan_bcn_df.iterrows():
    #1. MARKER without icon
    district = {"location": [row["lat"], row["lon"]], "tooltip": row["name"]}
    icon = Icon (
            color="green",
            opacity = 0.2,
            prefix = "fa",
            icon = "fa-solid fa-seedling",
            icon_color = "black",
            icon_size=(30, 30)
        )
    #3. Marker
    new_marker = Marker(**district, icon = icon, radius = 2)
    #4. Add the Marker
    new_marker.add_to(bcn_map_1)

# %%
bcn_map_1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6a4ecfee24e60ca938ced86eb2f987d4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6a4ecfee24e60ca938ced86eb2f987d4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_6a4ecfee24e60ca938ced86eb2f987d4 = L.map(
#                 &quot;map_6a4ecfee24e60ca938ced86eb2f987d4&quot;,
#                 {
#                     center: [41.3898224, 2.163367],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_aac73ddce5f10c506e5d41061e44cf7d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6a4ecfee24e60ca938ced86eb2f987d4);
#
#
#             var marker_ed9a8a6f0ebe9cf051b5581f7c711d27 = L.marker(
#                 [41.3854855, 2.1702872],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_6a4ecfee24e60ca938ced86eb2f987d4);
#
#
#             var icon_f697eeb93d92f70a101b32aa426f6fa6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_ed9a8a6f0ebe9cf051b5581f7c711d27.setIcon(icon_f697eeb93d92f70a101b32aa426f6fa6);
#
#
#             marker_ed9a8a6f0ebe9cf051b5581f7c711d27.bindTooltip(
#                 `&lt;div&gt;
#                      eyeOS
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_eb0777b57d7984e78a6744d1b213fcc7 = L.marker(
#                 [41.396553, 2.189241],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_6a4ecfee24e60ca938ced86eb2f987d4);
#
#
#             var icon_b2ce4df624ba1237738ec10fb23d9d79 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_eb0777b57d7984e78a6744d1b213fcc7.setIcon(icon_b2ce4df624ba1237738ec10fb23d9d79);
#
#
#             marker_eb0777b57d7984e78a6744d1b213fcc7.bindTooltip(
#                 `&lt;div&gt;
#                      Futurlink
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_dd437fbdbfe3025b1115787439fb054b = L.marker(
#                 [41.392852, 2.168021],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_6a4ecfee24e60ca938ced86eb2f987d4);
#
#
#             var icon_d886dbee23362d19b4a1cbe62c4ec848 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_dd437fbdbfe3025b1115787439fb054b.setIcon(icon_d886dbee23362d19b4a1cbe62c4ec848);
#
#
#             marker_dd437fbdbfe3025b1115787439fb054b.bindTooltip(
#                 `&lt;div&gt;
#                      vLex
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_0242669c9853eec482b45dbbcd266cc2 = L.marker(
#                 [41.3916792, 2.1775706],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_6a4ecfee24e60ca938ced86eb2f987d4);
#
#
#             var icon_364e3fc56a5047b61e9e541b3c8da662 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_0242669c9853eec482b45dbbcd266cc2.setIcon(icon_364e3fc56a5047b61e9e541b3c8da662);
#
#
#             marker_0242669c9853eec482b45dbbcd266cc2.bindTooltip(
#                 `&lt;div&gt;
#                      Nuroa
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_382504a3a10046e97f23525bac772e8a = L.marker(
#                 [41.406335, 2.192023],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_6a4ecfee24e60ca938ced86eb2f987d4);
#
#
#             var icon_08a393c576ffc302244b26f865d047f0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quo

# %% [markdown]
# ## Vegan BLN

# %%
# Copy and paste from example from website

vegan_bln_url = "https://api.foursquare.com/v3/places/search?ll=52.5172198%2C13.3782205&categories=13377"

headers = {
    "accept": "application/json",
    "Authorization": "fsq3ziQGzWOXPwEcMzd/Rtxo+uQG864OuLbWTFrbzs4E/+U="
}

vegan_bln_response = requests.get(vegan_bln_url, headers=headers).json()

# %%
#vegan_bln_list loop
vegan_bln_list = []
for i in vegan_bln_response ["results"]:
    
    name = i["name"]
    address =  i["location"]["formatted_address"]
    lat = i["geocodes"]["main"]["latitude"]
    lon = i["geocodes"]["main"]["longitude"]
        
    type_ = {"typepoint": 
                          {"type": "Point", 
                           "coordinates": [lat, lon]}}
    
    vegan_bln_list.append({"name":name, "lat":lat, "lon":lon, "type":type_})
    
vegan_bln_list
# Out:
# [{'name': 'Cookies Cream',
#   'lat': 52.516429,
#   'lon': 13.388216,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [52.516429, 13.388216]}}},
#  {'name': 'Frea',
#   'lat': 52.528188,
#   'lon': 13.393794,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [52.528188, 13.393794]}}},
#  {'name': 'W-Der Imbiss',
#   'lat': 52.534364,
#   'lon': 13.405191,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [52.534364, 13.405191]}}},
#  {'name': 'Brammibal’s Donuts',
#   'lat': 52.508011,
#   'lon': 13.373939,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [52.508011, 13.373939]}}},
#  {'name': 'Witz Hummus',
#   'lat': 52.491215,
#   'lon': 13.404595,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [52.491215, 13.404595]}}},
#  {'name': 'Holy Flat',
#   'lat': 52.490078,
#   'lon': 13.427266,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [52.490078, 13.427266]}}},
#  {'name': 'Falafel Dream 2010',
#   'lat': 52.543234,
#   'lon': 13.365171,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [52.543234, 13.365171]}}},
#  {'name': '1990 Vegan Living',
#   'lat': 52.510345,
#   'lon': 13.458633,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [52.510345, 13.458633]}}},
#  {'name': 'Li.Ke',
#   'lat': 52.511606,
#   'lon': 13.458694,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [52.511606, 13.458694]}}},
#  {'name': 'Baba Angora',
#   'lat': 52.504001,
#   'lon': 13.316851,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [52.504001, 13.316851]}}}]

# %%
#Into DataFrame
vegan_bln_df = pd.DataFrame(vegan_bln_list)

# %%
vegan_bln_df
# Out:
#                  name        lat        lon  \
# 0       Cookies Cream  52.516429  13.388216
# 1                Frea  52.528188  13.393794
# 2        W-Der Imbiss  52.534364  13.405191
# 3  Brammibal’s Donuts  52.508011  13.373939
# 4         Witz Hummus  52.491215  13.404595
# 5           Holy Flat  52.490078  13.427266
# 6  Falafel Dream 2010  52.543234  13.365171
# 7   1990 Vegan Living  52.510345  13.458633
# 8               Li.Ke  52.511606  13.458694
# 9         Baba Angora  52.504001  13.316851
#
#                                                 type
# 0  {'typepoint': {'type': 'Point', 'coordinates':...
# 1  {'typepoint': {'type': 'Point', 'coordinates':...
# 2  {'typepoint': {'type': 'Point', 'coordinates':...
# 3  {'typepoint': {'type': 'Point', 'coordinates':...
# 4  {'typepoint': {'type': 'Point', 'coordinates':...
# 5  {'typepoint': {'type': 'Point', 'coordinates':...
# 6  {'typepoint': {'type': 'Point', 'coordinates':...
# 7  {'typepoint': {'type': 'Point', 'coordinates':...
# 8  {'typepoint': {'type': 'Point', 'coordinates':...
# 9  {'typepoint': {'type': 'Point', 'coordinates':...

# %%
#Save DF
vegan_bln_df.to_csv("../data/vegan_bln_df.csv", index=False)

# %%
#Vegan BLN Marker Loop
for index, row in vegan_bln_df.iterrows():
    #1. MARKER without icon
    district = {"location": [row["lat"], row["lon"]], "tooltip": row["name"]}
    icon = Icon (
            color="green",
            opacity = 0.2,
            prefix = "fa",
            icon = "fa-solid fa-seedling",
            icon_color = "black",
            icon_size=(30, 30)
        )
    #3. Marker
    new_marker = Marker(**district, icon = icon, radius = 2)
    #4. Add the Marker
    new_marker.add_to(bln_map_1)

# %%
bln_map_1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_74a7d4e7c624aab3a65b5bbb480d6f07 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_74a7d4e7c624aab3a65b5bbb480d6f07&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_74a7d4e7c624aab3a65b5bbb480d6f07 = L.map(
#                 &quot;map_74a7d4e7c624aab3a65b5bbb480d6f07&quot;,
#                 {
#                     center: [52.5147951, 13.3775787],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e6c04544e2e7964d1341e40ff240400f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_74a7d4e7c624aab3a65b5bbb480d6f07);
#
#
#             var marker_a6fd312d17d468cd9fdafabfa759ce97 = L.marker(
#                 [52.523402, 13.398694],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_74a7d4e7c624aab3a65b5bbb480d6f07);
#
#
#             var icon_c3395731acff7ba3eaea64fa9923e17e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_a6fd312d17d468cd9fdafabfa759ce97.setIcon(icon_c3395731acff7ba3eaea64fa9923e17e);
#
#
#             marker_a6fd312d17d468cd9fdafabfa759ce97.bindTooltip(
#                 `&lt;div&gt;
#                      Plazes
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_73ca75968bce278d412535eb1e035d99 = L.marker(
#                 [52.4897, 13.38861],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_74a7d4e7c624aab3a65b5bbb480d6f07);
#
#
#             var icon_a8bc68828ec8f7e6c75eb3ea55cd7bd6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_73ca75968bce278d412535eb1e035d99.setIcon(icon_a8bc68828ec8f7e6c75eb3ea55cd7bd6);
#
#
#             marker_73ca75968bce278d412535eb1e035d99.bindTooltip(
#                 `&lt;div&gt;
#                      babbel
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_b0db5ed71ce2b4698a69367eed03e12c = L.marker(
#                 [52.512249, 13.419841],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_74a7d4e7c624aab3a65b5bbb480d6f07);
#
#
#             var icon_018e3de2f7b782947773dfaae3af85af = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_b0db5ed71ce2b4698a69367eed03e12c.setIcon(icon_018e3de2f7b782947773dfaae3af85af);
#
#
#             marker_b0db5ed71ce2b4698a69367eed03e12c.bindTooltip(
#                 `&lt;div&gt;
#                      Metaversum
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_ea8a41332f726db337e99b824f1612da = L.marker(
#                 [52.52348, 13.411494],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_74a7d4e7c624aab3a65b5bbb480d6f07);
#
#
#             var icon_3c4bafd8fb39e3630fe1cec23f36adb3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_ea8a41332f726db337e99b824f1612da.setIcon(icon_3c4bafd8fb39e3630fe1cec23f36adb3);
#
#
#             marker_ea8a41332f726db337e99b824f1612da.bindTooltip(
#                 `&lt;div&gt;
#                      gate5
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_a87e337d4e924baea7b44075d63dc10d = L.marker(
#                 [52.5283614, 13.4124563],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_74a7d4e7c624aab3a65b5bbb480d6f07);
#
#
#             var icon_9126190f892e17e72262e1a4b4dd6b2e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;blac
