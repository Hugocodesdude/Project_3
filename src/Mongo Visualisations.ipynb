# %% [markdown]
# ## Preliminary City Viz

# %%
#Tools
import requests
from bs4 import BeautifulSoup
import pandas as pd
import requests
import re
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rcParams

# %%
import folium
from folium import Choropleth, Circle, Marker, Icon, Map
from folium.plugins import HeatMap, MarkerCluster
import pandas as pd

# %%
#CSV Import: highval
bcn_highval_companies_clean= pd.read_csv("../data/bcn_highval_companies_clean.csv")

# %%
#DataFrame
bcn_highval_companies_clean
# Out:
#         name                                            offices  \
# 0      eyeOS  [{'description': 'HQ', 'address1': 'La Rambla ...
# 1  Futurlink  [{'description': '', 'address1': 'Passeig de G...
# 2       vLex  [{'description': 'VLEX HQ (Barcelona)', 'addre...
# 3      Nuroa  [{'description': 'Offices', 'address1': 'Carre...
# 4     3scale  [{'description': '3scale SPAIN', 'address1': '...
# 5     3scale  [{'description': '3scale SPAIN', 'address1': '...
# 6  Openbravo  [{'description': 'Branch', 'address1': 'Pau Cl...
# 7    Teambox  [{'description': 'Barcelona Office', 'address1...
#
#            description              address1 address2 zip_code       city  \
# 0                   HQ      La Rambla 140 4C      NaN    08002  Barcelona
# 1                  NaN  Passeig de Gracia 49      NaN    08018  Barcelona
# 2  VLEX HQ (Barcelona)   Consell de Cent 334      NaN   E08009  Barcelona
# 3              Offices    Carrer de Bailen 7      NaN    08010  Barcelona
# 4         3scale SPAIN       C/Napols 187, 8      NaN    08013  Barcelona
# 5         3scale SPAIN       C/Napols 187, 8      NaN    08013  Barcelona
# 6               Branch        Pau Claris 138      NaN    08009  Barcelona
# 7     Barcelona Office  Ronda Universitat 31    5o 4a    08007  Barcelona
#
#   state_code country_code   latitude  longitude
# 0        NaN          ESP  41.385486   2.170287
# 1        NaN          ESP  41.396553   2.189241
# 2        NaN          ESP  41.392852   2.168021
# 3        NaN          ESP  41.391679   2.177571
# 4        NaN          ESP  41.406335   2.192023
# 5        NaN          ESP  41.406335   2.192023
# 6        NaN          ESP  41.393532   2.166078
# 7         CA          ESP  41.406335   2.192023

# %% [markdown]
# ## Barcelona

# %%
#bcn geolocation 
barna_lat = 41.3898224
barna_long = 2.163367

# %%
#map
bcn_map_1 = Map(location=[barna_lat, barna_long], zoom_start=15)
bcn_map_1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d96fd034b402eda3890be59cc8f18c1a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d96fd034b402eda3890be59cc8f18c1a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_d96fd034b402eda3890be59cc8f18c1a = L.map(
#                 &quot;map_d96fd034b402eda3890be59cc8f18c1a&quot;,
#                 {
#                     center: [41.3898224, 2.163367],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1a11720f3492c226c8a33d84f007981a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d96fd034b402eda3890be59cc8f18c1a);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#highval companies loop
for index, row in bcn_highval_companies_clean.iterrows():
    #1. MARKER without icon
    district = {"location": [row["latitude"], row["longitude"]], "tooltip": row["name"]}
    icon = Icon (
            color="blue",
            opacity = 0.6,
            prefix = "fa",
            icon = "building-o",
            icon_color = "black",
            icon_size=(30, 30)
        )
    #3. Marker
    new_marker = Marker(**district, icon = icon, radius = 2)
    #4. Add the Marker
    new_marker.add_to(bcn_map_1)

# %%
#CSV Import: design
bcn_design_companies_clean= pd.read_csv("../data/bcn_design_companies_clean.csv")

# %%
#DataFrame
bcn_design_companies_clean
# Out:
#      name                                            offices   description  \
# 0  MEDDIA  [{'description': 'Headquarters', 'address1': '...  Headquarters
#
#            address1  address2  zip_code       city  state_code country_code  \
# 0  Av. Diagonal 237       NaN      8013  Barcelona         NaN          ESP
#
#     latitude  longitude
# 0  41.401809   2.181565

# %%
#Design companies loop
for index, row in bcn_design_companies_clean.iterrows():
    #1. MARKER without icon
    district = {"location": [row["latitude"], row["longitude"]], "tooltip": row["name"]}
    icon = Icon (
            color="red",
            opacity = 0.6,
            prefix = "fa",
            icon = "building-o",
            icon_color = "white",
            icon_size=(30, 30)
        )
    #3. Marker
    new_marker = Marker(**district, icon = icon, radius = 2)
    #4. Add the Marker
    new_marker.add_to(bcn_map_1)

# %%
#CSV Import: videogame
bcn_videogame_companies_clean= pd.read_csv("../data/bcn_videogame_companies_clean.csv")

# %%
#Video game companies loop
for index, row in bcn_videogame_companies_clean.iterrows():
    #1. MARKER without icon
    district = {"location": [row["latitude"], row["longitude"]], "tooltip": row["name"]}
    icon = Icon (
            color="green",
            opacity = 0.6,
            prefix = "fa",
            icon = "building-o",
            icon_color = "white",
            icon_size=(30, 30)
        )
    #3. Marker
    new_marker = Marker(**district, icon = icon, radius = 2)
    #4. Add the Marker
    new_marker.add_to(bcn_map_1)

# %%
#BCN Companies Map
bcn_map_1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d96fd034b402eda3890be59cc8f18c1a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d96fd034b402eda3890be59cc8f18c1a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_d96fd034b402eda3890be59cc8f18c1a = L.map(
#                 &quot;map_d96fd034b402eda3890be59cc8f18c1a&quot;,
#                 {
#                     center: [41.3898224, 2.163367],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1a11720f3492c226c8a33d84f007981a = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d96fd034b402eda3890be59cc8f18c1a);
#
#
#             var marker_3e1d2083f2af697867409cf1a23c27f2 = L.marker(
#                 [41.3854855, 2.1702872],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_d96fd034b402eda3890be59cc8f18c1a);
#
#
#             var icon_44503cef3b5ff7e54c165a3c61cd1f97 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_3e1d2083f2af697867409cf1a23c27f2.setIcon(icon_44503cef3b5ff7e54c165a3c61cd1f97);
#
#
#             marker_3e1d2083f2af697867409cf1a23c27f2.bindTooltip(
#                 `&lt;div&gt;
#                      eyeOS
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_458841396eb752b043195c16587d81bf = L.marker(
#                 [41.396553, 2.189241],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_d96fd034b402eda3890be59cc8f18c1a);
#
#
#             var icon_8891e350c2cb715800f6fd46ac8e8b7e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_458841396eb752b043195c16587d81bf.setIcon(icon_8891e350c2cb715800f6fd46ac8e8b7e);
#
#
#             marker_458841396eb752b043195c16587d81bf.bindTooltip(
#                 `&lt;div&gt;
#                      Futurlink
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_62b9ad423b9327f90d322fc2e33309d0 = L.marker(
#                 [41.392852, 2.168021],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_d96fd034b402eda3890be59cc8f18c1a);
#
#
#             var icon_6fb3310e01d05697a7a287908a342aa8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_62b9ad423b9327f90d322fc2e33309d0.setIcon(icon_6fb3310e01d05697a7a287908a342aa8);
#
#
#             marker_62b9ad423b9327f90d322fc2e33309d0.bindTooltip(
#                 `&lt;div&gt;
#                      vLex
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_a1b85d84b4da87ac4585e1ff38c1d634 = L.marker(
#                 [41.3916792, 2.1775706],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_d96fd034b402eda3890be59cc8f18c1a);
#
#
#             var icon_6d60c0faf5426dce93ab17a346c6380b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_a1b85d84b4da87ac4585e1ff38c1d634.setIcon(icon_6d60c0faf5426dce93ab17a346c6380b);
#
#
#             marker_a1b85d84b4da87ac4585e1ff38c1d634.bindTooltip(
#                 `&lt;div&gt;
#                      Nuroa
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_855a652f306226801d13c77f3a03a2b9 = L.marker(
#                 [41.406335, 2.192023],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_d96fd034b402eda3890be59cc8f18c1a);
#
#
#             var icon_0df9deac473ea0f754772cf499694ee8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quo

# %% [markdown]
# ## Berlin

# %%
#Berlin Geolocation
bern_lat = 52.5147951
bern_long = 13.3775787

# %%
#Map
bern_map_1 = Map(location=[bern_lat, bern_long], zoom_start=15)
bern_map_1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3b22ed27dea42212d8f0c3f87d308d7f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3b22ed27dea42212d8f0c3f87d308d7f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_3b22ed27dea42212d8f0c3f87d308d7f = L.map(
#                 &quot;map_3b22ed27dea42212d8f0c3f87d308d7f&quot;,
#                 {
#                     center: [52.5147951, 13.3775787],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bd28438dbab6bb16e6b3ee8a224b4357 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3b22ed27dea42212d8f0c3f87d308d7f);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#CSV Import: highval
bcn_highval_companies_clean= pd.read_csv("../data/bcn_highval_companies_clean.csv")

# %% [markdown]
# ## London

# %%
ldn_lat = 51.5037375
ldn_long = -0.1346877

# %%
ldn_map_1 = Map(location=[ldn_lat, ldn_long], zoom_start=15)
ldn_map_1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ce8d764ae209b9491ba6a258db48a264 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ce8d764ae209b9491ba6a258db48a264&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_ce8d764ae209b9491ba6a258db48a264 = L.map(
#                 &quot;map_ce8d764ae209b9491ba6a258db48a264&quot;,
#                 {
#                     center: [51.5037375, -0.1346877],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6978965c3c1cf702c327ffaca73e8636 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ce8d764ae209b9491ba6a258db48a264);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
