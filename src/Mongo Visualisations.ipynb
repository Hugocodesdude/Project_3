# %% [markdown]
# ## Preliminary City Viz

# %%
#Tools
import requests
from bs4 import BeautifulSoup
import pandas as pd
import requests
import re
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rcParams

# %%
import folium
from folium import Choropleth, Circle, Marker, Icon, Map
from folium.plugins import HeatMap, MarkerCluster
import pandas as pd

# %%
#CSV Import: highval
bcn_highval_companies_clean= pd.read_csv("../data/bcn_highval_companies_clean.csv")

# %%
#DataFrame
bcn_highval_companies_clean
# Out:
#         name                                            offices  \
# 0      eyeOS  [{'description': 'HQ', 'address1': 'La Rambla ...
# 1  Futurlink  [{'description': '', 'address1': 'Passeig de G...
# 2       vLex  [{'description': 'VLEX HQ (Barcelona)', 'addre...
# 3      Nuroa  [{'description': 'Offices', 'address1': 'Carre...
# 4     3scale  [{'description': '3scale SPAIN', 'address1': '...
# 5     3scale  [{'description': '3scale SPAIN', 'address1': '...
# 6  Openbravo  [{'description': 'Branch', 'address1': 'Pau Cl...
# 7    Teambox  [{'description': 'Barcelona Office', 'address1...
#
#            description              address1 address2 zip_code       city  \
# 0                   HQ      La Rambla 140 4C      NaN    08002  Barcelona
# 1                  NaN  Passeig de Gracia 49      NaN    08018  Barcelona
# 2  VLEX HQ (Barcelona)   Consell de Cent 334      NaN   E08009  Barcelona
# 3              Offices    Carrer de Bailen 7      NaN    08010  Barcelona
# 4         3scale SPAIN       C/Napols 187, 8      NaN    08013  Barcelona
# 5         3scale SPAIN       C/Napols 187, 8      NaN    08013  Barcelona
# 6               Branch        Pau Claris 138      NaN    08009  Barcelona
# 7     Barcelona Office  Ronda Universitat 31    5o 4a    08007  Barcelona
#
#   state_code country_code   latitude  longitude
# 0        NaN          ESP  41.385486   2.170287
# 1        NaN          ESP  41.396553   2.189241
# 2        NaN          ESP  41.392852   2.168021
# 3        NaN          ESP  41.391679   2.177571
# 4        NaN          ESP  41.406335   2.192023
# 5        NaN          ESP  41.406335   2.192023
# 6        NaN          ESP  41.393532   2.166078
# 7         CA          ESP  41.406335   2.192023

# %% [markdown]
# # Barcelona

# %%
#bcn geolocation 
barna_lat = 41.3898224
barna_long = 2.163367

# %%
#map
bcn_map_1 = Map(location=[barna_lat, barna_long], zoom_start=15)
bcn_map_1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0f6b4dc8483f4662b9e8c4811b64f5e9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0f6b4dc8483f4662b9e8c4811b64f5e9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_0f6b4dc8483f4662b9e8c4811b64f5e9 = L.map(
#                 &quot;map_0f6b4dc8483f4662b9e8c4811b64f5e9&quot;,
#                 {
#                     center: [41.3898224, 2.163367],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_36b28ded39357a6a5c143ead03bd8193 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0f6b4dc8483f4662b9e8c4811b64f5e9);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#highval companies loop
for index, row in bcn_highval_companies_clean.iterrows():
    #1. MARKER without icon
    district = {"location": [row["latitude"], row["longitude"]], "tooltip": row["name"]}
    icon = Icon (
            color="blue",
            opacity = 0.6,
            prefix = "fa",
            icon = "building-o",
            icon_color = "black",
            icon_size=(30, 30)
        )
    #3. Marker
    new_marker = Marker(**district, icon = icon, radius = 2)
    #4. Add the Marker
    new_marker.add_to(bcn_map_1)

# %%
#CSV Import: design
bcn_design_companies_clean= pd.read_csv("../data/bcn_design_companies_clean.csv")

# %%
#DataFrame
bcn_design_companies_clean
# Out:
#      name                                            offices   description  \
# 0  MEDDIA  [{'description': 'Headquarters', 'address1': '...  Headquarters
#
#            address1  address2  zip_code       city  state_code country_code  \
# 0  Av. Diagonal 237       NaN      8013  Barcelona         NaN          ESP
#
#     latitude  longitude
# 0  41.401809   2.181565

# %%
#Design companies loop
for index, row in bcn_design_companies_clean.iterrows():
    #1. MARKER without icon
    district = {"location": [row["latitude"], row["longitude"]], "tooltip": row["name"]}
    icon = Icon (
            color="red",
            opacity = 0.6,
            prefix = "fa",
            icon = "building-o",
            icon_color = "white",
            icon_size=(30, 30)
        )
    #3. Marker
    new_marker = Marker(**district, icon = icon, radius = 2)
    #4. Add the Marker
    new_marker.add_to(bcn_map_1)

# %%
#CSV Import: videogame
bcn_videogame_companies_clean= pd.read_csv("../data/bcn_videogame_companies_clean.csv")

# %%
#Video game companies loop
for index, row in bcn_videogame_companies_clean.iterrows():
    #1. MARKER without icon
    district = {"location": [row["latitude"], row["longitude"]], "tooltip": row["name"]}
    icon = Icon (
            color="green",
            opacity = 0.6,
            prefix = "fa",
            icon = "building-o",
            icon_color = "white",
            icon_size=(30, 30)
        )
    #3. Marker
    new_marker = Marker(**district, icon = icon, radius = 2)
    #4. Add the Marker
    new_marker.add_to(bcn_map_1)

# %%
#BCN Companies Map
bcn_map_1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0f6b4dc8483f4662b9e8c4811b64f5e9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0f6b4dc8483f4662b9e8c4811b64f5e9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_0f6b4dc8483f4662b9e8c4811b64f5e9 = L.map(
#                 &quot;map_0f6b4dc8483f4662b9e8c4811b64f5e9&quot;,
#                 {
#                     center: [41.3898224, 2.163367],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_36b28ded39357a6a5c143ead03bd8193 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0f6b4dc8483f4662b9e8c4811b64f5e9);
#
#
#             var marker_23fea4b180fd19c81d85b133c889ca1e = L.marker(
#                 [41.3854855, 2.1702872],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_0f6b4dc8483f4662b9e8c4811b64f5e9);
#
#
#             var icon_169819f31b8f321e10f15e4b4e639e89 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_23fea4b180fd19c81d85b133c889ca1e.setIcon(icon_169819f31b8f321e10f15e4b4e639e89);
#
#
#             marker_23fea4b180fd19c81d85b133c889ca1e.bindTooltip(
#                 `&lt;div&gt;
#                      eyeOS
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_dbf8d689b36a9cff9437a30fe0147637 = L.marker(
#                 [41.396553, 2.189241],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_0f6b4dc8483f4662b9e8c4811b64f5e9);
#
#
#             var icon_f5620d5da066e33ae737e153123b0b14 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_dbf8d689b36a9cff9437a30fe0147637.setIcon(icon_f5620d5da066e33ae737e153123b0b14);
#
#
#             marker_dbf8d689b36a9cff9437a30fe0147637.bindTooltip(
#                 `&lt;div&gt;
#                      Futurlink
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_8998d812479b663932ce197fac1335bb = L.marker(
#                 [41.392852, 2.168021],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_0f6b4dc8483f4662b9e8c4811b64f5e9);
#
#
#             var icon_3a6727c4625f54e21dd8331f65d28ae8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_8998d812479b663932ce197fac1335bb.setIcon(icon_3a6727c4625f54e21dd8331f65d28ae8);
#
#
#             marker_8998d812479b663932ce197fac1335bb.bindTooltip(
#                 `&lt;div&gt;
#                      vLex
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_c3b27a061fb861d0666405f87bcefc58 = L.marker(
#                 [41.3916792, 2.1775706],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_0f6b4dc8483f4662b9e8c4811b64f5e9);
#
#
#             var icon_efdfbbf932a1621fec4dea6f1959793d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_c3b27a061fb861d0666405f87bcefc58.setIcon(icon_efdfbbf932a1621fec4dea6f1959793d);
#
#
#             marker_c3b27a061fb861d0666405f87bcefc58.bindTooltip(
#                 `&lt;div&gt;
#                      Nuroa
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_ee84a88bc2637c71fd421366d3d03ce9 = L.marker(
#                 [41.406335, 2.192023],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_0f6b4dc8483f4662b9e8c4811b64f5e9);
#
#
#             var icon_84e8664c1e6bdc4fa62fbfa10d7e9fd7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quo

# %% [markdown]
# # Berlin

# %%
#Berlin Geolocation
bern_lat = 52.5147951
bern_long = 13.3775787

# %%
#Map
bln_map_1 = Map(location=[bern_lat, bern_long], zoom_start=15)
bln_map_1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_80e44fa6f594ecd374b6643ee073cb2d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_80e44fa6f594ecd374b6643ee073cb2d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_80e44fa6f594ecd374b6643ee073cb2d = L.map(
#                 &quot;map_80e44fa6f594ecd374b6643ee073cb2d&quot;,
#                 {
#                     center: [52.5147951, 13.3775787],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fc6c33a0cdbf7ffde1196d8da6fe9b0b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_80e44fa6f594ecd374b6643ee073cb2d);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#CSV Import: highval
bln_highval_companies_clean= pd.read_csv("../data/bln_highval_companies_clean.csv")

# %%
#highval companies loop
for index, row in bln_highval_companies_clean.iterrows():
    #1. MARKER without icon
    district = {"location": [row["latitude"], row["longitude"]], "tooltip": row["name"]}
    icon = Icon (
            color="blue",
            opacity = 0.6,
            prefix = "fa",
            icon = "building-o",
            icon_color = "black",
            icon_size=(30, 30)
        )
    #3. Marker
    new_marker = Marker(**district, icon = icon, radius = 2)
    #4. Add the Marker
    new_marker.add_to(bln_map_1)

# %%
#CSV Import: design
bln_design_companies_clean= pd.read_csv("../data/bln_design_companies_clean.csv")

# %%
#Design companies loop
for index, row in bln_design_companies_clean.iterrows():
    #1. MARKER without icon
    district = {"location": [row["latitude"], row["longitude"]], "tooltip": row["name"]}
    icon = Icon (
            color="red",
            opacity = 0.6,
            prefix = "fa",
            icon = "building-o",
            icon_color = "white",
            icon_size=(30, 30)
        )
    #3. Marker
    new_marker = Marker(**district, icon = icon, radius = 2)
    #4. Add the Marker
    new_marker.add_to(bln_map_1)

# %%
#CSV Import: videogame
bln_videogame_companies_clean= pd.read_csv("../data/bln_videogame_companies_clean.csv")

# %%
#Video game companies loop
for index, row in bln_videogame_companies_clean.iterrows():
    #1. MARKER without icon
    district = {"location": [row["latitude"], row["longitude"]], "tooltip": row["name"]}
    icon = Icon (
            color="green",
            opacity = 0.6,
            prefix = "fa",
            icon = "building-o",
            icon_color = "white",
            icon_size=(30, 30)
        )
    #3. Marker
    new_marker = Marker(**district, icon = icon, radius = 2)
    #4. Add the Marker
    new_marker.add_to(bln_map_1)

# %%
#BLN Companies Map
bln_map_1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_80e44fa6f594ecd374b6643ee073cb2d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_80e44fa6f594ecd374b6643ee073cb2d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_80e44fa6f594ecd374b6643ee073cb2d = L.map(
#                 &quot;map_80e44fa6f594ecd374b6643ee073cb2d&quot;,
#                 {
#                     center: [52.5147951, 13.3775787],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fc6c33a0cdbf7ffde1196d8da6fe9b0b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_80e44fa6f594ecd374b6643ee073cb2d);
#
#
#             var marker_2c07c729f69142481790f76471f4c5ae = L.marker(
#                 [52.523402, 13.398694],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_80e44fa6f594ecd374b6643ee073cb2d);
#
#
#             var icon_2d9497b3d0b25b3d752236e195df9ca3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_2c07c729f69142481790f76471f4c5ae.setIcon(icon_2d9497b3d0b25b3d752236e195df9ca3);
#
#
#             marker_2c07c729f69142481790f76471f4c5ae.bindTooltip(
#                 `&lt;div&gt;
#                      Plazes
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_b64ed0e543af881a193ab7e508ec7f50 = L.marker(
#                 [52.4897, 13.38861],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_80e44fa6f594ecd374b6643ee073cb2d);
#
#
#             var icon_0f322b56954ebd7d60e54f4321f76da9 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_b64ed0e543af881a193ab7e508ec7f50.setIcon(icon_0f322b56954ebd7d60e54f4321f76da9);
#
#
#             marker_b64ed0e543af881a193ab7e508ec7f50.bindTooltip(
#                 `&lt;div&gt;
#                      babbel
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_4a623ccd490e1441683253691edbc70a = L.marker(
#                 [52.512249, 13.419841],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_80e44fa6f594ecd374b6643ee073cb2d);
#
#
#             var icon_ec165360af014a0813d1b053c6fb33ce = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_4a623ccd490e1441683253691edbc70a.setIcon(icon_ec165360af014a0813d1b053c6fb33ce);
#
#
#             marker_4a623ccd490e1441683253691edbc70a.bindTooltip(
#                 `&lt;div&gt;
#                      Metaversum
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_ad463118af175ddbe773ec5fac542fa3 = L.marker(
#                 [52.52348, 13.411494],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_80e44fa6f594ecd374b6643ee073cb2d);
#
#
#             var icon_3cc5e0d06aea9447fa6e0f10e17c5353 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_ad463118af175ddbe773ec5fac542fa3.setIcon(icon_3cc5e0d06aea9447fa6e0f10e17c5353);
#
#
#             marker_ad463118af175ddbe773ec5fac542fa3.bindTooltip(
#                 `&lt;div&gt;
#                      gate5
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_545e56ba96f3c3a0d53fef103c26ecfe = L.marker(
#                 [52.5283614, 13.4124563],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_80e44fa6f594ecd374b6643ee073cb2d);
#
#
#             var icon_e9c75f45d889b1d6e723068242124d17 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;blac

# %% [markdown]
# ## London

# %%
ldn_lat = 51.5037375
ldn_long = -0.1346877

# %%
ldn_map_1 = Map(location=[ldn_lat, ldn_long], zoom_start=15)
ldn_map_1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_88e3b8cff1cb893d4b8332530acc6b73 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_88e3b8cff1cb893d4b8332530acc6b73&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_88e3b8cff1cb893d4b8332530acc6b73 = L.map(
#                 &quot;map_88e3b8cff1cb893d4b8332530acc6b73&quot;,
#                 {
#                     center: [51.5037375, -0.1346877],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_43c740d00d84638322710474320b7672 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_88e3b8cff1cb893d4b8332530acc6b73);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#CSV Import: highval
ldn_highval_companies_clean= pd.read_csv("../data/ldn_highval_companies_clean.csv")

# %%
#highval companies loop
for index, row in ldn_highval_companies_clean.iterrows():
    #1. MARKER without icon
    district = {"location": [row["latitude"], row["longitude"]], "tooltip": row["name"]}
    icon = Icon (
            color="blue",
            opacity = 0.6,
            prefix = "fa",
            icon = "building-o",
            icon_color = "black",
            icon_size=(30, 30)
        )
    #3. Marker
    new_marker = Marker(**district, icon = icon, radius = 2)
    #4. Add the Marker
    new_marker.add_to(ldn_map_1)

# %%
#CSV Import: design
ldn_design_companies_clean= pd.read_csv("../data/ldn_design_companies_clean.csv")

# %%
#Design companies loop
for index, row in ldn_design_companies_clean.iterrows():
    #1. MARKER without icon
    district = {"location": [row["latitude"], row["longitude"]], "tooltip": row["name"]}
    icon = Icon (
            color="red",
            opacity = 0.6,
            prefix = "fa",
            icon = "building-o",
            icon_color = "white",
            icon_size=(30, 30)
        )
    #3. Marker
    new_marker = Marker(**district, icon = icon, radius = 2)
    #4. Add the Marker
    new_marker.add_to(ldn_map_1)

# %%
#CSV Import: videogame
ldn_videogame_companies_clean= pd.read_csv("../data/ldn_videogame_companies_clean.csv")

# %%
ldn_videogame_companies_clean
# Out:
#                    name                                            offices  \
# 0              Babelgum  [{'description': '', 'address1': '', 'address2...
# 1              blinkbox  [{'description': None, 'address1': '20-24 Kirb...
# 2               idiomag  [{'description': None, 'address1': '', 'addres...
# 3              Playfish  [{'description': 'Corporate Headquarters', 'ad...
# 4                 Pikum  [{'description': None, 'address1': '7 Chalcot ...
# 5               Vigster  [{'description': 'London Office', 'address1': ...
# 6              Mixcloud  [{'description': 'Office', 'address1': 'Tabern...
# 7      Illumina Digital  [{'description': '8 Canham Mews', 'address1': ...
# 8              BeatPick  [{'description': 'London Office', 'address1': ...
# 9          CareerPlayer  [{'description': '', 'address1': '', 'address2...
# 10         Wazoo Sports  [{'description': '', 'address1': 'P.O. Box 328...
# 11       Kramaley Games  [{'description': 'London', 'address1': '12A Ec...
# 12         Filmed Media  [{'description': 'Head Office', 'address1': '5...
# 13             Spoonfed  [{'description': 'Spoonfed LDN', 'address1': '...
# 14              Swiffen  [{'description': 'London Office', 'address1': ...
# 15               Owngig  [{'description': 'Owngig.com', 'address1': '1&...
# 16           Bandstocks  [{'description': 'Civilian Industries PLC', 'a...
# 17  Keen Software House  [{'description': 'London Office', 'address1': ...
#
#                 description                address1           address2  \
# 0                       NaN                     NaN                NaN
# 1                       NaN      20-24 Kirby Street                NaN
# 2                       NaN                     NaN                NaN
# 3    Corporate Headquarters  125 Kensington High St             W8 5SF
# 4                       NaN          7 Chalcot Road                NaN
# 5             London Office                     NaN                NaN
# 6                    Office       Tabernacle Street                NaN
# 7             8 Canham Mews             Canham Road                NaN
# 8             London Office                     NaN                NaN
# 9                       NaN                     NaN                NaN
# 10                      NaN           P.O. Box 3289                NaN
# 11                   London    12A Eccleston Street        Westminster
# 12              Head Office       58 Salusbury Road        Queens Park
# 13             Spoonfed LDN               Studio 16  14 Southgate Road
# 14            London Office   114, St. Martins Lane                NaN
# 15               Owngig.com       1&2 Barley Shotts    246 Acklam Road
# 16  Civilian Industries PLC       17 Shorts Gardens      Covent Garden
# 17            London Office  145-157 St John Street                NaN
#
#     zip_code    city state_code country_code   latitude  longitude
# 0        NaN  London        NaN          GBR  53.344104  -6.267494
# 1   EC1N 8TS  London        NaN          GBR  51.520779  -0.107590
# 2        NaN  London        NaN          GBR  51.500152  -0.126236
# 3     London  London        NaN          GBR  51.499109  -0.198480
# 4    Nw1 8lh  London        NaN          GBR  51.539778  -0.152998
# 5        NaN  London        NaN          GBR  51.500152  -0.126236
# 6        NaN  London        NaN          GBR  51.539910  -0.285979
# 7     W3 7SR  London        NaN          GBR  51.503612  -0.256280
# 8        NaN  London        NaN          GBR  51.500152  -0.126236
# 9        NaN  London        NaN          GBR  51.500152  -0.126236
# 10     40743  London         KY          USA  37.128600 -84.083400
# 11  SW1W 9LT  London        NaN          GBR  51.494500  -0.147932
# 12   NW6 6NP  London        NaN          GBR  51.535901  -0.205508
# 13    N1 3LY  London        NaN          GBR  51.757745  -1.218672
# 14   WC2N4BE  London        NaN          GBR  51.516338  -0.082817
# 15   W10 5YG  London        NaN          GBR  39.396150  22.763030
# 16  WC2H 9AT  London        NaN          GBR  51.514213  -0.126185
# 17  EC1V 4PY  London        NaN          GBR  51.522076  -0.115300

# %%
#Video game companies loop
for index, row in ldn_videogame_companies_clean.iterrows():
    #1. MARKER without icon
    district = {"location": [row["latitude"], row["longitude"]], "tooltip": row["name"]}
    icon = Icon (
            color="green",
            opacity = 0.6,
            prefix = "fa",
            icon = "building-o",
            icon_color = "white",
            icon_size=(30, 30)
        )
    #3. Marker
    new_marker = Marker(**district, icon = icon, radius = 2)
    #4. Add the Marker
    new_marker.add_to(ldn_map_1)

# %%
ldn_map_1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_88e3b8cff1cb893d4b8332530acc6b73 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_88e3b8cff1cb893d4b8332530acc6b73&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_88e3b8cff1cb893d4b8332530acc6b73 = L.map(
#                 &quot;map_88e3b8cff1cb893d4b8332530acc6b73&quot;,
#                 {
#                     center: [51.5037375, -0.1346877],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_43c740d00d84638322710474320b7672 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_88e3b8cff1cb893d4b8332530acc6b73);
#
#
#             var marker_7ec92eea075c99f72e52028870ff39a6 = L.marker(
#                 [53.344104, -6.267494],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_88e3b8cff1cb893d4b8332530acc6b73);
#
#
#             var icon_c83f6a3956c44425fbd980772525fc21 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_7ec92eea075c99f72e52028870ff39a6.setIcon(icon_c83f6a3956c44425fbd980772525fc21);
#
#
#             marker_7ec92eea075c99f72e52028870ff39a6.bindTooltip(
#                 `&lt;div&gt;
#                      Babelgum
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_8ecab4aad2d3b8083f10e2372aee76ae = L.marker(
#                 [37.09024, -95.712891],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_88e3b8cff1cb893d4b8332530acc6b73);
#
#
#             var icon_b8a3fb9e8f3d5c61e07225c03b486b31 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_8ecab4aad2d3b8083f10e2372aee76ae.setIcon(icon_b8a3fb9e8f3d5c61e07225c03b486b31);
#
#
#             marker_8ecab4aad2d3b8083f10e2372aee76ae.bindTooltip(
#                 `&lt;div&gt;
#                      Kelkoo
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_aac75f5361d7dbcae34c863e90114d18 = L.marker(
#                 [41.53155, -72.188584],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_88e3b8cff1cb893d4b8332530acc6b73);
#
#
#             var icon_a4702768882b820b5ec53d871c07aa67 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_aac75f5361d7dbcae34c863e90114d18.setIcon(icon_a4702768882b820b5ec53d871c07aa67);
#
#
#             marker_aac75f5361d7dbcae34c863e90114d18.bindTooltip(
#                 `&lt;div&gt;
#                      ReachLocal
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_baaebed39f447b1beccb321745a1bb52 = L.marker(
#                 [51.5108803, -0.1418973],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_88e3b8cff1cb893d4b8332530acc6b73);
#
#
#             var icon_d3bd7e846f1edc87b94ec3f25b09fafb = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_baaebed39f447b1beccb321745a1bb52.setIcon(icon_d3bd7e846f1edc87b94ec3f25b09fafb);
#
#
#             marker_baaebed39f447b1beccb321745a1bb52.bindTooltip(
#                 `&lt;div&gt;
#                      Seedcamp
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_afe1d93040c1683e0ec81807c0819924 = L.marker(
#                 [51.5192042, -0.1626103],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_88e3b8cff1cb893d4b8332530acc6b73);
#
#
#             var icon_1c46ed3a3291c8b1c86e07beb8b2a2e2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;:
