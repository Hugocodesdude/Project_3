# %% [markdown]
# ## Preliminary City Viz

# %%
#Tools
import requests
from bs4 import BeautifulSoup
import pandas as pd
import requests
import re
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rcParams

# %%
import folium
from folium import Choropleth, Circle, Marker, Icon, Map
from folium.plugins import HeatMap, MarkerCluster
import pandas as pd

# %%
import os
import requests
import json
from dotenv import load_dotenv
import pandas as pd

# %%
#CSV Import: highval
bcn_highval_companies_clean= pd.read_csv("../data/bcn_highval_companies_clean.csv")

# %%
#DataFrame
bcn_highval_companies_clean
# Out:
#         name                                            offices  \
# 0      eyeOS  [{'description': 'HQ', 'address1': 'La Rambla ...
# 1  Futurlink  [{'description': '', 'address1': 'Passeig de G...
# 2       vLex  [{'description': 'VLEX HQ (Barcelona)', 'addre...
# 3      Nuroa  [{'description': 'Offices', 'address1': 'Carre...
# 4     3scale  [{'description': '3scale SPAIN', 'address1': '...
# 5     3scale  [{'description': '3scale SPAIN', 'address1': '...
# 6  Openbravo  [{'description': 'Branch', 'address1': 'Pau Cl...
# 7    Teambox  [{'description': 'Barcelona Office', 'address1...
#
#            description              address1 address2 zip_code       city  \
# 0                   HQ      La Rambla 140 4C      NaN    08002  Barcelona
# 1                  NaN  Passeig de Gracia 49      NaN    08018  Barcelona
# 2  VLEX HQ (Barcelona)   Consell de Cent 334      NaN   E08009  Barcelona
# 3              Offices    Carrer de Bailen 7      NaN    08010  Barcelona
# 4         3scale SPAIN       C/Napols 187, 8      NaN    08013  Barcelona
# 5         3scale SPAIN       C/Napols 187, 8      NaN    08013  Barcelona
# 6               Branch        Pau Claris 138      NaN    08009  Barcelona
# 7     Barcelona Office  Ronda Universitat 31    5o 4a    08007  Barcelona
#
#   state_code country_code   latitude  longitude
# 0        NaN          ESP  41.385486   2.170287
# 1        NaN          ESP  41.396553   2.189241
# 2        NaN          ESP  41.392852   2.168021
# 3        NaN          ESP  41.391679   2.177571
# 4        NaN          ESP  41.406335   2.192023
# 5        NaN          ESP  41.406335   2.192023
# 6        NaN          ESP  41.393532   2.166078
# 7         CA          ESP  41.406335   2.192023

# %% [markdown]
# # Barcelona

# %%
#bcn geolocation 
barna_lat = 41.3898224
barna_long = 2.163367

# %%
#map
bcn_map_1 = Map(location=[barna_lat, barna_long], zoom_start=15)
bcn_map_1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1c7751833034494e122f6e041a144b2c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1c7751833034494e122f6e041a144b2c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_1c7751833034494e122f6e041a144b2c = L.map(
#                 &quot;map_1c7751833034494e122f6e041a144b2c&quot;,
#                 {
#                     center: [41.3898224, 2.163367],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5b2589963e8ef719d193a3a42a0f04c8 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1c7751833034494e122f6e041a144b2c);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#highval companies loop
for index, row in bcn_highval_companies_clean.iterrows():
    #1. MARKER without icon
    district = {"location": [row["latitude"], row["longitude"]], "tooltip": row["name"]}
    icon = Icon (
            color="blue",
            opacity = 0.6,
            prefix = "fa",
            icon = "briefcase",
            icon_color = "white",
            icon_size=(30, 30)
        )
    #3. Marker
    new_marker = Marker(**district, icon = icon, radius = 2)
    #4. Add the Marker
    new_marker.add_to(bcn_map_1)

# %%
#CSV Import: design
bcn_design_companies_clean= pd.read_csv("../data/bcn_design_companies_clean.csv")

# %%
#DataFrame
bcn_design_companies_clean
# Out:
#      name                                            offices   description  \
# 0  MEDDIA  [{'description': 'Headquarters', 'address1': '...  Headquarters
#
#            address1  address2  zip_code       city  state_code country_code  \
# 0  Av. Diagonal 237       NaN      8013  Barcelona         NaN          ESP
#
#     latitude  longitude
# 0  41.401809   2.181565

# %%
#Design companies loop
for index, row in bcn_design_companies_clean.iterrows():
    #1. MARKER without icon
    district = {"location": [row["latitude"], row["longitude"]], "tooltip": row["name"]}
    icon = Icon (
            color="red",
            opacity = 0.6,
            prefix = "fa",
            icon = "desktop",
            icon_color = "white",
            icon_size=(30, 30)
        )
    #3. Marker
    new_marker = Marker(**district, icon = icon, radius = 2)
    #4. Add the Marker
    new_marker.add_to(bcn_map_1)

# %%
#CSV Import: videogame
bcn_videogame_companies_clean= pd.read_csv("../data/bcn_videogame_companies_clean.csv")

# %%
#Video game companies loop
for index, row in bcn_videogame_companies_clean.iterrows():
    #1. MARKER without icon
    district = {"location": [row["latitude"], row["longitude"]], "tooltip": row["name"]}
    icon = Icon (
            color="pink",
            opacity = 1,
            prefix = "fa",
            icon = "gamepad",
            icon_color = "white",
            icon_size=(30, 30)
        )
    #3. Marker
    new_marker = Marker(**district, icon = icon, radius = 2)
    #4. Add the Marker
    new_marker.add_to(bcn_map_1)

# %%
#BCN Companies Map
bcn_map_1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1c7751833034494e122f6e041a144b2c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1c7751833034494e122f6e041a144b2c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_1c7751833034494e122f6e041a144b2c = L.map(
#                 &quot;map_1c7751833034494e122f6e041a144b2c&quot;,
#                 {
#                     center: [41.3898224, 2.163367],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5b2589963e8ef719d193a3a42a0f04c8 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1c7751833034494e122f6e041a144b2c);
#
#
#             var marker_11a24e3566bc7041e3ce42f19d84df9c = L.marker(
#                 [41.3854855, 2.1702872],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_1c7751833034494e122f6e041a144b2c);
#
#
#             var icon_a43bba29fcde0926ecd03e3e1674b3df = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_11a24e3566bc7041e3ce42f19d84df9c.setIcon(icon_a43bba29fcde0926ecd03e3e1674b3df);
#
#
#             marker_11a24e3566bc7041e3ce42f19d84df9c.bindTooltip(
#                 `&lt;div&gt;
#                      eyeOS
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_63da76f5868f2fe77e24eed54fa7fd7d = L.marker(
#                 [41.396553, 2.189241],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_1c7751833034494e122f6e041a144b2c);
#
#
#             var icon_94010287d78b4a671e551f46cd82f4c7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_63da76f5868f2fe77e24eed54fa7fd7d.setIcon(icon_94010287d78b4a671e551f46cd82f4c7);
#
#
#             marker_63da76f5868f2fe77e24eed54fa7fd7d.bindTooltip(
#                 `&lt;div&gt;
#                      Futurlink
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_ec8bfe147e21dde388c28b4b09e4c42d = L.marker(
#                 [41.392852, 2.168021],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_1c7751833034494e122f6e041a144b2c);
#
#
#             var icon_78e5d51307c0897cc44ac718e2410c6c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_ec8bfe147e21dde388c28b4b09e4c42d.setIcon(icon_78e5d51307c0897cc44ac718e2410c6c);
#
#
#             marker_ec8bfe147e21dde388c28b4b09e4c42d.bindTooltip(
#                 `&lt;div&gt;
#                      vLex
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_9c5978124108cf8c3e327f5883a0d6c3 = L.marker(
#                 [41.3916792, 2.1775706],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_1c7751833034494e122f6e041a144b2c);
#
#
#             var icon_5b50d515979bed0912f1c4d4de9aa742 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_9c5978124108cf8c3e327f5883a0d6c3.setIcon(icon_5b50d515979bed0912f1c4d4de9aa742);
#
#
#             marker_9c5978124108cf8c3e327f5883a0d6c3.bindTooltip(
#                 `&lt;div&gt;
#                      Nuroa
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_52fdd87f043e13ac1321789ff0a6d8dc = L.marker(
#                 [41.406335, 2.192023],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_1c7751833034494e122f6e041a144b2c);
#
#
#             var icon_ae6218d71ffabc3ccb99ade5f455f8b3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quo

# %%
bcn_map_1.save('bcn_map_1.html')

# %% [markdown]
# # Berlin

# %%
#Berlin Geolocation
bern_lat = 52.5147951
bern_long = 13.3775787

# %%
#Map
bln_map_1 = Map(location=[bern_lat, bern_long], zoom_start=15)
bln_map_1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fe120040b155e0a12133908d8286b2c4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fe120040b155e0a12133908d8286b2c4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_fe120040b155e0a12133908d8286b2c4 = L.map(
#                 &quot;map_fe120040b155e0a12133908d8286b2c4&quot;,
#                 {
#                     center: [52.5147951, 13.3775787],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_92be951bd9eacd5ba2c1bf326854e466 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_fe120040b155e0a12133908d8286b2c4);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#CSV Import: highval
bln_highval_companies_clean= pd.read_csv("../data/bln_highval_companies_clean.csv")

# %%
#highval companies loop
for index, row in bln_highval_companies_clean.iterrows():
    #1. MARKER without icon
    district = {"location": [row["latitude"], row["longitude"]], "tooltip": row["name"]}
    icon = Icon (
            color="blue",
            opacity = 0.6,
            prefix = "fa",
            icon = "briefcase",
            icon_color = "white",
            icon_size=(30, 30)
        )
    #3. Marker
    new_marker = Marker(**district, icon = icon, radius = 2)
    #4. Add the Marker
    new_marker.add_to(bln_map_1)

# %%
#CSV Import: design
bln_design_companies_clean= pd.read_csv("../data/bln_design_companies_clean.csv")

# %%
#Design companies loop
for index, row in bln_design_companies_clean.iterrows():
    #1. MARKER without icon
    district = {"location": [row["latitude"], row["longitude"]], "tooltip": row["name"]}
    icon = Icon (
            color="red",
            opacity = 0.6,
            prefix = "fa",
            icon = "desktop",
            icon_color = "white",
            icon_size=(30, 30)
        )
    #3. Marker
    new_marker = Marker(**district, icon = icon, radius = 2)
    #4. Add the Marker
    new_marker.add_to(bln_map_1)

# %%
#CSV Import: videogame
bln_videogame_companies_clean= pd.read_csv("../data/bln_videogame_companies_clean.csv")

# %%
#Video game companies loop
for index, row in bln_videogame_companies_clean.iterrows():
    #1. MARKER without icon
    district = {"location": [row["latitude"], row["longitude"]], "tooltip": row["name"]}
    icon = Icon (
            color="pink",
            opacity = 0.6,
            prefix = "fa",
            icon = "gamepad",
            icon_color = "white",
            icon_size=(30, 30)
        )
    #3. Marker
    new_marker = Marker(**district, icon = icon, radius = 2)
    #4. Add the Marker
    new_marker.add_to(bln_map_1)

# %%
#BLN Companies Map
bln_map_1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fe120040b155e0a12133908d8286b2c4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fe120040b155e0a12133908d8286b2c4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_fe120040b155e0a12133908d8286b2c4 = L.map(
#                 &quot;map_fe120040b155e0a12133908d8286b2c4&quot;,
#                 {
#                     center: [52.5147951, 13.3775787],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_92be951bd9eacd5ba2c1bf326854e466 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_fe120040b155e0a12133908d8286b2c4);
#
#
#             var marker_d332845fafadcc677c52ba222da6cd91 = L.marker(
#                 [52.523402, 13.398694],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_fe120040b155e0a12133908d8286b2c4);
#
#
#             var icon_c69e87027a1575390917c21e7ea3d66b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_d332845fafadcc677c52ba222da6cd91.setIcon(icon_c69e87027a1575390917c21e7ea3d66b);
#
#
#             marker_d332845fafadcc677c52ba222da6cd91.bindTooltip(
#                 `&lt;div&gt;
#                      Plazes
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_601a0cfc5c9aec7dddb9cc71f0b662c4 = L.marker(
#                 [52.4897, 13.38861],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_fe120040b155e0a12133908d8286b2c4);
#
#
#             var icon_5bfbe5cb83acd0dc905338c9c647b4ba = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_601a0cfc5c9aec7dddb9cc71f0b662c4.setIcon(icon_5bfbe5cb83acd0dc905338c9c647b4ba);
#
#
#             marker_601a0cfc5c9aec7dddb9cc71f0b662c4.bindTooltip(
#                 `&lt;div&gt;
#                      babbel
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_cfe69a3b76c19efd099f53988291f90e = L.marker(
#                 [52.512249, 13.419841],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_fe120040b155e0a12133908d8286b2c4);
#
#
#             var icon_fe5f5d7c28987a9f732a141e3cff6a62 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_cfe69a3b76c19efd099f53988291f90e.setIcon(icon_fe5f5d7c28987a9f732a141e3cff6a62);
#
#
#             marker_cfe69a3b76c19efd099f53988291f90e.bindTooltip(
#                 `&lt;div&gt;
#                      Metaversum
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_7ac6b166a24cdf91554dd681a4f1cb15 = L.marker(
#                 [52.52348, 13.411494],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_fe120040b155e0a12133908d8286b2c4);
#
#
#             var icon_effd74d79d925ddedcd5d22715ac4335 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_7ac6b166a24cdf91554dd681a4f1cb15.setIcon(icon_effd74d79d925ddedcd5d22715ac4335);
#
#
#             marker_7ac6b166a24cdf91554dd681a4f1cb15.bindTooltip(
#                 `&lt;div&gt;
#                      gate5
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_ded9ff1c94fbf77a19e7f59f232c2a2a = L.marker(
#                 [52.5283614, 13.4124563],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_fe120040b155e0a12133908d8286b2c4);
#
#
#             var icon_6f417dfc5056503be57ba442140f8fbf = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;blac

# %%
bln_map_1.save('bln_map_1.html')

# %% [markdown]
# ## London

# %%
ldn_lat = 51.5037375
ldn_long = -0.1346877

# %%
ldn_map_1 = Map(location=[ldn_lat, ldn_long], zoom_start=15)
ldn_map_1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5066b73b7074fb6f51d693ee76d7bd45 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5066b73b7074fb6f51d693ee76d7bd45&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_5066b73b7074fb6f51d693ee76d7bd45 = L.map(
#                 &quot;map_5066b73b7074fb6f51d693ee76d7bd45&quot;,
#                 {
#                     center: [51.5037375, -0.1346877],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7a13c78b1236dc0f8324f96d9ce6fd25 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5066b73b7074fb6f51d693ee76d7bd45);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#CSV Import: highval
ldn_highval_companies_clean= pd.read_csv("../data/ldn_highval_companies_clean.csv")

# %%
#highval companies loop
for index, row in ldn_highval_companies_clean.iterrows():
    #1. MARKER without icon
    district = {"location": [row["latitude"], row["longitude"]], "tooltip": row["name"]}
    icon = Icon (
            color="blue",
            opacity = 0.6,
            prefix = "fa",
            icon = "briefcase",
            icon_color = "white",
            icon_size=(30, 30)
        )
    #3. Marker
    new_marker = Marker(**district, icon = icon, radius = 2)
    #4. Add the Marker
    new_marker.add_to(ldn_map_1)

# %%
#CSV Import: design
ldn_design_companies_clean= pd.read_csv("../data/ldn_design_companies_clean.csv")

# %%
#Design companies loop
for index, row in ldn_design_companies_clean.iterrows():
    #1. MARKER without icon
    district = {"location": [row["latitude"], row["longitude"]], "tooltip": row["name"]}
    icon = Icon (
            color="red",
            opacity = 0.6,
            prefix = "fa",
            icon = "desktop",
            icon_color = "white",
            icon_size=(30, 30)
        )
    #3. Marker
    new_marker = Marker(**district, icon = icon, radius = 2)
    #4. Add the Marker
    new_marker.add_to(ldn_map_1)

# %%
#CSV Import: videogame
ldn_videogame_companies_clean= pd.read_csv("../data/ldn_videogame_companies_clean.csv")

# %%
ldn_videogame_companies_clean
# Out:
#                    name                                            offices  \
# 0              Babelgum  [{'description': '', 'address1': '', 'address2...
# 1              blinkbox  [{'description': None, 'address1': '20-24 Kirb...
# 2               idiomag  [{'description': None, 'address1': '', 'addres...
# 3              Playfish  [{'description': 'Corporate Headquarters', 'ad...
# 4                 Pikum  [{'description': None, 'address1': '7 Chalcot ...
# 5               Vigster  [{'description': 'London Office', 'address1': ...
# 6              Mixcloud  [{'description': 'Office', 'address1': 'Tabern...
# 7      Illumina Digital  [{'description': '8 Canham Mews', 'address1': ...
# 8              BeatPick  [{'description': 'London Office', 'address1': ...
# 9          CareerPlayer  [{'description': '', 'address1': '', 'address2...
# 10         Wazoo Sports  [{'description': '', 'address1': 'P.O. Box 328...
# 11       Kramaley Games  [{'description': 'London', 'address1': '12A Ec...
# 12         Filmed Media  [{'description': 'Head Office', 'address1': '5...
# 13             Spoonfed  [{'description': 'Spoonfed LDN', 'address1': '...
# 14              Swiffen  [{'description': 'London Office', 'address1': ...
# 15               Owngig  [{'description': 'Owngig.com', 'address1': '1&...
# 16           Bandstocks  [{'description': 'Civilian Industries PLC', 'a...
# 17  Keen Software House  [{'description': 'London Office', 'address1': ...
#
#                 description                address1           address2  \
# 0                       NaN                     NaN                NaN
# 1                       NaN      20-24 Kirby Street                NaN
# 2                       NaN                     NaN                NaN
# 3    Corporate Headquarters  125 Kensington High St             W8 5SF
# 4                       NaN          7 Chalcot Road                NaN
# 5             London Office                     NaN                NaN
# 6                    Office       Tabernacle Street                NaN
# 7             8 Canham Mews             Canham Road                NaN
# 8             London Office                     NaN                NaN
# 9                       NaN                     NaN                NaN
# 10                      NaN           P.O. Box 3289                NaN
# 11                   London    12A Eccleston Street        Westminster
# 12              Head Office       58 Salusbury Road        Queens Park
# 13             Spoonfed LDN               Studio 16  14 Southgate Road
# 14            London Office   114, St. Martins Lane                NaN
# 15               Owngig.com       1&2 Barley Shotts    246 Acklam Road
# 16  Civilian Industries PLC       17 Shorts Gardens      Covent Garden
# 17            London Office  145-157 St John Street                NaN
#
#     zip_code    city state_code country_code   latitude  longitude
# 0        NaN  London        NaN          GBR  53.344104  -6.267494
# 1   EC1N 8TS  London        NaN          GBR  51.520779  -0.107590
# 2        NaN  London        NaN          GBR  51.500152  -0.126236
# 3     London  London        NaN          GBR  51.499109  -0.198480
# 4    Nw1 8lh  London        NaN          GBR  51.539778  -0.152998
# 5        NaN  London        NaN          GBR  51.500152  -0.126236
# 6        NaN  London        NaN          GBR  51.539910  -0.285979
# 7     W3 7SR  London        NaN          GBR  51.503612  -0.256280
# 8        NaN  London        NaN          GBR  51.500152  -0.126236
# 9        NaN  London        NaN          GBR  51.500152  -0.126236
# 10     40743  London         KY          USA  37.128600 -84.083400
# 11  SW1W 9LT  London        NaN          GBR  51.494500  -0.147932
# 12   NW6 6NP  London        NaN          GBR  51.535901  -0.205508
# 13    N1 3LY  London        NaN          GBR  51.757745  -1.218672
# 14   WC2N4BE  London        NaN          GBR  51.516338  -0.082817
# 15   W10 5YG  London        NaN          GBR  39.396150  22.763030
# 16  WC2H 9AT  London        NaN          GBR  51.514213  -0.126185
# 17  EC1V 4PY  London        NaN          GBR  51.522076  -0.115300

# %%
#Video game companies loop
for index, row in ldn_videogame_companies_clean.iterrows():
    #1. MARKER without icon
    district = {"location": [row["latitude"], row["longitude"]], "tooltip": row["name"]}
    icon = Icon (
            color="pink",
            opacity = 0.6,
            prefix = "fa",
            icon = "gamepad",
            icon_color = "white",
            icon_size=(30, 30)
        )
    #3. Marker
    new_marker = Marker(**district, icon = icon, radius = 2)
    #4. Add the Marker
    new_marker.add_to(ldn_map_1)

# %%
ldn_map_1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5066b73b7074fb6f51d693ee76d7bd45 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5066b73b7074fb6f51d693ee76d7bd45&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_5066b73b7074fb6f51d693ee76d7bd45 = L.map(
#                 &quot;map_5066b73b7074fb6f51d693ee76d7bd45&quot;,
#                 {
#                     center: [51.5037375, -0.1346877],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7a13c78b1236dc0f8324f96d9ce6fd25 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5066b73b7074fb6f51d693ee76d7bd45);
#
#
#             var marker_fa62d17c87474588eb292f736540c0ec = L.marker(
#                 [53.344104, -6.267494],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_5066b73b7074fb6f51d693ee76d7bd45);
#
#
#             var icon_a6eb60e051d06dafb8c61eb8e678a860 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_fa62d17c87474588eb292f736540c0ec.setIcon(icon_a6eb60e051d06dafb8c61eb8e678a860);
#
#
#             marker_fa62d17c87474588eb292f736540c0ec.bindTooltip(
#                 `&lt;div&gt;
#                      Babelgum
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_5be41a7bbc29964c8b1a8d23b6a3e15e = L.marker(
#                 [37.09024, -95.712891],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_5066b73b7074fb6f51d693ee76d7bd45);
#
#
#             var icon_563444affedb1f9be534bc0432fb1eca = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_5be41a7bbc29964c8b1a8d23b6a3e15e.setIcon(icon_563444affedb1f9be534bc0432fb1eca);
#
#
#             marker_5be41a7bbc29964c8b1a8d23b6a3e15e.bindTooltip(
#                 `&lt;div&gt;
#                      Kelkoo
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_c47262103744112d3807ab71f39d85b1 = L.marker(
#                 [41.53155, -72.188584],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_5066b73b7074fb6f51d693ee76d7bd45);
#
#
#             var icon_c337d7fae318cb74652cdc64fed56e22 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_c47262103744112d3807ab71f39d85b1.setIcon(icon_c337d7fae318cb74652cdc64fed56e22);
#
#
#             marker_c47262103744112d3807ab71f39d85b1.bindTooltip(
#                 `&lt;div&gt;
#                      ReachLocal
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_00a7e0d7de0fe6eae8468cef8b8fa6d3 = L.marker(
#                 [51.5108803, -0.1418973],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_5066b73b7074fb6f51d693ee76d7bd45);
#
#
#             var icon_166d8e77f6b54592d4812a5f7a4860a1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_00a7e0d7de0fe6eae8468cef8b8fa6d3.setIcon(icon_166d8e77f6b54592d4812a5f7a4860a1);
#
#
#             marker_00a7e0d7de0fe6eae8468cef8b8fa6d3.bindTooltip(
#                 `&lt;div&gt;
#                      Seedcamp
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_3fc3bec577b00f0cb08b2a9f0f7b2f07 = L.marker(
#                 [51.5192042, -0.1626103],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_5066b73b7074fb6f51d693ee76d7bd45);
#
#
#             var icon_a1bb6511c2f9ac6e6e9f2a3c91523103 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;:

# %%
ldn_map_1.save('ldn_map_1.html')

# %% [markdown]
# # FourSquare APIs

# %% [markdown]
# ## Vegan BCN

# %%
load_dotenv()
# Out:
# True

# %%
token_fsq = os.getenv("token_foursquare")

# %%
# Copy and paste from example from website

vegan_bcn_url = "https://api.foursquare.com/v3/places/search?ll=41.3898224%2C2.163367&categories=13377"

headers = {
    "accept": "application/json",
    "Authorization": "fsq3ziQGzWOXPwEcMzd/Rtxo+uQG864OuLbWTFrbzs4E/+U="
}



vegan_bcn_response = requests.get(vegan_bcn_url, headers=headers).json()

# %%
#vegan_bcn_list loop
vegan_bcn_list = []
for i in vegan_bcn_response ["results"]:
    
    name = i["name"]
    address =  i["location"]["formatted_address"]
    lat = i["geocodes"]["main"]["latitude"]
    lon = i["geocodes"]["main"]["longitude"]
        
    type_ = {"typepoint": 
                          {"type": "Point", 
                           "coordinates": [lat, lon]}}
    
    vegan_bcn_list.append({"name":name, "lat":lat, "lon":lon, "type":type_})
    
vegan_bcn_list
# Out:
# [{'name': 'A Tu Bola',
#   'lat': 41.380092,
#   'lon': 2.168815,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [41.380092, 2.168815]}}},
#  {'name': 'Maoz Vegetarian',
#   'lat': 41.380911,
#   'lon': 2.174652,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [41.380911, 2.174652]}}},
#  {'name': 'Quinoa Bar Vegetarià',
#   'lat': 41.402766,
#   'lon': 2.159899,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [41.402766, 2.159899]}}},
#  {'name': 'La Papa',
#   'lat': 41.389798,
#   'lon': 2.157615,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [41.389798, 2.157615]}}},
#  {'name': 'Teresa Carles',
#   'lat': 41.385039,
#   'lon': 2.167858,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [41.385039, 2.167858]}}},
#  {'name': 'Menssana',
#   'lat': 41.390787,
#   'lon': 2.190208,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [41.390787, 2.190208]}}},
#  {'name': 'La Cerería',
#   'lat': 41.381564,
#   'lon': 2.176641,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [41.381564, 2.176641]}}},
#  {'name': 'Federal',
#   'lat': 41.378062,
#   'lon': 2.177878,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [41.378062, 2.177878]}}},
#  {'name': 'Flax & Kale',
#   'lat': 41.385204,
#   'lon': 2.165382,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [41.385204, 2.165382]}}},
#  {'name': 'Green Spot',
#   'lat': 41.381781,
#   'lon': 2.183982,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [41.381781, 2.183982]}}}]

# %%
#Into DataFrame
vegan_bcn_df = pd.DataFrame(vegan_bcn_list)

# %%
vegan_bcn_df
# Out:
#                    name        lat       lon  \
# 0             A Tu Bola  41.380092  2.168815
# 1       Maoz Vegetarian  41.380911  2.174652
# 2  Quinoa Bar Vegetarià  41.402766  2.159899
# 3               La Papa  41.389798  2.157615
# 4         Teresa Carles  41.385039  2.167858
# 5              Menssana  41.390787  2.190208
# 6            La Cerería  41.381564  2.176641
# 7               Federal  41.378062  2.177878
# 8           Flax & Kale  41.385204  2.165382
# 9            Green Spot  41.381781  2.183982
#
#                                                 type
# 0  {'typepoint': {'type': 'Point', 'coordinates':...
# 1  {'typepoint': {'type': 'Point', 'coordinates':...
# 2  {'typepoint': {'type': 'Point', 'coordinates':...
# 3  {'typepoint': {'type': 'Point', 'coordinates':...
# 4  {'typepoint': {'type': 'Point', 'coordinates':...
# 5  {'typepoint': {'type': 'Point', 'coordinates':...
# 6  {'typepoint': {'type': 'Point', 'coordinates':...
# 7  {'typepoint': {'type': 'Point', 'coordinates':...
# 8  {'typepoint': {'type': 'Point', 'coordinates':...
# 9  {'typepoint': {'type': 'Point', 'coordinates':...

# %%
#Save DF
vegan_bcn_df.to_csv("../data/vegan_bcn_df.csv", index=False)

# %%
#Vegan BCN Marker Loop
for index, row in vegan_bcn_df.iterrows():
    #1. MARKER without icon
    district = {"location": [row["lat"], row["lon"]], "tooltip": row["name"]}
    icon = Icon (
            color="green",
            opacity = 0.2,
            prefix = "fa",
            icon = "leaf",
            icon_color = "white",
            icon_size=(30, 30)
        )
    #3. Marker
    new_marker = Marker(**district, icon = icon, radius = 2)
    #4. Add the Marker
    new_marker.add_to(bcn_map_1)

# %%
bcn_map_1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1c7751833034494e122f6e041a144b2c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1c7751833034494e122f6e041a144b2c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_1c7751833034494e122f6e041a144b2c = L.map(
#                 &quot;map_1c7751833034494e122f6e041a144b2c&quot;,
#                 {
#                     center: [41.3898224, 2.163367],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5b2589963e8ef719d193a3a42a0f04c8 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1c7751833034494e122f6e041a144b2c);
#
#
#             var marker_11a24e3566bc7041e3ce42f19d84df9c = L.marker(
#                 [41.3854855, 2.1702872],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_1c7751833034494e122f6e041a144b2c);
#
#
#             var icon_a43bba29fcde0926ecd03e3e1674b3df = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_11a24e3566bc7041e3ce42f19d84df9c.setIcon(icon_a43bba29fcde0926ecd03e3e1674b3df);
#
#
#             marker_11a24e3566bc7041e3ce42f19d84df9c.bindTooltip(
#                 `&lt;div&gt;
#                      eyeOS
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_63da76f5868f2fe77e24eed54fa7fd7d = L.marker(
#                 [41.396553, 2.189241],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_1c7751833034494e122f6e041a144b2c);
#
#
#             var icon_94010287d78b4a671e551f46cd82f4c7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_63da76f5868f2fe77e24eed54fa7fd7d.setIcon(icon_94010287d78b4a671e551f46cd82f4c7);
#
#
#             marker_63da76f5868f2fe77e24eed54fa7fd7d.bindTooltip(
#                 `&lt;div&gt;
#                      Futurlink
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_ec8bfe147e21dde388c28b4b09e4c42d = L.marker(
#                 [41.392852, 2.168021],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_1c7751833034494e122f6e041a144b2c);
#
#
#             var icon_78e5d51307c0897cc44ac718e2410c6c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_ec8bfe147e21dde388c28b4b09e4c42d.setIcon(icon_78e5d51307c0897cc44ac718e2410c6c);
#
#
#             marker_ec8bfe147e21dde388c28b4b09e4c42d.bindTooltip(
#                 `&lt;div&gt;
#                      vLex
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_9c5978124108cf8c3e327f5883a0d6c3 = L.marker(
#                 [41.3916792, 2.1775706],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_1c7751833034494e122f6e041a144b2c);
#
#
#             var icon_5b50d515979bed0912f1c4d4de9aa742 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_9c5978124108cf8c3e327f5883a0d6c3.setIcon(icon_5b50d515979bed0912f1c4d4de9aa742);
#
#
#             marker_9c5978124108cf8c3e327f5883a0d6c3.bindTooltip(
#                 `&lt;div&gt;
#                      Nuroa
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_52fdd87f043e13ac1321789ff0a6d8dc = L.marker(
#                 [41.406335, 2.192023],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_1c7751833034494e122f6e041a144b2c);
#
#
#             var icon_ae6218d71ffabc3ccb99ade5f455f8b3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quo

# %% [markdown]
# ## Vegan BLN

# %%
# Copy and paste from example from website

vegan_bln_url = "https://api.foursquare.com/v3/places/search?ll=52.5172198%2C13.3782205&categories=13377"

headers = {
    "accept": "application/json",
    "Authorization": "fsq3ziQGzWOXPwEcMzd/Rtxo+uQG864OuLbWTFrbzs4E/+U="
}

vegan_bln_response = requests.get(vegan_bln_url, headers=headers).json()

# %%
#vegan_bln_list loop
vegan_bln_list = []
for i in vegan_bln_response ["results"]:
    
    name = i["name"]
    address =  i["location"]["formatted_address"]
    lat = i["geocodes"]["main"]["latitude"]
    lon = i["geocodes"]["main"]["longitude"]
        
    type_ = {"typepoint": 
                          {"type": "Point", 
                           "coordinates": [lat, lon]}}
    
    vegan_bln_list.append({"name":name, "lat":lat, "lon":lon, "type":type_})
    
vegan_bln_list
# Out:
# [{'name': 'Cookies Cream',
#   'lat': 52.516429,
#   'lon': 13.388216,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [52.516429, 13.388216]}}},
#  {'name': 'Frea',
#   'lat': 52.528188,
#   'lon': 13.393794,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [52.528188, 13.393794]}}},
#  {'name': 'W-Der Imbiss',
#   'lat': 52.534364,
#   'lon': 13.405191,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [52.534364, 13.405191]}}},
#  {'name': 'Brammibal’s Donuts',
#   'lat': 52.508011,
#   'lon': 13.373939,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [52.508011, 13.373939]}}},
#  {'name': 'Witz Hummus',
#   'lat': 52.491215,
#   'lon': 13.404595,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [52.491215, 13.404595]}}},
#  {'name': 'Holy Flat',
#   'lat': 52.490078,
#   'lon': 13.427266,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [52.490078, 13.427266]}}},
#  {'name': 'Falafel Dream 2010',
#   'lat': 52.543234,
#   'lon': 13.365171,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [52.543234, 13.365171]}}},
#  {'name': '1990 Vegan Living',
#   'lat': 52.510345,
#   'lon': 13.458633,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [52.510345, 13.458633]}}},
#  {'name': 'Li.Ke',
#   'lat': 52.511606,
#   'lon': 13.458694,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [52.511606, 13.458694]}}},
#  {'name': 'Baba Angora',
#   'lat': 52.504001,
#   'lon': 13.316851,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [52.504001, 13.316851]}}}]

# %%
#Into DataFrame
vegan_bln_df = pd.DataFrame(vegan_bln_list)

# %%
vegan_bln_df
# Out:
#                  name        lat        lon  \
# 0       Cookies Cream  52.516429  13.388216
# 1                Frea  52.528188  13.393794
# 2        W-Der Imbiss  52.534364  13.405191
# 3  Brammibal’s Donuts  52.508011  13.373939
# 4         Witz Hummus  52.491215  13.404595
# 5           Holy Flat  52.490078  13.427266
# 6  Falafel Dream 2010  52.543234  13.365171
# 7   1990 Vegan Living  52.510345  13.458633
# 8               Li.Ke  52.511606  13.458694
# 9         Baba Angora  52.504001  13.316851
#
#                                                 type
# 0  {'typepoint': {'type': 'Point', 'coordinates':...
# 1  {'typepoint': {'type': 'Point', 'coordinates':...
# 2  {'typepoint': {'type': 'Point', 'coordinates':...
# 3  {'typepoint': {'type': 'Point', 'coordinates':...
# 4  {'typepoint': {'type': 'Point', 'coordinates':...
# 5  {'typepoint': {'type': 'Point', 'coordinates':...
# 6  {'typepoint': {'type': 'Point', 'coordinates':...
# 7  {'typepoint': {'type': 'Point', 'coordinates':...
# 8  {'typepoint': {'type': 'Point', 'coordinates':...
# 9  {'typepoint': {'type': 'Point', 'coordinates':...

# %%
#Save DF
vegan_bln_df.to_csv("../data/vegan_bln_df.csv", index=False)

# %%
#Vegan BLN Marker Loop
for index, row in vegan_bln_df.iterrows():
    #1. MARKER without icon
    district = {"location": [row["lat"], row["lon"]], "tooltip": row["name"]}
    icon = Icon (
            color="green",
            opacity = 0.2,
            prefix = "fa",
            icon = "leaf",
            icon_color = "white",
            icon_size=(30, 30)
        )
    #3. Marker
    new_marker = Marker(**district, icon = icon, radius = 2)
    #4. Add the Marker
    new_marker.add_to(bln_map_1)

# %%
bln_map_1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fe120040b155e0a12133908d8286b2c4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fe120040b155e0a12133908d8286b2c4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_fe120040b155e0a12133908d8286b2c4 = L.map(
#                 &quot;map_fe120040b155e0a12133908d8286b2c4&quot;,
#                 {
#                     center: [52.5147951, 13.3775787],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_92be951bd9eacd5ba2c1bf326854e466 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_fe120040b155e0a12133908d8286b2c4);
#
#
#             var marker_d332845fafadcc677c52ba222da6cd91 = L.marker(
#                 [52.523402, 13.398694],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_fe120040b155e0a12133908d8286b2c4);
#
#
#             var icon_c69e87027a1575390917c21e7ea3d66b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_d332845fafadcc677c52ba222da6cd91.setIcon(icon_c69e87027a1575390917c21e7ea3d66b);
#
#
#             marker_d332845fafadcc677c52ba222da6cd91.bindTooltip(
#                 `&lt;div&gt;
#                      Plazes
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_601a0cfc5c9aec7dddb9cc71f0b662c4 = L.marker(
#                 [52.4897, 13.38861],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_fe120040b155e0a12133908d8286b2c4);
#
#
#             var icon_5bfbe5cb83acd0dc905338c9c647b4ba = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_601a0cfc5c9aec7dddb9cc71f0b662c4.setIcon(icon_5bfbe5cb83acd0dc905338c9c647b4ba);
#
#
#             marker_601a0cfc5c9aec7dddb9cc71f0b662c4.bindTooltip(
#                 `&lt;div&gt;
#                      babbel
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_cfe69a3b76c19efd099f53988291f90e = L.marker(
#                 [52.512249, 13.419841],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_fe120040b155e0a12133908d8286b2c4);
#
#
#             var icon_fe5f5d7c28987a9f732a141e3cff6a62 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_cfe69a3b76c19efd099f53988291f90e.setIcon(icon_fe5f5d7c28987a9f732a141e3cff6a62);
#
#
#             marker_cfe69a3b76c19efd099f53988291f90e.bindTooltip(
#                 `&lt;div&gt;
#                      Metaversum
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_7ac6b166a24cdf91554dd681a4f1cb15 = L.marker(
#                 [52.52348, 13.411494],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_fe120040b155e0a12133908d8286b2c4);
#
#
#             var icon_effd74d79d925ddedcd5d22715ac4335 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_7ac6b166a24cdf91554dd681a4f1cb15.setIcon(icon_effd74d79d925ddedcd5d22715ac4335);
#
#
#             marker_7ac6b166a24cdf91554dd681a4f1cb15.bindTooltip(
#                 `&lt;div&gt;
#                      gate5
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_ded9ff1c94fbf77a19e7f59f232c2a2a = L.marker(
#                 [52.5283614, 13.4124563],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_fe120040b155e0a12133908d8286b2c4);
#
#
#             var icon_6f417dfc5056503be57ba442140f8fbf = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;blac

# %% [markdown]
# ## Vegan LDN

# %%
# Copy and paste from example from website

vegan_ldn_url = "https://api.foursquare.com/v3/places/search?query=vegan&ll=51.5126202%2C-0.132383&categories=13377"

headers = {
    "accept": "application/json",
    "Authorization": "fsq3ziQGzWOXPwEcMzd/Rtxo+uQG864OuLbWTFrbzs4E/+U="
}

vegan_ldn_response = requests.get(vegan_ldn_url, headers=headers).json()

# %%
#vegan_ldn_list loop
vegan_ldn_list = []
for i in vegan_ldn_response ["results"]:
    
    name = i["name"]
    address =  i["location"]["formatted_address"]
    lat = i["geocodes"]["main"]["latitude"]
    lon = i["geocodes"]["main"]["longitude"]
        
    type_ = {"typepoint": 
                          {"type": "Point", 
                           "coordinates": [lat, lon]}}
    
    vegan_ldn_list.append({"name":name, "lat":lat, "lon":lon, "type":type_})
    
vegan_ldn_list
# Out:
# [{'name': 'Mildreds',
#   'lat': 51.513024,
#   'lon': -0.136479,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [51.513024, -0.136479]}}},
#  {'name': 'Black Cat',
#   'lat': 51.551292,
#   'lon': -0.05547,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [51.551292, -0.05547]}}},
#  {'name': 'What the Pitta',
#   'lat': 51.523478,
#   'lon': -0.076177,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [51.523478, -0.076177]}}},
#  {'name': '222 Veggie Vegan',
#   'lat': 51.486001,
#   'lon': -0.203059,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [51.486001, -0.203059]}}},
#  {'name': 'Mildreds',
#   'lat': 51.531369,
#   'lon': -0.117538,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [51.531369, -0.117538]}}},
#  {'name': 'Purezza',
#   'lat': 51.538144,
#   'lon': -0.144202,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [51.538144, -0.144202]}}},
#  {'name': 'Farmacy',
#   'lat': 51.515491,
#   'lon': -0.192777,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [51.515491, -0.192777]}}},
#  {'name': 'The Gate Hammersmith',
#   'lat': 51.490254,
#   'lon': -0.225387,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [51.490254, -0.225387]}}},
#  {'name': 'Mildreds',
#   'lat': 51.545444,
#   'lon': -0.074703,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [51.545444, -0.074703]}}},
#  {'name': 'Mildreds Camden',
#   'lat': 51.540535,
#   'lon': -0.145131,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [51.540535, -0.145131]}}}]

# %%
#Into DataFrame
vegan_ldn_df = pd.DataFrame(vegan_ldn_list)

# %%
vegan_ldn_df
# Out:
#                    name        lat       lon  \
# 0              Mildreds  51.513024 -0.136479
# 1             Black Cat  51.551292 -0.055470
# 2        What the Pitta  51.523478 -0.076177
# 3      222 Veggie Vegan  51.486001 -0.203059
# 4              Mildreds  51.531369 -0.117538
# 5               Purezza  51.538144 -0.144202
# 6               Farmacy  51.515491 -0.192777
# 7  The Gate Hammersmith  51.490254 -0.225387
# 8              Mildreds  51.545444 -0.074703
# 9       Mildreds Camden  51.540535 -0.145131
#
#                                                 type
# 0  {'typepoint': {'type': 'Point', 'coordinates':...
# 1  {'typepoint': {'type': 'Point', 'coordinates':...
# 2  {'typepoint': {'type': 'Point', 'coordinates':...
# 3  {'typepoint': {'type': 'Point', 'coordinates':...
# 4  {'typepoint': {'type': 'Point', 'coordinates':...
# 5  {'typepoint': {'type': 'Point', 'coordinates':...
# 6  {'typepoint': {'type': 'Point', 'coordinates':...
# 7  {'typepoint': {'type': 'Point', 'coordinates':...
# 8  {'typepoint': {'type': 'Point', 'coordinates':...
# 9  {'typepoint': {'type': 'Point', 'coordinates':...

# %%
#Save DF
vegan_bln_df.to_csv("../data/vegan_bln_df.csv", index=False)

# %%
#Vegan LDN Marker Loop
for index, row in vegan_ldn_df.iterrows():
    #1. MARKER without icon
    district = {"location": [row["lat"], row["lon"]], "tooltip": row["name"]}
    icon = Icon (
            color="green",
            opacity = 0.2,
            prefix = "fa",
            icon = "leaf",
            icon_color = "white",
            icon_size=(30, 30)
        )
    #3. Marker
    new_marker = Marker(**district, icon = icon, radius = 2)
    #4. Add the Marker
    new_marker.add_to(ldn_map_1)

# %%
ldn_map_1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5066b73b7074fb6f51d693ee76d7bd45 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5066b73b7074fb6f51d693ee76d7bd45&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_5066b73b7074fb6f51d693ee76d7bd45 = L.map(
#                 &quot;map_5066b73b7074fb6f51d693ee76d7bd45&quot;,
#                 {
#                     center: [51.5037375, -0.1346877],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7a13c78b1236dc0f8324f96d9ce6fd25 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5066b73b7074fb6f51d693ee76d7bd45);
#
#
#             var marker_fa62d17c87474588eb292f736540c0ec = L.marker(
#                 [53.344104, -6.267494],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_5066b73b7074fb6f51d693ee76d7bd45);
#
#
#             var icon_a6eb60e051d06dafb8c61eb8e678a860 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_fa62d17c87474588eb292f736540c0ec.setIcon(icon_a6eb60e051d06dafb8c61eb8e678a860);
#
#
#             marker_fa62d17c87474588eb292f736540c0ec.bindTooltip(
#                 `&lt;div&gt;
#                      Babelgum
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_5be41a7bbc29964c8b1a8d23b6a3e15e = L.marker(
#                 [37.09024, -95.712891],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_5066b73b7074fb6f51d693ee76d7bd45);
#
#
#             var icon_563444affedb1f9be534bc0432fb1eca = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_5be41a7bbc29964c8b1a8d23b6a3e15e.setIcon(icon_563444affedb1f9be534bc0432fb1eca);
#
#
#             marker_5be41a7bbc29964c8b1a8d23b6a3e15e.bindTooltip(
#                 `&lt;div&gt;
#                      Kelkoo
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_c47262103744112d3807ab71f39d85b1 = L.marker(
#                 [41.53155, -72.188584],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_5066b73b7074fb6f51d693ee76d7bd45);
#
#
#             var icon_c337d7fae318cb74652cdc64fed56e22 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_c47262103744112d3807ab71f39d85b1.setIcon(icon_c337d7fae318cb74652cdc64fed56e22);
#
#
#             marker_c47262103744112d3807ab71f39d85b1.bindTooltip(
#                 `&lt;div&gt;
#                      ReachLocal
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_00a7e0d7de0fe6eae8468cef8b8fa6d3 = L.marker(
#                 [51.5108803, -0.1418973],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_5066b73b7074fb6f51d693ee76d7bd45);
#
#
#             var icon_166d8e77f6b54592d4812a5f7a4860a1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_00a7e0d7de0fe6eae8468cef8b8fa6d3.setIcon(icon_166d8e77f6b54592d4812a5f7a4860a1);
#
#
#             marker_00a7e0d7de0fe6eae8468cef8b8fa6d3.bindTooltip(
#                 `&lt;div&gt;
#                      Seedcamp
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_3fc3bec577b00f0cb08b2a9f0f7b2f07 = L.marker(
#                 [51.5192042, -0.1626103],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_5066b73b7074fb6f51d693ee76d7bd45);
#
#
#             var icon_a1bb6511c2f9ac6e6e9f2a3c91523103 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;:

# %% [markdown]
# ## BCN Music Venues

# %%
# Copy and paste from example from website

music_bcn_url = "https://api.foursquare.com/v3/places/search?query=nightclub&ll=41.3898224%2C2.163367"

headers = {
    "accept": "application/json",
    "Authorization": "fsq3ziQGzWOXPwEcMzd/Rtxo+uQG864OuLbWTFrbzs4E/+U="
}

music_bcn_response = requests.get(music_bcn_url, headers=headers).json()

# %%
#music_bcn_list loop
music_bcn_list = []
for i in music_bcn_response ["results"]:
    
    name = i["name"]
    address =  i["location"]["formatted_address"]
    lat = i["geocodes"]["main"]["latitude"]
    lon = i["geocodes"]["main"]["longitude"]
        
    type_ = {"typepoint": 
                          {"type": "Point", 
                           "coordinates": [lat, lon]}}
    
    music_bcn_list.append({"name":name, "lat":lat, "lon":lon, "type":type_})
    
music_bcn_list
# Out:
# [{'name': 'Antilla BCN Latin Club',
#   'lat': 41.384641,
#   'lon': 2.154478,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [41.384641, 2.154478]}}},
#  {'name': 'Razzmatazz',
#   'lat': 41.397599,
#   'lon': 2.191102,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [41.397599, 2.191102]}}},
#  {'name': 'Input',
#   'lat': 41.368636,
#   'lon': 2.14877,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [41.368636, 2.14877]}}},
#  {'name': 'Cdlc',
#   'lat': 41.384976,
#   'lon': 2.1963,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [41.384976, 2.1963]}}},
#  {'name': 'La Terrrazza',
#   'lat': 41.368845,
#   'lon': 2.149262,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [41.368845, 2.149262]}}},
#  {'name': 'Garage 442',
#   'lat': 41.397175,
#   'lon': 2.16068,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [41.397175, 2.16068]}}},
#  {'name': 'Opium',
#   'lat': 41.385104,
#   'lon': 2.196826,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [41.385104, 2.196826]}}},
#  {'name': 'Undead Dark Club',
#   'lat': 41.379763,
#   'lon': 2.133411,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [41.379763, 2.133411]}}},
#  {'name': 'Moog',
#   'lat': 41.378149,
#   'lon': 2.174909,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [41.378149, 2.174909]}}},
#  {'name': 'Carpe Diem',
#   'lat': 41.389427,
#   'lon': 2.163662,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [41.389427, 2.163662]}}}]

# %%
#Into DataFrame
music_bcn_df = pd.DataFrame(music_bcn_list)

# %%
#Music BCN Marker Loop
for index, row in music_bcn_df.iterrows():
    #1. MARKER without icon
    district = {"location": [row["lat"], row["lon"]], "tooltip": row["name"]}
    icon = Icon (
            color="darkpurple",
            opacity = 0.2,
            prefix = "fa",
            icon = "music",
            icon_color = "white",
            icon_size=(30, 30)
        )
    #3. Marker
    new_marker = Marker(**district, icon = icon, radius = 2)
    #4. Add the Marker
    new_marker.add_to(bcn_map_1)

# %%
bcn_map_1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1c7751833034494e122f6e041a144b2c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1c7751833034494e122f6e041a144b2c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_1c7751833034494e122f6e041a144b2c = L.map(
#                 &quot;map_1c7751833034494e122f6e041a144b2c&quot;,
#                 {
#                     center: [41.3898224, 2.163367],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5b2589963e8ef719d193a3a42a0f04c8 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1c7751833034494e122f6e041a144b2c);
#
#
#             var marker_11a24e3566bc7041e3ce42f19d84df9c = L.marker(
#                 [41.3854855, 2.1702872],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_1c7751833034494e122f6e041a144b2c);
#
#
#             var icon_a43bba29fcde0926ecd03e3e1674b3df = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_11a24e3566bc7041e3ce42f19d84df9c.setIcon(icon_a43bba29fcde0926ecd03e3e1674b3df);
#
#
#             marker_11a24e3566bc7041e3ce42f19d84df9c.bindTooltip(
#                 `&lt;div&gt;
#                      eyeOS
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_63da76f5868f2fe77e24eed54fa7fd7d = L.marker(
#                 [41.396553, 2.189241],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_1c7751833034494e122f6e041a144b2c);
#
#
#             var icon_94010287d78b4a671e551f46cd82f4c7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_63da76f5868f2fe77e24eed54fa7fd7d.setIcon(icon_94010287d78b4a671e551f46cd82f4c7);
#
#
#             marker_63da76f5868f2fe77e24eed54fa7fd7d.bindTooltip(
#                 `&lt;div&gt;
#                      Futurlink
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_ec8bfe147e21dde388c28b4b09e4c42d = L.marker(
#                 [41.392852, 2.168021],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_1c7751833034494e122f6e041a144b2c);
#
#
#             var icon_78e5d51307c0897cc44ac718e2410c6c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_ec8bfe147e21dde388c28b4b09e4c42d.setIcon(icon_78e5d51307c0897cc44ac718e2410c6c);
#
#
#             marker_ec8bfe147e21dde388c28b4b09e4c42d.bindTooltip(
#                 `&lt;div&gt;
#                      vLex
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_9c5978124108cf8c3e327f5883a0d6c3 = L.marker(
#                 [41.3916792, 2.1775706],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_1c7751833034494e122f6e041a144b2c);
#
#
#             var icon_5b50d515979bed0912f1c4d4de9aa742 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_9c5978124108cf8c3e327f5883a0d6c3.setIcon(icon_5b50d515979bed0912f1c4d4de9aa742);
#
#
#             marker_9c5978124108cf8c3e327f5883a0d6c3.bindTooltip(
#                 `&lt;div&gt;
#                      Nuroa
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_52fdd87f043e13ac1321789ff0a6d8dc = L.marker(
#                 [41.406335, 2.192023],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_1c7751833034494e122f6e041a144b2c);
#
#
#             var icon_ae6218d71ffabc3ccb99ade5f455f8b3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quo

# %% [markdown]
# ## BLN Music Venues

# %%
# Copy and paste from example from website

music_bln_url = "https://api.foursquare.com/v3/places/search?query=nightclub&ll=52.5172198%2C13.3782205"

headers = {
    "accept": "application/json",
    "Authorization": "fsq3ziQGzWOXPwEcMzd/Rtxo+uQG864OuLbWTFrbzs4E/+U="
}

music_bln_response = requests.get(music_bln_url, headers=headers).json()

# %%
#Music BLN list loop
music_bln_list = []
for i in music_bln_response ["results"]:
    
    name = i["name"]
    address =  i["location"]["formatted_address"]
    lat = i["geocodes"]["main"]["latitude"]
    lon = i["geocodes"]["main"]["longitude"]
        
    type_ = {"typepoint": 
                          {"type": "Point", 
                           "coordinates": [lat, lon]}}
    
    music_bln_list.append({"name":name, "lat":lat, "lon":lon, "type":type_})
    
music_bln_list
# Out:
# [{'name': 'Berghain',
#   'lat': 52.511684,
#   'lon': 13.443349,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [52.511684, 13.443349]}}},
#  {'name': 'Kater Blau',
#   'lat': 52.511956,
#   'lon': 13.42545,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [52.511956, 13.42545]}}},
#  {'name': 'Teledisko',
#   'lat': 52.507578,
#   'lon': 13.454489,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [52.507578, 13.454489]}}},
#  {'name': 'Mensch Meier',
#   'lat': 52.535213,
#   'lon': 13.452298,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [52.535213, 13.452298]}}},
#  {'name': 'Sisyphos',
#   'lat': 52.493365,
#   'lon': 13.490793,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [52.493365, 13.490793]}}},
#  {'name': 'Salon - Zur Wilden Renate',
#   'lat': 52.497405,
#   'lon': 13.465153,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [52.497405, 13.465153]}}},
#  {'name': 'KitKatClub',
#   'lat': 52.511176,
#   'lon': 13.416753,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [52.511176, 13.416753]}}},
#  {'name': 'Golden Gate',
#   'lat': 52.516155,
#   'lon': 13.416737,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [52.516155, 13.416737]}}},
#  {'name': 'About Blank',
#   'lat': 52.502354,
#   'lon': 13.466283,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [52.502354, 13.466283]}}},
#  {'name': 'Ohm',
#   'lat': 52.510541,
#   'lon': 13.420376,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [52.510541, 13.420376]}}}]

# %%
#Into DataFrame
music_bln_df = pd.DataFrame(music_bln_list)

# %%
#Music BLN Marker Loop
for index, row in music_bln_df.iterrows():
    #1. MARKER without icon
    district = {"location": [row["lat"], row["lon"]], "tooltip": row["name"]}
    icon = Icon (
            color="darkpurple",
            opacity = 0.2,
            prefix = "fa",
            icon = "music",
            icon_color = "white",
            icon_size=(30, 30)
        )
    #3. Marker
    new_marker = Marker(**district, icon = icon, radius = 2)
    #4. Add the Marker
    new_marker.add_to(bln_map_1)

# %%
bln_map_1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fe120040b155e0a12133908d8286b2c4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fe120040b155e0a12133908d8286b2c4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_fe120040b155e0a12133908d8286b2c4 = L.map(
#                 &quot;map_fe120040b155e0a12133908d8286b2c4&quot;,
#                 {
#                     center: [52.5147951, 13.3775787],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_92be951bd9eacd5ba2c1bf326854e466 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_fe120040b155e0a12133908d8286b2c4);
#
#
#             var marker_d332845fafadcc677c52ba222da6cd91 = L.marker(
#                 [52.523402, 13.398694],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_fe120040b155e0a12133908d8286b2c4);
#
#
#             var icon_c69e87027a1575390917c21e7ea3d66b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_d332845fafadcc677c52ba222da6cd91.setIcon(icon_c69e87027a1575390917c21e7ea3d66b);
#
#
#             marker_d332845fafadcc677c52ba222da6cd91.bindTooltip(
#                 `&lt;div&gt;
#                      Plazes
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_601a0cfc5c9aec7dddb9cc71f0b662c4 = L.marker(
#                 [52.4897, 13.38861],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_fe120040b155e0a12133908d8286b2c4);
#
#
#             var icon_5bfbe5cb83acd0dc905338c9c647b4ba = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_601a0cfc5c9aec7dddb9cc71f0b662c4.setIcon(icon_5bfbe5cb83acd0dc905338c9c647b4ba);
#
#
#             marker_601a0cfc5c9aec7dddb9cc71f0b662c4.bindTooltip(
#                 `&lt;div&gt;
#                      babbel
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_cfe69a3b76c19efd099f53988291f90e = L.marker(
#                 [52.512249, 13.419841],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_fe120040b155e0a12133908d8286b2c4);
#
#
#             var icon_fe5f5d7c28987a9f732a141e3cff6a62 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_cfe69a3b76c19efd099f53988291f90e.setIcon(icon_fe5f5d7c28987a9f732a141e3cff6a62);
#
#
#             marker_cfe69a3b76c19efd099f53988291f90e.bindTooltip(
#                 `&lt;div&gt;
#                      Metaversum
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_7ac6b166a24cdf91554dd681a4f1cb15 = L.marker(
#                 [52.52348, 13.411494],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_fe120040b155e0a12133908d8286b2c4);
#
#
#             var icon_effd74d79d925ddedcd5d22715ac4335 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_7ac6b166a24cdf91554dd681a4f1cb15.setIcon(icon_effd74d79d925ddedcd5d22715ac4335);
#
#
#             marker_7ac6b166a24cdf91554dd681a4f1cb15.bindTooltip(
#                 `&lt;div&gt;
#                      gate5
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_ded9ff1c94fbf77a19e7f59f232c2a2a = L.marker(
#                 [52.5283614, 13.4124563],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_fe120040b155e0a12133908d8286b2c4);
#
#
#             var icon_6f417dfc5056503be57ba442140f8fbf = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;blac

# %% [markdown]
# ## LDN Music Venues

# %%
# Copy and paste from example from website

music_ldn_url = "https://api.foursquare.com/v3/places/search?query=nightclub&ll=51.512620%2C-0.132383"

headers = {
    "accept": "application/json",
    "Authorization": "fsq3ziQGzWOXPwEcMzd/Rtxo+uQG864OuLbWTFrbzs4E/+U="
}


music_ldn_response = requests.get(music_ldn_url, headers=headers).json()

# %%
#music_ldn_list loop
music_ldn_list = []
for i in music_ldn_response ["results"]:
    
    name = i["name"]
    address =  i["location"]["formatted_address"]
    lat = i["geocodes"]["main"]["latitude"]
    lon = i["geocodes"]["main"]["longitude"]
        
    type_ = {"typepoint": 
                          {"type": "Point", 
                           "coordinates": [lat, lon]}}
    
    music_ldn_list.append({"name":name, "lat":lat, "lon":lon, "type":type_})
    
music_ldn_list
# Out:
# [{'name': 'Tramp',
#   'lat': 51.508255,
#   'lon': -0.13782,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [51.508255, -0.13782]}}},
#  {'name': 'Cirque le Soir',
#   'lat': 51.51291,
#   'lon': -0.13893,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [51.51291, -0.13893]}}},
#  {'name': 'Maddox Club',
#   'lat': 51.512702,
#   'lon': -0.142262,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [51.512702, -0.142262]}}},
#  {'name': 'Ministry of Sound',
#   'lat': 51.497637,
#   'lon': -0.099503,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [51.497637, -0.099503]}}},
#  {'name': 'Phonox',
#   'lat': 51.464317,
#   'lon': -0.114536,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [51.464317, -0.114536]}}},
#  {'name': 'Electrowerkz',
#   'lat': 51.532262,
#   'lon': -0.105177,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [51.532262, -0.105177]}}},
#  {'name': 'Fabric',
#   'lat': 51.51962,
#   'lon': -0.10252,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [51.51962, -0.10252]}}},
#  {'name': 'The Social',
#   'lat': 51.517359,
#   'lon': -0.140988,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [51.517359, -0.140988]}}},
#  {'name': 'Fold',
#   'lat': 51.519379,
#   'lon': 0.003826,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [51.519379, 0.003826]}}},
#  {'name': 'Tape London',
#   'lat': 51.514326,
#   'lon': -0.144572,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [51.514326, -0.144572]}}}]

# %%
#Into DataFrame
music_ldn_df = pd.DataFrame(music_ldn_list)

# %%
#Music LDN Marker Loop
for index, row in music_ldn_df.iterrows():
    #1. MARKER without icon
    district = {"location": [row["lat"], row["lon"]], "tooltip": row["name"]}
    icon = Icon (
            color="darkpurple",
            opacity = 0.2,
            prefix = "fa",
            icon = "music",
            icon_color = "white",
            icon_size=(30, 30)
        )
    #3. Marker
    new_marker = Marker(**district, icon = icon, radius = 2)
    #4. Add the Marker
    new_marker.add_to(ldn_map_1)

# %%
ldn_map_1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5066b73b7074fb6f51d693ee76d7bd45 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5066b73b7074fb6f51d693ee76d7bd45&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_5066b73b7074fb6f51d693ee76d7bd45 = L.map(
#                 &quot;map_5066b73b7074fb6f51d693ee76d7bd45&quot;,
#                 {
#                     center: [51.5037375, -0.1346877],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7a13c78b1236dc0f8324f96d9ce6fd25 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5066b73b7074fb6f51d693ee76d7bd45);
#
#
#             var marker_fa62d17c87474588eb292f736540c0ec = L.marker(
#                 [53.344104, -6.267494],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_5066b73b7074fb6f51d693ee76d7bd45);
#
#
#             var icon_a6eb60e051d06dafb8c61eb8e678a860 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_fa62d17c87474588eb292f736540c0ec.setIcon(icon_a6eb60e051d06dafb8c61eb8e678a860);
#
#
#             marker_fa62d17c87474588eb292f736540c0ec.bindTooltip(
#                 `&lt;div&gt;
#                      Babelgum
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_5be41a7bbc29964c8b1a8d23b6a3e15e = L.marker(
#                 [37.09024, -95.712891],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_5066b73b7074fb6f51d693ee76d7bd45);
#
#
#             var icon_563444affedb1f9be534bc0432fb1eca = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_5be41a7bbc29964c8b1a8d23b6a3e15e.setIcon(icon_563444affedb1f9be534bc0432fb1eca);
#
#
#             marker_5be41a7bbc29964c8b1a8d23b6a3e15e.bindTooltip(
#                 `&lt;div&gt;
#                      Kelkoo
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_c47262103744112d3807ab71f39d85b1 = L.marker(
#                 [41.53155, -72.188584],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_5066b73b7074fb6f51d693ee76d7bd45);
#
#
#             var icon_c337d7fae318cb74652cdc64fed56e22 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_c47262103744112d3807ab71f39d85b1.setIcon(icon_c337d7fae318cb74652cdc64fed56e22);
#
#
#             marker_c47262103744112d3807ab71f39d85b1.bindTooltip(
#                 `&lt;div&gt;
#                      ReachLocal
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_00a7e0d7de0fe6eae8468cef8b8fa6d3 = L.marker(
#                 [51.5108803, -0.1418973],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_5066b73b7074fb6f51d693ee76d7bd45);
#
#
#             var icon_166d8e77f6b54592d4812a5f7a4860a1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_00a7e0d7de0fe6eae8468cef8b8fa6d3.setIcon(icon_166d8e77f6b54592d4812a5f7a4860a1);
#
#
#             marker_00a7e0d7de0fe6eae8468cef8b8fa6d3.bindTooltip(
#                 `&lt;div&gt;
#                      Seedcamp
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_3fc3bec577b00f0cb08b2a9f0f7b2f07 = L.marker(
#                 [51.5192042, -0.1626103],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_5066b73b7074fb6f51d693ee76d7bd45);
#
#
#             var icon_a1bb6511c2f9ac6e6e9f2a3c91523103 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;:

# %% [markdown]
# ## BCN Airports

# %%
# Copy and paste from example from website

airport_bcn_url = "https://api.foursquare.com/v3/places/search?query=airport&ll=41.3898224%2C2.163367"

headers = {
    "accept": "application/json",
    "Authorization": "fsq3ziQGzWOXPwEcMzd/Rtxo+uQG864OuLbWTFrbzs4E/+U="
}



airport_bcn_response = requests.get(airport_bcn_url, headers=headers).json()

# %%
#airport_bcn_list loop
airport_bcn_list = []
for i in airport_bcn_response ["results"]:
    
    name = i["name"]
    address =  i["location"]["formatted_address"]
    lat = i["geocodes"]["main"]["latitude"]
    lon = i["geocodes"]["main"]["longitude"]
        
    type_ = {"typepoint": 
                          {"type": "Point", 
                           "coordinates": [lat, lon]}}
    
    airport_bcn_list.append({"name":name, "lat":lat, "lon":lon, "type":type_})
    
airport_bcn_list
# Out:
# [{'name': 'Barcelona–El Prat Josep Tarradellas Airport (BCN) (Aeropuerto Josep Tarradellas Barcelona-El Prat)',
#   'lat': 41.289084,
#   'lon': 2.073963,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [41.289084, 2.073963]}}},
#  {'name': 'Sabadell Airport (Aeroport de Sabadell)',
#   'lat': 41.521142,
#   'lon': 2.103024,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [41.521142, 2.103024]}}},
#  {'name': 'Estacion del Capitolio, Panem',
#   'lat': 41.296123,
#   'lon': 2.075351,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [41.296123, 2.075351]}}},
#  {'name': 'Newco Base Rampa',
#   'lat': 41.291094,
#   'lon': 2.078811,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [41.291094, 2.078811]}}},
#  {'name': 'Pk 217 T1 Aeropuerto de Barcelona',
#   'lat': 41.291755,
#   'lon': 2.075308,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [41.291755, 2.075308]}}},
#  {'name': 'KLM lounge',
#   'lat': 41.29026,
#   'lon': 2.075008,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [41.29026, 2.075008]}}},
#  {'name': 'Oficina transitos Vueling, zona a',
#   'lat': 41.290654,
#   'lon': 2.074304,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [41.290654, 2.074304]}}},
#  {'name': 'Sala Tripulaciones VLG',
#   'lat': 41.291167,
#   'lon': 2.072467,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [41.291167, 2.072467]}}},
#  {'name': 'Sala de control sate',
#   'lat': 41.288312,
#   'lon': 2.076681,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [41.288312, 2.076681]}}},
#  {'name': 'Planta -1 de la T1',
#   'lat': 41.288614,
#   'lon': 2.074044,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [41.288614, 2.074044]}}}]

# %%
#Into DataFrame
airport_bcn_df = pd.DataFrame(airport_bcn_list)

# %%
#Airport BCN Marker Loop
for index, row in airport_bcn_df.iterrows():
    #1. MARKER without icon
    district = {"location": [row["lat"], row["lon"]], "tooltip": row["name"]}
    icon = Icon (
            color="gray",
            opacity = 0.2,
            prefix = "fa",
            icon = "plane",
            icon_color = "white",
            icon_size=(30, 30)
        )
    #3. Marker
    new_marker = Marker(**district, icon = icon, radius = 2)
    #4. Add the Marker
    new_marker.add_to(bcn_map_1)

# %% [markdown]
# ## BLN Airports

# %%
# Copy and paste from example from website

airport_bln_url = "https://api.foursquare.com/v3/places/search?query=airport&ll=52.5172198%2C13.3782205"

headers = {
    "accept": "application/json",
    "Authorization": "fsq3ziQGzWOXPwEcMzd/Rtxo+uQG864OuLbWTFrbzs4E/+U="
}


airport_bln_response = requests.get(airport_bln_url, headers=headers).json()

# %%
#airport_bln_list loop
airport_bln_list = []
for i in airport_bln_response ["results"]:
    
    name = i["name"]
    address =  i["location"]["formatted_address"]
    lat = i["geocodes"]["main"]["latitude"]
    lon = i["geocodes"]["main"]["longitude"]
        
    type_ = {"typepoint": 
                          {"type": "Point", 
                           "coordinates": [lat, lon]}}
    
    airport_bln_list.append({"name":name, "lat":lat, "lon":lon, "type":type_})
    
airport_bln_list
# Out:
# [{'name': 'Flugplatz Werneuchen GmbH',
#   'lat': 52.629537,
#   'lon': 13.735207,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [52.629537, 13.735207]}}},
#  {'name': 'Flugplatz Saarmund',
#   'lat': 52.308314,
#   'lon': 13.114647,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [52.308314, 13.114647]}}},
#  {'name': 'Sleepless Records',
#   'lat': 52.51609,
#   'lon': 13.376894,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [52.51609, 13.376894]}}},
#  {'name': 'Matthew Rosen N102',
#   'lat': 52.499586,
#   'lon': 13.362878,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [52.499586, 13.362878]}}},
#  {'name': 'AirSight GmbH',
#   'lat': 52.542522,
#   'lon': 13.383938,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [52.542522, 13.383938]}}},
#  {'name': 'Airport Berlin Brandenburg International',
#   'lat': 52.502662,
#   'lon': 13.34332,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [52.502662, 13.34332]}}},
#  {'name': 'beauty24 - Wellness Urlaub HQ',
#   'lat': 52.491235,
#   'lon': 13.385118,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [52.491235, 13.385118]}}},
#  {'name': 'Germandrones GmbH Luftfahrtunternehmen',
#   'lat': 52.52421,
#   'lon': 13.328689,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [52.52421, 13.328689]}}},
#  {'name': 'Tempelhof Projekt GmbH',
#   'lat': 52.483854,
#   'lon': 13.391172,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [52.483854, 13.391172]}}},
#  {'name': 'ATF-AIR-TAXI Fluggesellschaft',
#   'lat': 52.47605,
#   'lon': 13.370536,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [52.47605, 13.370536]}}}]

# %%
#Into DataFrame
airport_bln_df = pd.DataFrame(airport_bln_list)

# %%
#Airport BLN Marker Loop
for index, row in airport_bln_df.iterrows():
    #1. MARKER without icon
    district = {"location": [row["lat"], row["lon"]], "tooltip": row["name"]}
    icon = Icon (
            color="gray",
            opacity = 0.2,
            prefix = "fa",
            icon = "plane",
            icon_color = "white",
            icon_size=(30, 30)
        )
    #3. Marker
    new_marker = Marker(**district, icon = icon, radius = 2)
    #4. Add the Marker
    new_marker.add_to(bln_map_1)

# %% [markdown]
# ## LDN Airports

# %%
# Copy and paste from example from website

airport_ldn_url = "https://api.foursquare.com/v3/places/search?query=airport&ll=51.512620%2C-0.132383"

headers = {
    "accept": "application/json",
    "Authorization": "fsq3ziQGzWOXPwEcMzd/Rtxo+uQG864OuLbWTFrbzs4E/+U="
}


airport_ldn_response = requests.get(airport_ldn_url, headers=headers).json()

# %%
#airport_ldn_list loop
airport_ldn_list = []
for i in airport_ldn_response ["results"]:
    
    name = i["name"]
    address =  i["location"]["formatted_address"]
    lat = i["geocodes"]["main"]["latitude"]
    lon = i["geocodes"]["main"]["longitude"]
        
    type_ = {"typepoint": 
                          {"type": "Point", 
                           "coordinates": [lat, lon]}}
    
    airport_ldn_list.append({"name":name, "lat":lat, "lon":lon, "type":type_})
    
airport_ldn_list
# Out:
# [{'name': 'London Heathrow Airport (LHR)',
#   'lat': 51.470012,
#   'lon': -0.454478,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [51.470012, -0.454478]}}},
#  {'name': 'London City Airport (LCY)',
#   'lat': 51.503297,
#   'lon': 0.050112,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [51.503297, 0.050112]}}},
#  {'name': 'Elstree Aerodrome',
#   'lat': 51.654044,
#   'lon': -0.323953,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [51.654044, -0.323953]}}},
#  {'name': 'Kenley Aerodrome',
#   'lat': 51.302516,
#   'lon': -0.099422,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [51.302516, -0.099422]}}},
#  {'name': 'Biggin Hill Airport (BQH)',
#   'lat': 51.331889,
#   'lon': 0.028996,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [51.331889, 0.028996]}}},
#  {'name': 'Sala VIP Heathrow',
#   'lat': 51.42655,
#   'lon': -0.131691,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [51.42655, -0.131691]}}},
#  {'name': 'Damyns Hall Aerodrome',
#   'lat': 51.53119,
#   'lon': 0.246276,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [51.53119, 0.246276]}}},
#  {'name': 'Cargo Worldwide',
#   'lat': 51.523898,
#   'lon': 0.09529,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [51.523898, 0.09529]}}},
#  {'name': 'Stapleford Flight Centre',
#   'lat': 51.656588,
#   'lon': 0.155572,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [51.656588, 0.155572]}}},
#  {'name': 'Denham Aerodrome',
#   'lat': 51.591065,
#   'lon': -0.512883,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [51.591065, -0.512883]}}}]

# %%
#Into DataFrame
airport_ldn_df = pd.DataFrame(airport_ldn_list)

# %%
#Airport LDN Marker Loop
for index, row in airport_ldn_df.iterrows():
    #1. MARKER without icon
    district = {"location": [row["lat"], row["lon"]], "tooltip": row["name"]}
    icon = Icon (
            color="gray",
            opacity = 0.2,
            prefix = "fa",
            icon = "plane",
            icon_color = "white",
            icon_size=(30, 30)
        )
    #3. Marker
    new_marker = Marker(**district, icon = icon, radius = 2)
    #4. Add the Marker
    new_marker.add_to(ldn_map_1)

# %%
ldn_map_1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5066b73b7074fb6f51d693ee76d7bd45 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5066b73b7074fb6f51d693ee76d7bd45&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_5066b73b7074fb6f51d693ee76d7bd45 = L.map(
#                 &quot;map_5066b73b7074fb6f51d693ee76d7bd45&quot;,
#                 {
#                     center: [51.5037375, -0.1346877],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7a13c78b1236dc0f8324f96d9ce6fd25 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5066b73b7074fb6f51d693ee76d7bd45);
#
#
#             var marker_fa62d17c87474588eb292f736540c0ec = L.marker(
#                 [53.344104, -6.267494],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_5066b73b7074fb6f51d693ee76d7bd45);
#
#
#             var icon_a6eb60e051d06dafb8c61eb8e678a860 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_fa62d17c87474588eb292f736540c0ec.setIcon(icon_a6eb60e051d06dafb8c61eb8e678a860);
#
#
#             marker_fa62d17c87474588eb292f736540c0ec.bindTooltip(
#                 `&lt;div&gt;
#                      Babelgum
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_5be41a7bbc29964c8b1a8d23b6a3e15e = L.marker(
#                 [37.09024, -95.712891],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_5066b73b7074fb6f51d693ee76d7bd45);
#
#
#             var icon_563444affedb1f9be534bc0432fb1eca = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_5be41a7bbc29964c8b1a8d23b6a3e15e.setIcon(icon_563444affedb1f9be534bc0432fb1eca);
#
#
#             marker_5be41a7bbc29964c8b1a8d23b6a3e15e.bindTooltip(
#                 `&lt;div&gt;
#                      Kelkoo
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_c47262103744112d3807ab71f39d85b1 = L.marker(
#                 [41.53155, -72.188584],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_5066b73b7074fb6f51d693ee76d7bd45);
#
#
#             var icon_c337d7fae318cb74652cdc64fed56e22 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_c47262103744112d3807ab71f39d85b1.setIcon(icon_c337d7fae318cb74652cdc64fed56e22);
#
#
#             marker_c47262103744112d3807ab71f39d85b1.bindTooltip(
#                 `&lt;div&gt;
#                      ReachLocal
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_00a7e0d7de0fe6eae8468cef8b8fa6d3 = L.marker(
#                 [51.5108803, -0.1418973],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_5066b73b7074fb6f51d693ee76d7bd45);
#
#
#             var icon_166d8e77f6b54592d4812a5f7a4860a1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_00a7e0d7de0fe6eae8468cef8b8fa6d3.setIcon(icon_166d8e77f6b54592d4812a5f7a4860a1);
#
#
#             marker_00a7e0d7de0fe6eae8468cef8b8fa6d3.bindTooltip(
#                 `&lt;div&gt;
#                      Seedcamp
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_3fc3bec577b00f0cb08b2a9f0f7b2f07 = L.marker(
#                 [51.5192042, -0.1626103],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_5066b73b7074fb6f51d693ee76d7bd45);
#
#
#             var icon_a1bb6511c2f9ac6e6e9f2a3c91523103 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;:

# %% [markdown]
# ## BCN Starbucks

# %%
# Copy and paste from example from website

starbucks_bcn_url = "https://api.foursquare.com/v3/places/search?query=starbucks&ll=41.3898224%2C2.163367"

headers = {
    "accept": "application/json",
    "Authorization": "fsq3ziQGzWOXPwEcMzd/Rtxo+uQG864OuLbWTFrbzs4E/+U="
}

starbucks_bcn_response = requests.get(starbucks_bcn_url, headers=headers).json()

# %%
#starbucks_bln_list loop
starbucks_bcn_list = []
for i in starbucks_bcn_response ["results"]:
    
    name = i["name"]
    address =  i["location"]["formatted_address"]
    lat = i["geocodes"]["main"]["latitude"]
    lon = i["geocodes"]["main"]["longitude"]
        
    type_ = {"typepoint": 
                          {"type": "Point", 
                           "coordinates": [lat, lon]}}
    
    starbucks_bcn_list.append({"name":name, "lat":lat, "lon":lon, "type":type_})
    
starbucks_bcn_list
# Out:
# [{'name': 'Starbucks',
#   'lat': 41.390814,
#   'lon': 2.165062,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [41.390814, 2.165062]}}},
#  {'name': 'Starbucks',
#   'lat': 41.387974,
#   'lon': 2.167991,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [41.387974, 2.167991]}}},
#  {'name': 'Starbucks',
#   'lat': 41.385779,
#   'lon': 2.167932,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [41.385779, 2.167932]}}},
#  {'name': 'Starbucks',
#   'lat': 41.385204,
#   'lon': 2.163273,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [41.385204, 2.163273]}}},
#  {'name': 'Starbucks',
#   'lat': 41.383476,
#   'lon': 2.171057,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [41.383476, 2.171057]}}},
#  {'name': 'Starbucks',
#   'lat': 41.387848,
#   'lon': 2.169634,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [41.387848, 2.169634]}}},
#  {'name': 'Starbucks',
#   'lat': 41.381816,
#   'lon': 2.17225,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [41.381816, 2.17225]}}},
#  {'name': 'Starbucks',
#   'lat': 41.37651,
#   'lon': 2.150584,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [41.37651, 2.150584]}}},
#  {'name': 'Starbucks',
#   'lat': 41.402337,
#   'lon': 2.174068,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [41.402337, 2.174068]}}},
#  {'name': 'Starbucks',
#   'lat': 41.385244,
#   'lon': 2.177226,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [41.385244, 2.177226]}}}]

# %%
#Into DataFrame
starbucks_bcn_df = pd.DataFrame(starbucks_bcn_list)

# %%
#Starbucks BCN Marker Loop
for index, row in starbucks_bcn_df.iterrows():
    #1. MARKER without icon
    district = {"location": [row["lat"], row["lon"]], "tooltip": row["name"]}
    icon = Icon (
            color="beige",
            opacity = 0.2,
            prefix = "fa",
            icon = "coffee",
            icon_color = "white",
            icon_size=(30, 30)
        )
    #3. Marker
    new_marker = Marker(**district, icon = icon, radius = 2)
    #4. Add the Marker
    new_marker.add_to(bcn_map_1)

# %%
bcn_map_1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1c7751833034494e122f6e041a144b2c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1c7751833034494e122f6e041a144b2c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_1c7751833034494e122f6e041a144b2c = L.map(
#                 &quot;map_1c7751833034494e122f6e041a144b2c&quot;,
#                 {
#                     center: [41.3898224, 2.163367],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5b2589963e8ef719d193a3a42a0f04c8 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1c7751833034494e122f6e041a144b2c);
#
#
#             var marker_11a24e3566bc7041e3ce42f19d84df9c = L.marker(
#                 [41.3854855, 2.1702872],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_1c7751833034494e122f6e041a144b2c);
#
#
#             var icon_a43bba29fcde0926ecd03e3e1674b3df = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_11a24e3566bc7041e3ce42f19d84df9c.setIcon(icon_a43bba29fcde0926ecd03e3e1674b3df);
#
#
#             marker_11a24e3566bc7041e3ce42f19d84df9c.bindTooltip(
#                 `&lt;div&gt;
#                      eyeOS
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_63da76f5868f2fe77e24eed54fa7fd7d = L.marker(
#                 [41.396553, 2.189241],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_1c7751833034494e122f6e041a144b2c);
#
#
#             var icon_94010287d78b4a671e551f46cd82f4c7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_63da76f5868f2fe77e24eed54fa7fd7d.setIcon(icon_94010287d78b4a671e551f46cd82f4c7);
#
#
#             marker_63da76f5868f2fe77e24eed54fa7fd7d.bindTooltip(
#                 `&lt;div&gt;
#                      Futurlink
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_ec8bfe147e21dde388c28b4b09e4c42d = L.marker(
#                 [41.392852, 2.168021],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_1c7751833034494e122f6e041a144b2c);
#
#
#             var icon_78e5d51307c0897cc44ac718e2410c6c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_ec8bfe147e21dde388c28b4b09e4c42d.setIcon(icon_78e5d51307c0897cc44ac718e2410c6c);
#
#
#             marker_ec8bfe147e21dde388c28b4b09e4c42d.bindTooltip(
#                 `&lt;div&gt;
#                      vLex
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_9c5978124108cf8c3e327f5883a0d6c3 = L.marker(
#                 [41.3916792, 2.1775706],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_1c7751833034494e122f6e041a144b2c);
#
#
#             var icon_5b50d515979bed0912f1c4d4de9aa742 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_9c5978124108cf8c3e327f5883a0d6c3.setIcon(icon_5b50d515979bed0912f1c4d4de9aa742);
#
#
#             marker_9c5978124108cf8c3e327f5883a0d6c3.bindTooltip(
#                 `&lt;div&gt;
#                      Nuroa
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_52fdd87f043e13ac1321789ff0a6d8dc = L.marker(
#                 [41.406335, 2.192023],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_1c7751833034494e122f6e041a144b2c);
#
#
#             var icon_ae6218d71ffabc3ccb99ade5f455f8b3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quo

# %% [markdown]
# ## BLN Starbucks

# %%
# Copy and paste from example from website

starbucks_bln_url = "https://api.foursquare.com/v3/places/search?query=starbucks&ll=52.5172198%2C13.3782205"

headers = {
    "accept": "application/json",
    "Authorization": "fsq3ziQGzWOXPwEcMzd/Rtxo+uQG864OuLbWTFrbzs4E/+U="
}


starbucks_bln_response = requests.get(starbucks_bln_url, headers=headers).json()

# %%
#starbucks_bln_list loop
starbucks_bln_list = []
for i in starbucks_bln_response ["results"]:
    
    name = i["name"]
    address =  i["location"]["formatted_address"]
    lat = i["geocodes"]["main"]["latitude"]
    lon = i["geocodes"]["main"]["longitude"]
        
    type_ = {"typepoint": 
                          {"type": "Point", 
                           "coordinates": [lat, lon]}}
    
    starbucks_bln_list.append({"name":name, "lat":lat, "lon":lon, "type":type_})
    
starbucks_bln_list
# Out:
# [{'name': 'Starbucks',
#   'lat': 52.519478,
#   'lon': 13.388708,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [52.519478, 13.388708]}}},
#  {'name': 'Starbucks',
#   'lat': 52.523325,
#   'lon': 13.402302,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [52.523325, 13.402302]}}},
#  {'name': 'Starbucks',
#   'lat': 52.516714,
#   'lon': 13.379696,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [52.516714, 13.379696]}}},
#  {'name': 'Starbucks',
#   'lat': 52.524629,
#   'lon': 13.370125,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [52.524629, 13.370125]}}},
#  {'name': 'Starbucks',
#   'lat': 52.523795,
#   'lon': 13.414676,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [52.523795, 13.414676]}}},
#  {'name': 'Starbucks',
#   'lat': 52.521509,
#   'lon': 13.411302,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [52.521509, 13.411302]}}},
#  {'name': 'Starbucks',
#   'lat': 52.505811,
#   'lon': 13.331525,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [52.505811, 13.331525]}}},
#  {'name': 'Starbucks',
#   'lat': 52.511063,
#   'lon': 13.390129,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [52.511063, 13.390129]}}},
#  {'name': 'Starbucks',
#   'lat': 52.505983,
#   'lon': 13.446423,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [52.505983, 13.446423]}}},
#  {'name': 'Starbucks',
#   'lat': 52.503837,
#   'lon': 13.332973,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [52.503837, 13.332973]}}}]

# %%
#Into DataFrame
starbucks_bln_df = pd.DataFrame(starbucks_bln_list)

# %%
#Starbucks BLN Marker Loop
for index, row in starbucks_bln_df.iterrows():
    #1. MARKER without icon
    district = {"location": [row["lat"], row["lon"]], "tooltip": row["name"]}
    icon = Icon (
            color="beige",
            opacity = 0.2,
            prefix = "fa",
            icon = "coffee",
            icon_color = "white",
            icon_size=(30, 30)
        )
    #3. Marker
    new_marker = Marker(**district, icon = icon, radius = 2)
    #4. Add the Marker
    new_marker.add_to(bln_map_1)

# %%
bln_map_1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fe120040b155e0a12133908d8286b2c4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fe120040b155e0a12133908d8286b2c4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_fe120040b155e0a12133908d8286b2c4 = L.map(
#                 &quot;map_fe120040b155e0a12133908d8286b2c4&quot;,
#                 {
#                     center: [52.5147951, 13.3775787],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_92be951bd9eacd5ba2c1bf326854e466 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_fe120040b155e0a12133908d8286b2c4);
#
#
#             var marker_d332845fafadcc677c52ba222da6cd91 = L.marker(
#                 [52.523402, 13.398694],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_fe120040b155e0a12133908d8286b2c4);
#
#
#             var icon_c69e87027a1575390917c21e7ea3d66b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_d332845fafadcc677c52ba222da6cd91.setIcon(icon_c69e87027a1575390917c21e7ea3d66b);
#
#
#             marker_d332845fafadcc677c52ba222da6cd91.bindTooltip(
#                 `&lt;div&gt;
#                      Plazes
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_601a0cfc5c9aec7dddb9cc71f0b662c4 = L.marker(
#                 [52.4897, 13.38861],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_fe120040b155e0a12133908d8286b2c4);
#
#
#             var icon_5bfbe5cb83acd0dc905338c9c647b4ba = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_601a0cfc5c9aec7dddb9cc71f0b662c4.setIcon(icon_5bfbe5cb83acd0dc905338c9c647b4ba);
#
#
#             marker_601a0cfc5c9aec7dddb9cc71f0b662c4.bindTooltip(
#                 `&lt;div&gt;
#                      babbel
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_cfe69a3b76c19efd099f53988291f90e = L.marker(
#                 [52.512249, 13.419841],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_fe120040b155e0a12133908d8286b2c4);
#
#
#             var icon_fe5f5d7c28987a9f732a141e3cff6a62 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_cfe69a3b76c19efd099f53988291f90e.setIcon(icon_fe5f5d7c28987a9f732a141e3cff6a62);
#
#
#             marker_cfe69a3b76c19efd099f53988291f90e.bindTooltip(
#                 `&lt;div&gt;
#                      Metaversum
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_7ac6b166a24cdf91554dd681a4f1cb15 = L.marker(
#                 [52.52348, 13.411494],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_fe120040b155e0a12133908d8286b2c4);
#
#
#             var icon_effd74d79d925ddedcd5d22715ac4335 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_7ac6b166a24cdf91554dd681a4f1cb15.setIcon(icon_effd74d79d925ddedcd5d22715ac4335);
#
#
#             marker_7ac6b166a24cdf91554dd681a4f1cb15.bindTooltip(
#                 `&lt;div&gt;
#                      gate5
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_ded9ff1c94fbf77a19e7f59f232c2a2a = L.marker(
#                 [52.5283614, 13.4124563],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_fe120040b155e0a12133908d8286b2c4);
#
#
#             var icon_6f417dfc5056503be57ba442140f8fbf = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;blac

# %% [markdown]
# ## LDN Starbucks

# %%
# Copy and paste from example from website

starbucks_ldn_url = "https://api.foursquare.com/v3/places/search?query=starbucks&ll=51.5045314%2C-0.1359133"

headers = {
    "accept": "application/json",
    "Authorization": "fsq3ziQGzWOXPwEcMzd/Rtxo+uQG864OuLbWTFrbzs4E/+U="
}


starbucks_ldn_response = requests.get(starbucks_ldn_url, headers=headers).json()

# %%
#starbucks_ldn_list loop
starbucks_ldn_list = []
for i in starbucks_ldn_response ["results"]:
    
    name = i["name"]
    address =  i["location"]["formatted_address"]
    lat = i["geocodes"]["main"]["latitude"]
    lon = i["geocodes"]["main"]["longitude"]
        
    type_ = {"typepoint": 
                          {"type": "Point", 
                           "coordinates": [lat, lon]}}
    
    starbucks_ldn_list.append({"name":name, "lat":lat, "lon":lon, "type":type_})
    
starbucks_ldn_list
# Out:
# [{'name': 'Starbucks',
#   'lat': 51.507386,
#   'lon': -0.142561,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [51.507386, -0.142561]}}},
#  {'name': 'Starbucks',
#   'lat': 51.514658,
#   'lon': -0.150231,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [51.514658, -0.150231]}}},
#  {'name': 'Starbucks',
#   'lat': 51.499068,
#   'lon': -0.135253,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [51.499068, -0.135253]}}},
#  {'name': 'Starbucks',
#   'lat': 51.502096,
#   'lon': -0.117757,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [51.502096, -0.117757]}}},
#  {'name': 'Starbucks',
#   'lat': 51.512252,
#   'lon': -0.121563,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [51.512252, -0.121563]}}},
#  {'name': 'Starbucks',
#   'lat': 51.498155,
#   'lon': -0.132786,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [51.498155, -0.132786]}}},
#  {'name': 'Starbucks',
#   'lat': 51.516025,
#   'lon': -0.144089,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [51.516025, -0.144089]}}},
#  {'name': 'Starbucks',
#   'lat': 51.512688,
#   'lon': -0.133203,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [51.512688, -0.133203]}}},
#  {'name': 'Starbucks',
#   'lat': 51.51525,
#   'lon': -0.135126,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [51.51525, -0.135126]}}},
#  {'name': 'Starbucks',
#   'lat': 51.507373,
#   'lon': -0.122973,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [51.507373, -0.122973]}}}]

# %%
#Into DataFrame
starbucks_ldn_df = pd.DataFrame(starbucks_ldn_list)

# %%
#Starbucks LDN Marker Loop
for index, row in starbucks_ldn_df.iterrows():
    #1. MARKER without icon
    district = {"location": [row["lat"], row["lon"]], "tooltip": row["name"]}
    icon = Icon (
            color="beige",
            opacity = 0.2,
            prefix = "fa",
            icon = "coffee",
            icon_color = "white",
            icon_size=(30, 30)
        )
    #3. Marker
    new_marker = Marker(**district, icon = icon, radius = 2)
    #4. Add the Marker
    new_marker.add_to(ldn_map_1)

# %%
ldn_map_1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5066b73b7074fb6f51d693ee76d7bd45 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5066b73b7074fb6f51d693ee76d7bd45&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_5066b73b7074fb6f51d693ee76d7bd45 = L.map(
#                 &quot;map_5066b73b7074fb6f51d693ee76d7bd45&quot;,
#                 {
#                     center: [51.5037375, -0.1346877],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7a13c78b1236dc0f8324f96d9ce6fd25 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5066b73b7074fb6f51d693ee76d7bd45);
#
#
#             var marker_fa62d17c87474588eb292f736540c0ec = L.marker(
#                 [53.344104, -6.267494],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_5066b73b7074fb6f51d693ee76d7bd45);
#
#
#             var icon_a6eb60e051d06dafb8c61eb8e678a860 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_fa62d17c87474588eb292f736540c0ec.setIcon(icon_a6eb60e051d06dafb8c61eb8e678a860);
#
#
#             marker_fa62d17c87474588eb292f736540c0ec.bindTooltip(
#                 `&lt;div&gt;
#                      Babelgum
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_5be41a7bbc29964c8b1a8d23b6a3e15e = L.marker(
#                 [37.09024, -95.712891],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_5066b73b7074fb6f51d693ee76d7bd45);
#
#
#             var icon_563444affedb1f9be534bc0432fb1eca = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_5be41a7bbc29964c8b1a8d23b6a3e15e.setIcon(icon_563444affedb1f9be534bc0432fb1eca);
#
#
#             marker_5be41a7bbc29964c8b1a8d23b6a3e15e.bindTooltip(
#                 `&lt;div&gt;
#                      Kelkoo
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_c47262103744112d3807ab71f39d85b1 = L.marker(
#                 [41.53155, -72.188584],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_5066b73b7074fb6f51d693ee76d7bd45);
#
#
#             var icon_c337d7fae318cb74652cdc64fed56e22 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_c47262103744112d3807ab71f39d85b1.setIcon(icon_c337d7fae318cb74652cdc64fed56e22);
#
#
#             marker_c47262103744112d3807ab71f39d85b1.bindTooltip(
#                 `&lt;div&gt;
#                      ReachLocal
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_00a7e0d7de0fe6eae8468cef8b8fa6d3 = L.marker(
#                 [51.5108803, -0.1418973],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_5066b73b7074fb6f51d693ee76d7bd45);
#
#
#             var icon_166d8e77f6b54592d4812a5f7a4860a1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_00a7e0d7de0fe6eae8468cef8b8fa6d3.setIcon(icon_166d8e77f6b54592d4812a5f7a4860a1);
#
#
#             marker_00a7e0d7de0fe6eae8468cef8b8fa6d3.bindTooltip(
#                 `&lt;div&gt;
#                      Seedcamp
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_3fc3bec577b00f0cb08b2a9f0f7b2f07 = L.marker(
#                 [51.5192042, -0.1626103],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_5066b73b7074fb6f51d693ee76d7bd45);
#
#
#             var icon_a1bb6511c2f9ac6e6e9f2a3c91523103 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;:

# %% [markdown]
# ## BCN Basketball

# %%
# Copy and paste from example from website

basketball_bcn_url = "https://api.foursquare.com/v3/places/search?query=basketball%20&ll=41.3898224%2C2.163367"

headers = {
    "accept": "application/json",
    "Authorization": "fsq3ziQGzWOXPwEcMzd/Rtxo+uQG864OuLbWTFrbzs4E/+U="
}




basketball_bcn_response = requests.get(basketball_bcn_url, headers=headers).json()

# %%
#basketball_bcn_list loop
basketball_bcn_list = []
for i in basketball_bcn_response ["results"]:
    
    name = i["name"]
    address =  i["location"]["formatted_address"]
    lat = i["geocodes"]["main"]["latitude"]
    lon = i["geocodes"]["main"]["longitude"]
        
    type_ = {"typepoint": 
                          {"type": "Point", 
                           "coordinates": [lat, lon]}}
    
    basketball_bcn_list.append({"name":name, "lat":lat, "lon":lon, "type":type_})
    
basketball_bcn_list
# Out:
# [{'name': 'Palau Blaugrana',
#   'lat': 41.380163,
#   'lon': 2.120141,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [41.380163, 2.120141]}}},
#  {'name': 'Pavelló Olímpic de Badalona',
#   'lat': 41.442346,
#   'lon': 2.232148,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [41.442346, 2.232148]}}},
#  {'name': 'Pavelló Municipal de Cabrils',
#   'lat': 41.521748,
#   'lon': 2.369039,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [41.521748, 2.369039]}}},
#  {'name': 'Club Basquet Granollers',
#   'lat': 41.616691,
#   'lon': 2.293679,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [41.616691, 2.293679]}}},
#  {'name': 'Parque de la Infanta',
#   'lat': 41.360562,
#   'lon': 2.063817,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [41.360562, 2.063817]}}},
#  {'name': 'Esportiu Claret',
#   'lat': 41.406447,
#   'lon': 2.166812,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [41.406447, 2.166812]}}},
#  {'name': 'Poliesportiu Ripollet',
#   'lat': 41.500396,
#   'lon': 2.149372,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [41.500396, 2.149372]}}},
#  {'name': 'Poliesportiu la Llana',
#   'lat': 41.501004,
#   'lon': 2.029792,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [41.501004, 2.029792]}}},
#  {'name': "Palau d'Esports de Granollers",
#   'lat': 41.598324,
#   'lon': 2.287622,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [41.598324, 2.287622]}}},
#  {'name': 'Poliesportiu municipal',
#   'lat': 41.43131,
#   'lon': 2.215605,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [41.43131, 2.215605]}}}]

# %%
#Into DataFrame
basketball_bcn_df = pd.DataFrame(basketball_bcn_list)

# %%
#Basketball BCN Marker Loop
for index, row in basketball_bcn_df.iterrows():
    #1. MARKER without icon
    district = {"location": [row["lat"], row["lon"]], "tooltip": row["name"]}
    icon = Icon (
            color="orange",
            opacity = 0.2,
            prefix = "fa",
            icon = "futbol-o",
            icon_color = "white",
            icon_size=(30, 30)
        )
    #3. Marker
    new_marker = Marker(**district, icon = icon, radius = 2)
    #4. Add the Marker
    new_marker.add_to(bcn_map_1)

# %%
bcn_map_1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1c7751833034494e122f6e041a144b2c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1c7751833034494e122f6e041a144b2c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_1c7751833034494e122f6e041a144b2c = L.map(
#                 &quot;map_1c7751833034494e122f6e041a144b2c&quot;,
#                 {
#                     center: [41.3898224, 2.163367],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5b2589963e8ef719d193a3a42a0f04c8 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1c7751833034494e122f6e041a144b2c);
#
#
#             var marker_11a24e3566bc7041e3ce42f19d84df9c = L.marker(
#                 [41.3854855, 2.1702872],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_1c7751833034494e122f6e041a144b2c);
#
#
#             var icon_a43bba29fcde0926ecd03e3e1674b3df = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_11a24e3566bc7041e3ce42f19d84df9c.setIcon(icon_a43bba29fcde0926ecd03e3e1674b3df);
#
#
#             marker_11a24e3566bc7041e3ce42f19d84df9c.bindTooltip(
#                 `&lt;div&gt;
#                      eyeOS
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_63da76f5868f2fe77e24eed54fa7fd7d = L.marker(
#                 [41.396553, 2.189241],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_1c7751833034494e122f6e041a144b2c);
#
#
#             var icon_94010287d78b4a671e551f46cd82f4c7 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_63da76f5868f2fe77e24eed54fa7fd7d.setIcon(icon_94010287d78b4a671e551f46cd82f4c7);
#
#
#             marker_63da76f5868f2fe77e24eed54fa7fd7d.bindTooltip(
#                 `&lt;div&gt;
#                      Futurlink
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_ec8bfe147e21dde388c28b4b09e4c42d = L.marker(
#                 [41.392852, 2.168021],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_1c7751833034494e122f6e041a144b2c);
#
#
#             var icon_78e5d51307c0897cc44ac718e2410c6c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_ec8bfe147e21dde388c28b4b09e4c42d.setIcon(icon_78e5d51307c0897cc44ac718e2410c6c);
#
#
#             marker_ec8bfe147e21dde388c28b4b09e4c42d.bindTooltip(
#                 `&lt;div&gt;
#                      vLex
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_9c5978124108cf8c3e327f5883a0d6c3 = L.marker(
#                 [41.3916792, 2.1775706],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_1c7751833034494e122f6e041a144b2c);
#
#
#             var icon_5b50d515979bed0912f1c4d4de9aa742 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_9c5978124108cf8c3e327f5883a0d6c3.setIcon(icon_5b50d515979bed0912f1c4d4de9aa742);
#
#
#             marker_9c5978124108cf8c3e327f5883a0d6c3.bindTooltip(
#                 `&lt;div&gt;
#                      Nuroa
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_52fdd87f043e13ac1321789ff0a6d8dc = L.marker(
#                 [41.406335, 2.192023],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_1c7751833034494e122f6e041a144b2c);
#
#
#             var icon_ae6218d71ffabc3ccb99ade5f455f8b3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quo

# %% [markdown]
# ## BLN Basketball

# %%
# Copy and paste from example from website

basketball_bln_url = "https://api.foursquare.com/v3/places/search?query=basketball%20&ll=52.5172198%2C13.3782205"

headers = {
    "accept": "application/json",
    "Authorization": "fsq3ziQGzWOXPwEcMzd/Rtxo+uQG864OuLbWTFrbzs4E/+U="
}




basketball_bln_response = requests.get(basketball_bln_url, headers=headers).json()

# %%
#basketball_ldn_list loop
basketball_bln_list = []
for i in basketball_bln_response ["results"]:
    
    name = i["name"]
    address =  i["location"]["formatted_address"]
    lat = i["geocodes"]["main"]["latitude"]
    lon = i["geocodes"]["main"]["longitude"]
        
    type_ = {"typepoint": 
                          {"type": "Point", 
                           "coordinates": [lat, lon]}}
    
    basketball_bln_list.append({"name":name, "lat":lat, "lon":lon, "type":type_})
    
basketball_bln_list
# Out:
# [{'name': 'Basketballplatz Böcklerpark',
#   'lat': 52.496867,
#   'lon': 13.407324,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [52.496867, 13.407324]}}},
#  {'name': 'Basketballplatz Mauerpark',
#   'lat': 52.541184,
#   'lon': 13.40322,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [52.541184, 13.40322]}}},
#  {'name': 'Berlin - Basketball im Mauerpark',
#   'lat': 52.540628,
#   'lon': 13.405647,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [52.540628, 13.405647]}}},
#  {'name': 'Basketballplatz Rütli-Schule',
#   'lat': 52.486831,
#   'lon': 13.434298,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [52.486831, 13.434298]}}},
#  {'name': 'Mellowpark',
#   'lat': 52.455546,
#   'lon': 13.563746,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [52.455546, 13.563746]}}},
#  {'name': 'Mauerpark',
#   'lat': 52.543815,
#   'lon': 13.402656,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [52.543815, 13.402656]}}},
#  {'name': 'Volkspark Wilmersdorf',
#   'lat': 52.48338,
#   'lon': 13.327615,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [52.48338, 13.327615]}}},
#  {'name': 'Schwalbe',
#   'lat': 52.545535,
#   'lon': 13.416885,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [52.545535, 13.416885]}}},
#  {'name': 'Bata Bar & Billiards',
#   'lat': 52.530591,
#   'lon': 13.367283,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [52.530591, 13.367283]}}},
#  {'name': 'adidas Performance Store',
#   'lat': 52.503596,
#   'lon': 13.337239,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [52.503596, 13.337239]}}}]

# %%
#Into DataFrame
basketball_bln_df = pd.DataFrame(basketball_bln_list)

# %%
#Basketball BLN Marker Loop
for index, row in basketball_bln_df.iterrows():
    #1. MARKER without icon
    district = {"location": [row["lat"], row["lon"]], "tooltip": row["name"]}
    icon = Icon (
            color="orange",
            opacity = 0.2,
            prefix = "fa",
            icon = "futbol-o",
            icon_color = "white",
            icon_size=(30, 30)
        )
    #3. Marker
    new_marker = Marker(**district, icon = icon, radius = 2)
    #4. Add the Marker
    new_marker.add_to(bln_map_1)

# %%
bln_map_1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fe120040b155e0a12133908d8286b2c4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fe120040b155e0a12133908d8286b2c4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_fe120040b155e0a12133908d8286b2c4 = L.map(
#                 &quot;map_fe120040b155e0a12133908d8286b2c4&quot;,
#                 {
#                     center: [52.5147951, 13.3775787],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_92be951bd9eacd5ba2c1bf326854e466 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_fe120040b155e0a12133908d8286b2c4);
#
#
#             var marker_d332845fafadcc677c52ba222da6cd91 = L.marker(
#                 [52.523402, 13.398694],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_fe120040b155e0a12133908d8286b2c4);
#
#
#             var icon_c69e87027a1575390917c21e7ea3d66b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_d332845fafadcc677c52ba222da6cd91.setIcon(icon_c69e87027a1575390917c21e7ea3d66b);
#
#
#             marker_d332845fafadcc677c52ba222da6cd91.bindTooltip(
#                 `&lt;div&gt;
#                      Plazes
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_601a0cfc5c9aec7dddb9cc71f0b662c4 = L.marker(
#                 [52.4897, 13.38861],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_fe120040b155e0a12133908d8286b2c4);
#
#
#             var icon_5bfbe5cb83acd0dc905338c9c647b4ba = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_601a0cfc5c9aec7dddb9cc71f0b662c4.setIcon(icon_5bfbe5cb83acd0dc905338c9c647b4ba);
#
#
#             marker_601a0cfc5c9aec7dddb9cc71f0b662c4.bindTooltip(
#                 `&lt;div&gt;
#                      babbel
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_cfe69a3b76c19efd099f53988291f90e = L.marker(
#                 [52.512249, 13.419841],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_fe120040b155e0a12133908d8286b2c4);
#
#
#             var icon_fe5f5d7c28987a9f732a141e3cff6a62 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_cfe69a3b76c19efd099f53988291f90e.setIcon(icon_fe5f5d7c28987a9f732a141e3cff6a62);
#
#
#             marker_cfe69a3b76c19efd099f53988291f90e.bindTooltip(
#                 `&lt;div&gt;
#                      Metaversum
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_7ac6b166a24cdf91554dd681a4f1cb15 = L.marker(
#                 [52.52348, 13.411494],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_fe120040b155e0a12133908d8286b2c4);
#
#
#             var icon_effd74d79d925ddedcd5d22715ac4335 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_7ac6b166a24cdf91554dd681a4f1cb15.setIcon(icon_effd74d79d925ddedcd5d22715ac4335);
#
#
#             marker_7ac6b166a24cdf91554dd681a4f1cb15.bindTooltip(
#                 `&lt;div&gt;
#                      gate5
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_ded9ff1c94fbf77a19e7f59f232c2a2a = L.marker(
#                 [52.5283614, 13.4124563],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_fe120040b155e0a12133908d8286b2c4);
#
#
#             var icon_6f417dfc5056503be57ba442140f8fbf = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;blac

# %% [markdown]
# ## LDN Basketball

# %%
# Copy and paste from example from website

basketball_ldn_url = "https://api.foursquare.com/v3/places/search?query=basketball%20&ll=51.512620%2C0.132383"

headers = {
    "accept": "application/json",
    "Authorization": "fsq3ziQGzWOXPwEcMzd/Rtxo+uQG864OuLbWTFrbzs4E/+U="
}




basketball_ldn_response = requests.get(basketball_ldn_url, headers=headers).json()

# %%
#basketball_ldn_list loop
basketball_ldn_list = []
for i in basketball_ldn_response ["results"]:
    
    name = i["name"]
    address =  i["location"]["formatted_address"]
    lat = i["geocodes"]["main"]["latitude"]
    lon = i["geocodes"]["main"]["longitude"]
        
    type_ = {"typepoint": 
                          {"type": "Point", 
                           "coordinates": [lat, lon]}}
    
    basketball_ldn_list.append({"name":name, "lat":lat, "lon":lon, "type":type_})
    
basketball_ldn_list
# Out:
# [{'name': 'Geraldine Mary Harmsworth Sports Facility',
#   'lat': 51.496187,
#   'lon': -0.106748,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [51.496187, -0.106748]}}},
#  {'name': 'Aske Gardens',
#   'lat': 51.528096,
#   'lon': -0.083989,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [51.528096, -0.083989]}}},
#  {'name': 'Clissold Park',
#   'lat': 51.561438,
#   'lon': -0.088457,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [51.561438, -0.088457]}}},
#  {'name': 'Q Motion Health & Fitness Centre',
#   'lat': 51.523206,
#   'lon': -0.043008,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [51.523206, -0.043008]}}},
#  {'name': 'Chinbrook Meadows',
#   'lat': 51.428723,
#   'lon': 0.028298,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [51.428723, 0.028298]}}},
#  {'name': 'Kennington Park',
#   'lat': 51.482819,
#   'lon': -0.107596,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [51.482819, -0.107596]}}},
#  {'name': 'Bounce',
#   'lat': 51.518019,
#   'lon': -0.108431,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [51.518019, -0.108431]}}},
#  {'name': 'Leyton Jubilee Park',
#   'lat': 51.564646,
#   'lon': -0.025511,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [51.564646, -0.025511]}}},
#  {'name': 'Victoria Park',
#   'lat': 51.605484,
#   'lon': -0.184854,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [51.605484, -0.184854]}}},
#  {'name': 'The Beehive',
#   'lat': 51.593991,
#   'lon': -0.06856,
#   'type': {'typepoint': {'type': 'Point',
#     'coordinates': [51.593991, -0.06856]}}}]

# %%
#Into DataFrame
basketball_ldn_df = pd.DataFrame(basketball_ldn_list)

# %%
#Basketball LDN Marker Loop
for index, row in basketball_ldn_df.iterrows():
    #1. MARKER without icon
    district = {"location": [row["lat"], row["lon"]], "tooltip": row["name"]}
    icon = Icon (
            color="orange",
            opacity = 0.2,
            prefix = "fa",
            icon = "futbol-o",
            icon_color = "white",
            icon_size=(30, 30)
        )
    #3. Marker
    new_marker = Marker(**district, icon = icon, radius = 2)
    #4. Add the Marker
    new_marker.add_to(ldn_map_1)

# %%
ldn_map_1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5066b73b7074fb6f51d693ee76d7bd45 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5066b73b7074fb6f51d693ee76d7bd45&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_5066b73b7074fb6f51d693ee76d7bd45 = L.map(
#                 &quot;map_5066b73b7074fb6f51d693ee76d7bd45&quot;,
#                 {
#                     center: [51.5037375, -0.1346877],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7a13c78b1236dc0f8324f96d9ce6fd25 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5066b73b7074fb6f51d693ee76d7bd45);
#
#
#             var marker_fa62d17c87474588eb292f736540c0ec = L.marker(
#                 [53.344104, -6.267494],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_5066b73b7074fb6f51d693ee76d7bd45);
#
#
#             var icon_a6eb60e051d06dafb8c61eb8e678a860 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_fa62d17c87474588eb292f736540c0ec.setIcon(icon_a6eb60e051d06dafb8c61eb8e678a860);
#
#
#             marker_fa62d17c87474588eb292f736540c0ec.bindTooltip(
#                 `&lt;div&gt;
#                      Babelgum
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_5be41a7bbc29964c8b1a8d23b6a3e15e = L.marker(
#                 [37.09024, -95.712891],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_5066b73b7074fb6f51d693ee76d7bd45);
#
#
#             var icon_563444affedb1f9be534bc0432fb1eca = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_5be41a7bbc29964c8b1a8d23b6a3e15e.setIcon(icon_563444affedb1f9be534bc0432fb1eca);
#
#
#             marker_5be41a7bbc29964c8b1a8d23b6a3e15e.bindTooltip(
#                 `&lt;div&gt;
#                      Kelkoo
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_c47262103744112d3807ab71f39d85b1 = L.marker(
#                 [41.53155, -72.188584],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_5066b73b7074fb6f51d693ee76d7bd45);
#
#
#             var icon_c337d7fae318cb74652cdc64fed56e22 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_c47262103744112d3807ab71f39d85b1.setIcon(icon_c337d7fae318cb74652cdc64fed56e22);
#
#
#             marker_c47262103744112d3807ab71f39d85b1.bindTooltip(
#                 `&lt;div&gt;
#                      ReachLocal
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_00a7e0d7de0fe6eae8468cef8b8fa6d3 = L.marker(
#                 [51.5108803, -0.1418973],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_5066b73b7074fb6f51d693ee76d7bd45);
#
#
#             var icon_166d8e77f6b54592d4812a5f7a4860a1 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;: &quot;black&quot;, &quot;iconSize&quot;: [30, 30], &quot;markerColor&quot;: &quot;blue&quot;, &quot;opacity&quot;: 0.6, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_00a7e0d7de0fe6eae8468cef8b8fa6d3.setIcon(icon_166d8e77f6b54592d4812a5f7a4860a1);
#
#
#             marker_00a7e0d7de0fe6eae8468cef8b8fa6d3.bindTooltip(
#                 `&lt;div&gt;
#                      Seedcamp
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_3fc3bec577b00f0cb08b2a9f0f7b2f07 = L.marker(
#                 [51.5192042, -0.1626103],
#                 {&quot;radius&quot;: 2}
#             ).addTo(map_5066b73b7074fb6f51d693ee76d7bd45);
#
#
#             var icon_a1bb6511c2f9ac6e6e9f2a3c91523103 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;building-o&quot;, &quot;iconColor&quot;:
